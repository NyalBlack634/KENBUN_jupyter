# %% [markdown]
# # 新聞取得

# %%
import os
import openpyxl

# %%
path_list = []

for curDir, dirs, files in os.walk("新聞"):
    #         print('=='*20)
    #         print('現在のフォルダ: ' + curDir)
    #         print('内包するフォルダ: ', end='')
    #         print(dirs)
    #         print('内包するファイル: ', end='')
    #         print(files)
    path = curDir + '\\'
    for file in files:
        path += file
        #             print('ファイルパス: ' + path)
        path_list.append(path)
        path = curDir + '\\'

# %%
headlines = []  # 格納用辞書

wb1 = openpyxl.load_workbook(path_list[0])
sheet = wb1['シート1']
# [社名、年、月、名前、見出し、ベクトル]
headlines = [(row[0].value, row[1].value, row[2].value, row[3].value, row[4].value) for row in sheet.rows]

wb2 = openpyxl.load_workbook(path_list[1])
sheet = wb2['シート1']
headlines2 = [(row[0].value, row[1].value, row[2].value, row[3].value, row[4].value) for row in sheet.rows]

# %%
headlines += headlines2

# %% [markdown]
# # 分かち書き

# %%
import MeCab as mc
import mojimoji
m = mc.Tagger("-Ochasen")

# %%
def mecab_tokenizer(text: str):
    """
    テキストを分かち書きするメソッド
    :param text: 分割したいテキスト
    :return: 分割後のテキスト
    """

    node = m.parseToNode(text)
    word_list = list()
    while node:
        if node.surface != "":
            res = node.feature.split(",")
            word_type = res[0]
            if word_type in ['名詞', "動詞", "形容詞", "副詞"]:  # 名詞, 動詞, 形容詞, 副詞のみを抽出
                basic_word = res[6]
                if basic_word != "*":
                    word_list.append(basic_word)
                else:
                    word_list.append('[UNK]')  # 未知語の場合は[UNK]トークンに置き換え
        node = node.next
        if node is None:
            break
    return word_list

# %%
from gensim.models import KeyedVectors
# Out:
# C:\Users\naoki\anaconda3\envs\nlp_bot\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
def clean_text(text: str):
    """
    テキストの正規化
    :param text: 正規化するテキスト
    :return: 正規化後のテキスト
    """
    text = mojimoji.han_to_zen(text, digit=False, ascii=False)  # 半角文字を全角文字に統一(数字, 英語以外)
    text = mojimoji.zen_to_han(text, kana=False)  # 全角文字を半角文字に統一(かな以外)
    text = text.lower()  # 小文字に統一
    return text

# %% [markdown]
# # ベクトル化

# %%
file_name = "jawiki.all_vectors.200d.txt"

model = KeyedVectors.load_word2vec_format(file_name)

# %%
import numpy as np

# %%
def vectorize_word(text: str):
    """
    元word_analysis()
    ベクトル化を行うメソッド
    :param text: ベクトル化するテキスト
    :return: ベクトル化したテキスト(array型)
    """

    text = clean_text(text)

    V = list()  # 文章のベクトル(200次元)を格納

    # 文章の対して, 文章中の単語のベクトルの平均を求める処理を行う
    word_list = mecab_tokenizer(text)
    v = np.array([0.0] * 200)
    word_num = 0
    for word in word_list:
        try:
            v += np.array(model[word])
        except KeyError as error:
            continue
        except ValueError as verror:
            continue
        word_num += 1

    try:
        v = v / word_num
    except ZeroDivisionError as e:
        print(f'ZeroDivisionError: {e}')

    return v

def cos_sim(v1, v2):
    """
    cos類似度を計算
    :param v1: word2vecによりベクトル化したテキスト1(ndarray型)
    :param v2: word2vecによりベクトル化したテキスト2(ndarray型)
    :return: 二つのテキストのcos類似度
    """
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

# %%
def get_news_dict(filename: str):
    """
    エクセルから見出しのタイトル(識別番号？)とテキストを取り出しベクトル化して辞書として返す
    :param filename: excelファイル名
    :return: ひと月分の辞書<br>
    一つの要素に{(会社名、年、月、名前):(見出し, ベクトル)} -> の形で返す
    """
    wb = openpyxl.load_workbook(filename)
    sheet = wb['シート1']
    dict = {}  # 格納用辞書
    for row in sheet.rows:

        if row[4].value is not None:
            vector = vectorize_word(row[4].value)  # 見出しをベクトル化
            dict[(row[0].value, row[1].value, row[2].value, row[3].value)] = (row[4].value, vector)  # (会社名、年、月、名前)と(見出し、ベクトル)の組

    return dict

# %%
all_newspapers = [get_news_dict(path) for path in path_list]

headline_list = [(name[0], name[1], name[2], name[3], headline[0], headline[1]) for news in all_newspapers \
                for name, headline in news.items()]

del all_newspapers
# Out:
# C:\Users\naoki\anaconda3\envs\nlp_bot\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# # Wordnetを利用
# 参考サイト: https://qiita.com/pocket_kyoto/items/f2382b9821d32624e6bc<br>
# https://github.com/EmulsionBondo/jwordnet/blob/master/SearchUpperConceptWords.py

# %%
import sqlite3
import sys
conn = sqlite3.connect("wnjpn.db")

# %%
# 上位-下位の関係にある概念の抽出
hierarchy_dict = {}  # key:上位語(String), value:下位語(List of String)
n_term_set = set()  # 下位語に含まれる単語集合

# %%
class node:
    def __init__(self, name, children=None):
        self.name = name  # String
        self.children = children  # List of Class node

    # 結果表示用
    def display(self, indent = 0):
        if self.children != None:
            print(' '*indent + self.name)
            for c in self.children:
                c.display(indent+1)
        else:
            print(' '*indent + self.name)

# %%
def search_upper_concept_words(word, hierarchy_dict):
    """
    特定の単語を入力とした時に、上位語を検索する関数
    :param word: 検索する単語
    :param hierarchy_dict: 上位語
    :return : すべての上位語を返す
    """
    cur = conn.execute(f"select wordid from word where lemma='{word}'")
    word_id = 99999999  #temp
    for row in cur:
        word_id = row[0]
    
    if word_id == 99999999: # Wordnetに存在する語であるかの判定
        print(f'「{word}」は存在しない単語です。')
    else:
        print(f'「{word}」の上位概念を出力します。')
    
    # 入力された単語を含む概念を検索
    cur = conn.execute(f"select synset from sense where wordid='{word_id}'")
    synsets = []
    for row in cur:
        synsets.append(row[0])
    
    hypernyms = []
    for synset in synsets:
        # 上位語を取得する対象のsynsetを表示
        print(f'------------------{synset_name_dict[synset]}---------------------')
        hypernyms.append(synset_name_dict[synset])
        
        #現在のsynsetの上位語をすべて取得するため，tmp_synsetに代入
        tmp_synset=synset
        # synsetの上位語を最上位まで列挙
        while(tmp_synset in hierarchy_dict.values()):
            # エラーが発生=最上位を取得したら終了
            try:
                print(synset_name_dict[hierarchy_dict[tmp_synset]])
                hypernyms.append(synset_name_dict[hierarchy_dict[tmp_synset]])
                tmp_synset = hierarchy_dict[tmp_synset]
            except:
                break
    
    return hypernyms

# %%
# 下位-上位の関係にある概念の抽出
cur = conn.execute("select synset1,synset2 from synlink where link='hypo'")

# %%
for row in cur:
    b_term = row[0] # 下位概念のID
    n_term = row[1] # 上位概念のID
    
    if n_term not in hierarchy_dict:
        hierarchy_dict[n_term] = b_term

# %%
# synset(概念)のIDから、概念の名称に変換する辞書の作成
synset_name_dict = {}  # key:synsetのID, value:synsetの名称
cur = conn.execute("select synset,name from synset")

# %%
for row in cur:
    synset_name_dict[row[0]] = row[1]

# %%
search_upper_concept_words('猫', hierarchy_dict)
# Out:
# 「猫」の上位概念を出力します。
# ------------------true_cat---------------------
# feline
# carnivore
# placental
# mammalian
# vertebrate
# chordate
# animate_being
# being
# living_thing
# whole
# physical_object
# physical_entity
# entity
# ['true_cat',
#  'feline',
#  'carnivore',
#  'placental',
#  'mammalian',
#  'vertebrate',
#  'chordate',
#  'animate_being',
#  'being',
#  'living_thing',
#  'whole',
#  'physical_object',
#  'physical_entity',
#  'entity']

# %% [markdown]
# # 組み合わせて使うパターンとは？
# 選択した記事を形態素解析で分解してwordnetで上位概念を呼び出す？

# %%
def get_all_similarity(headline_list, speech_text: str):
    """
    全ての見出しと発言の類似度分析を行い, 類似度で降順にソートして返す
    :param headline_list: 見出しをまとめたリスト<br> ひとつの要素に(ファイルパス, 番号, (見出し, ベクトル)) -> の形で格納している
    :param speech_text: 発言
    :return: 類似度で降順にソートしたリスト [((会社名, 出版年, 出版付き, 番号, 見出し), 類似度)] -> この形になっている
    """
    # speech_text = '物価下がらなかったのね'
    speech_v = vectorize_word(speech_text)  # 発言をベクトル化

    similarity_dic = {}

    for company, year, month, day, headline, vector in headline_list:
        cs = cos_sim(speech_v, vector)  # 発言と見出しテキストのcos類似度を計算

        if cs >= 0.75:  # cos類似度が閾値以上であれば提示する見出しリストに加える
            similarity_dic[(company, year, month, day, headline)] = cs

    return sorted(similarity_dic.items(), key=lambda x: x[1], reverse=True)

# %%
test_list = get_all_similarity(headline_list, '大分県')

# %%
for i, test in enumerate(test_list):
    if i < 15:
        print(test)
# Out:
# (('大分合同新聞', '1961年', '10月', '19-a-11_01', '大分県'), 0.9999999999999999)
# (('大分合同新聞', '1964年', '7月', '25-a-2_01', '大分県から'), 0.9999999999999999)
# (('大分合同新聞', '1956年', '7月', '5-a-2_08', '* 垢石と大分県\n木下'), 0.9367297438196754)
# (('大分新聞', '1921年', '7月', '26-a-1_01', '大分県の人々へ'), 0.9360428091470805)
# (('大分合同新聞', '1963年', '1月', '4-y-3_11', 'にし\n大分県から'), 0.9338110293527784)
# (('大分合同新聞', '1955年', '11月', '20-a-2_07', '大分県い觀光'), 0.9312139687897014)
# (('大分合同新聞', '1959年', '3月', '27-y-3_04', '「ウルト』\nのゆく大分県'), 0.9297332033559976)
# (('大分合同新聞', '1965年', '2月', '19-y-2_04', '愛知県の危険は大分県でも...'), 0.9290716653395311)
# (('大分合同新聞', '1957年', '10月', '9-y-3_13', '大分県の道'), 0.9272672920557428)
# (('大分合同新聞', '1958年', '1月', '13-y-2_04', '(ラジオ大分県のNHK)'), 0.9255612509047665)
# (('大分新聞', '1936年', '6月', '30-y-1_13', '間にりを 大分県'), 0.9232655893301763)
# (('大分合同新聞', '1960年', '12月', '17-y-3_02', '大分県呉市'), 0.9217930500878802)
# (('大分合同新聞', '1961年', '3月', '18-y-4_01', '大分県の酒'), 0.9189891448092182)
# (('大分合同新聞', '1962年', '8月', '17-a-5_02', '| 大分県の盆踊り'), 0.9172397856294606)
# (('大分合同新聞', '1963年', '1月', '1-a-15_01', '大分県を美しく'), 0.916509134812021)

# %%
# 上で提示された見出しの中からクリックしたと想定
sample_text = '愛知県の危険は大分県でも...'

tokens = mecab_tokenizer(sample_text)

# %%
tokens
# Out:
# ['愛知', '県', '危険', '大分', '県', '[UNK]']

# %%
# 重複排除
tokens = list(set(tokens))

# %%
for token in tokens:
    print(f'検索語: {token}')
    hypernyms = search_upper_concept_words(token, hierarchy_dict)
    print(hypernyms)
# Out:
# 検索語: 危険
# 「危険」の上位概念を出力します。
# ------------------parlous---------------------
# ------------------risky---------------------
# ------------------severe---------------------
# ------------------bad---------------------
# ------------------unsafe---------------------
# ['parlous', 'risky', 'severe', 'bad', 'unsafe']
# 検索語: 大分
# 「大分」の上位概念を出力します。
# ------------------considerably---------------------
# ------------------much---------------------
# ------------------a_lot---------------------
# ['considerably', 'much', 'a_lot']
# 検索語: [UNK]
# 「[UNK]」は存在しない単語です。
# []
# 検索語: 愛知
# 「愛知」は存在しない単語です。
# []
# 検索語: 県
# 「県」の上位概念を出力します。
# ------------------prefecture---------------------
# ['prefecture']

# %%
test_list = get_all_similarity(headline_list, 'parlous')
# Out:
# C:\Users\naoki\anaconda3\envs\nlp_bot\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in true_divide

# %%
test_list
# Out:
# []

# %% [markdown]
# ## Google翻訳APIのエラー対処
# 以下のサイトを参考<br>
# 最新のアルファ版を使うと安定<br>
# https://qiita.com/_yushuu/items/83c51e29771530646659

# %%
from googletrans import Translator

# %%
translator = Translator()

# %%
translated = translator.translate('prefecture', src='en', dest='ja')
print(translated.text)
# Out:
# 県

# %%
# %%timeit
similarity_headlines = []

for token in tokens:
    print(f'検索語: {token}')
    hypernyms = search_upper_concept_words(token, hierarchy_dict)
    
    # 翻訳
    for hypernym in hypernyms:
        print(f'{hypernym}')
        translated = translator.translate(hypernym, src='en', dest='ja')
        similarity_headlines += get_all_similarity(headline_list, translated.text)
# Out:
# 検索語: 危険
# 「危険」の上位概念を出力します。
# ------------------parlous---------------------
# ------------------risky---------------------
# ------------------severe---------------------
# ------------------bad---------------------
# ------------------unsafe---------------------
# parlous
# C:\Users\naoki\anaconda3\envs\nlp_bot\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in true_divide
# risky
# severe
# bad
# unsafe
# 検索語: 大分
# 「大分」の上位概念を出力します。
# ------------------considerably---------------------
# ------------------much---------------------
# ------------------a_lot---------------------
# considerably
# much
# a_lot
# 検索語: [UNK]
# 「[UNK]」は存在しない単語です。
# 検索語: 愛知
# 「愛知」は存在しない単語です。
# 検索語: 県
# 「県」の上位概念を出力します。
# ------------------prefecture---------------------
# prefecture
# 検索語: 危険
# 「危険」の上位概念を出力します。
# ------------------parlous---------------------
# ------------------risky---------------------
# ------------------severe---------------------
# ------------------bad---------------------
# ------------------unsafe---------------------
# parlous
# risky
# severe
# bad
# unsafe
# 検索語: 大分
# 「大分」の上位概念を出力します。
# ------------------considerably---------------------
# ------------------much---------------------
# ------------------a_lot---------------------
# considerably
# much
# a_lot
# 検索語: [UNK]
# 「[UNK]」は存在しない単語です。
# 検索語: 愛知
# 「愛知」は存在しない単語です。
# 検索語: 県
# 「県」の上位概念を出力します。
# ------------------prefecture---------------------
# prefecture
# 検索語: 危険
# 「危険」の上位概念を出力します。
# ------------------parlous---------------------
# ------------------risky---------------------
# ------------------severe---------------------
# ------------------bad---------------------
# ------------------unsafe---------------------
# parlous
# risky
# severe
# bad
# unsafe
# 検索語: 大分
# 「大分」の上位概念を出力します。
# ------------------considerably---------------------
# ------------------much---------------------
# ------------------a_lot---------------------
# considerably
# much
# a_lot
# 検索語: [UNK]
# 「[UNK]」は存在しない単語です。
# 検索語: 愛知
# 「愛知」は存在しない単語です。
# 検索語: 県
# 「県」の上位概念を出力します。
# ------------------prefecture---------------------
# prefecture
# 検索語: 危険
# 「危険」の上位概念を出力します。
# ------------------parlous---------------------
# ------------------risky---------------------
# ------------------severe---------------------
# ------------------bad---------------------
# ------------------unsafe---------------------
# parlous
# risky
# severe
# bad
# unsafe
# 検索語: 大分
# 「大分」の上位概念を出力します。
# ------------------considerably---------------------
# ------------------much---------------------
# ------------------a_lot---------------------
# considerably
# much
# a_lot
# 検索語: [UNK]
# 「[UNK]」は存在しない単語です。
# 検索語: 愛知
# 「愛知」は存在しない単語です。
# 検索語: 県
# 「県」の上位概念を出力します。
# ------------------prefecture---------------------
# prefecture
# 検索語: 危険
# 「危険」の上位概念を出力します。
# ------------------parlous---------------------
# ------------------risky---------------------
# ------------------severe---------------------
# ------------------bad---------------------
# ------------------unsafe---------------------
# parlous
# risky
# severe
# bad
# unsafe
# 検索語: 大分
# 「大分」の上位概念を出力します。
# ------------------considerably---------------------
# ------------------much---------------------
# ------------------a_lot---------------------
# considerably
# much
# a_lot
# 検索語: [UNK]
# 「[UNK]」は存在しない単語です。
# 検索語: 愛知
# 「愛知」は存在しない単語です。
# 検索語: 県
# 「県」の上位概念を出力します。
# ------------------prefecture---------------------
# prefecture
# 検索語: 危険
# 「危険」の上位概念を出力します。
# ------------------parlous---------------------
# ------------------risky---------------------
# ------------------severe---------------------
# ------------------bad---------------------
# ------------------unsafe---------------------
# parlous
# risky
# severe
# bad
# unsafe
# 検索語: 大分
# 「大分」の上位概念を出力します。
# ------------------considerably---------------------
# ------------------much---------------------
# ------------------a_lot---------------------
# considerably
# much
# a_lot
# 検索語: [UNK]
# 「[UNK]」は存在しない単語です。
# 検索語: 愛知
# 「愛知」は存在しない単語です。
# 検索語: 県
# 「県」の上位概念を出力します。
# ------------------prefecture---------------------
# prefecture
# 検索語: 危険
# 「危険」の上位概念を出力します。
# ------------------parlous---------------------
# ------------------risky---------------------
# ------------------severe---------------------
# ------------------bad---------------------
# ------------------unsafe---------------------
# parlous
# risky
# severe
# bad
# unsafe
# 検索語: 大分
# 「大分」の上位概念を出力します。
# ------------------considerably---------------------
# ------------------much---------------------
# ------------------a_lot---------------------
# considerably
# much
# a_lot
# 検索語: [UNK]
# 「[UNK]」は存在しない単語です。
# 検索語: 愛知
# 「愛知」は存在しない単語です。
# 検索語: 県
# 「県」の上位概念を出力します。
# ------------------prefecture---------------------
# prefecture
# 検索語: 危険
# 「危険」の上位概念を出力します。
# ------------------parlous---------------------
# ------------------risky---------------------
# ------------------severe---------------------
# ------------------bad---------------------
# ------------------unsafe---------------------
# parlous
# risky
# severe
# bad
# unsafe
# 検索語: 大分
# 「大分」の上位概念を出力します。
# ------------------considerably---------------------
# ------------------much---------------------
# ------------------a_lot---------------------
# considerably
# much
# a_lot
# 検索語: [UNK]
# 「[UNK]」は存在しない単語です。
# 検索語: 愛知
# 「愛知」は存在しない単語です。
# 検索語: 県
# 「県」の上位概念を出力します。
# ------------------prefecture---------------------
# prefecture
# 1min 52s ± 2.28 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## 上位概念を一つずつ
# 1min 52s ± 2.28 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
similarity_headlines = []

print(tokens)

for token in tokens:
    print(f'検索語: {token}')
    hypernyms = search_upper_concept_words(token, hierarchy_dict)
    
    # 翻訳
    for hypernym in hypernyms:
        print(f'翻訳前: {hypernym}')
        translated = translator.translate(hypernym, src='en', dest='ja')
        print(f'翻訳後: {translated.text}')
        similarity_headlines += get_all_similarity(headline_list, translated.text)
# Out:
# ['危険', '大分', '[UNK]', '愛知', '県']
# 検索語: 危険
# 「危険」の上位概念を出力します。
# ------------------parlous---------------------
# ------------------risky---------------------
# ------------------severe---------------------
# ------------------bad---------------------
# ------------------unsafe---------------------
# 翻訳前: parlous
# 翻訳後: par par
# C:\Users\naoki\anaconda3\envs\nlp_bot\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in true_divide
# 翻訳前: risky
# 翻訳後: リスキーな
# 翻訳前: severe
# 翻訳後: ひどい
# 翻訳前: bad
# 翻訳後: 悪い
# 翻訳前: unsafe
# 翻訳後: 危険な
# 検索語: 大分
# 「大分」の上位概念を出力します。
# ------------------considerably---------------------
# ------------------much---------------------
# ------------------a_lot---------------------
# 翻訳前: considerably
# 翻訳後: consider
# 翻訳前: much
# 翻訳後: 多くの
# 翻訳前: a_lot
# 翻訳後: 多くの
# 検索語: [UNK]
# 「[UNK]」は存在しない単語です。
# 検索語: 愛知
# 「愛知」は存在しない単語です。
# 検索語: 県
# 「県」の上位概念を出力します。
# ------------------prefecture---------------------
# 翻訳前: prefecture
# 翻訳後: 県

# %%
len(similarity_headlines)
# Out:
# 721

# %%
similarity_headlines
# Out:
# [(('大分合同新聞', '1966年', '10月', '15-a-9_09', '門前払いはひどい'), 0.8642213216316279),
#  (('大分新聞', '1929年', '9月', '19-a-8_01', 'T-FE\n- をひどく好まない、そして,'),
#   0.8521979145699125),
#  (('大分合同新聞',
#    '1963年',
#    '10月',
#    '21-a-1_02',
#    'このひどさ、忘れずに\nMintalinuncilichirunchronrokiminurikawadline'),
#   0.8384749549050137),
#  (('大分合同新聞', '1966年', '9月', '13-a-1_02', '特にひどい中、'), 0.8174514736513242),
#  (('大分合同新聞', '1967年', '9月', '9-a-4_08', 'あまりにひどい荒目不足\n泣き寝入りはそうめん」'),
#   0.8000957494181787),
#  (('大分新聞', '1919年', '4月', '10-a-4_05', '>餘程酷い目\nBotton'), 0.7864407447582961),
#  (('豊州新報', '1936年', '7月', '27-a-7_04', 'パイプ詰めが 一番害がひどい'), 0.7858620175757086),
#  (('大分合同新聞', '1963年', '7月', '14-y-2_02', 'はたけ、に悩み\n薬でかえってひどくな名'),
#   0.7792719989758976),
#  (('大分合同新聞', '1960年', '2月', '23-a-4_04', '「ひどすぎる引き上げ」\nこんどは地獄から苦情'),
#   0.7778415978563747),
#  (('大分合同新聞', '1965年', '7月', '3-a-9_01', 'ひどい!居眠りトラック'), 0.7742249335701976),
#  (('大分合同新聞', '1967年', '2月', '28-y-4_03', '抜け毛がひどい勝一'), 0.7703064855245308),
#  (('大分新聞', '1937年', '11月', '28-y-3_04', '"風邪の錄防\n外出後は手がひど\nーーーーーーーーーー'),
#   0.7678842454144009),
#  (('大分合同新聞', '1956年', '3月', '21-a-3_06', 'あまりにひどい制限, DS患者、病院から苦情'),
#   0.7654795125795368),
#  (('大分新聞', '1938年', '5月', '14-y-2_01', '憎くや,肅選,\n今度はとてもひどい効目\n大分檢番の泣言'),
#   0.7652713051569937),
#  (('大分合同新聞', '1948年', '5月', '13-a-1_14', '御営がひどい\n博落に'), 0.7635048133882757),
#  (('大分新聞', '1927年', '7月', '17-a-9_12', '「カル大の モボ狩り\nひどい連中'),
#   0.7616172013660267),
#  (('大分合同新聞', '1965年', '10月', '8-a-9_07', 'ひどすぎる。\nさん新たな悲しみ、怒n'),
#   0.7613640910429934),
#  (('豊州新報', '1938年', '6月', '23-a-8_03', '入梅中は特に 疲労がひどい\n恢復には何が良いか'),
#   0.7609716220343404),
#  (('大分合同新聞', '1965年', '9月', '15-y-3_01', 'ひどすぎるいたずら」 学校の窓に投石 |'),
#   0.7603060530132737),
#  (('大分合同新聞', '1943年', '4月', '1-y-1_05', 'オロ灣をまた痛爆'), 0.7586532243198318),
#  (('豊州新報', '1939年', '12月', '5-a-3_17', '「痛いの'), 0.7586532243198318),
#  (('大分合同新聞', '1967年', '4月', '12-y-3_05', 'まあひどいことを\n飲呀オチューリップ根こそぎ'),
#   0.7583261428444332),
#  (('大分新聞', '1936年', '9月', '18-y-1_14', 'Xぁ、俺花か?|\nトテモひどい抜け毛でしたが'),
#   0.7518634185364564),
#  (('大分合同新聞', '1960年', '1月', '7-y-2_02', 'ランカは悪くな'), 1.0),
#  (('大分合同新聞', '1959年', '1月', '7-y-4_06', '評判の悪い'), 0.8921548299451866),
#  (('大分合同新聞', '1955年', '5月', '9-a-4_09', '悪い遊びが'), 0.8677709524070982),
#  (('大分合同新聞',
#    '1957年',
#    '10月',
#    '14-y-4_06',
#    'できの悪い表作の\nKumotomisaki Rester.gl/\n7nczbe'),
#   0.8661312188891253),
#  (('大分合同新聞', '1952年', '4月', '3-y-1-2_12', '"のせいに悪いです\nGi|-8)'),
#   0.8576465784361186),
#  (('大分新聞', '1941年', '10月', '14-y-3_07', '悪い齒並び\n馬鹿に出來ぬ影響'),
#   0.8340441564988349),
#  (('豊州新報',
#    '1933年',
#    '5月',
#    '25-a-4_03',
#    'えん彼女す。 鼻ニ聲の三角關係 腦の悪い人は鼻が悪く 鼻の悪い人は聲が悪い'),
#   0.8326026093135547),
#  (('大分合同新聞', '1961年', '6月', '26-a-3_10', 'ー+10%\n悪かった観'), 0.8307292037695924),
#  (('豊州新報', '1929年', '10月', '1-a-7_03', '間違っては 駄目な洋服の手入 手入れの仕方が悪いと\n却って悪くします'),
#   0.8299488965488453),
#  (('大分合同新聞', '1965年', '7月', '7-a-10_02', '太りは悪いが甘\nTRMNh0M'),
#   0.8269506191084389),
#  (('大分合同新聞', '1955年', '5月', '9-a-4_08', '悪い遊びが一 なくなった」'), 0.8238816600660049),
#  (('大分合同新聞', '1957年', '7月', '28-a-1_11', '多すぎて解けない悪'), 0.8235833007850308),
#  (('豊州新報', '1933年', '2月', '19-a-5_02', '戯算お風呂\nいつてよいか悪いか'), 0.82340846464888),
#  (('大分合同新聞', '1958年', '2月', '14-y-2_05', '厚着はかえって悪い\nおフロにも入れましょう'),
#   0.8198390700189049),
#  (('大分新聞', '1934年', '6月', '29-y-3_02', '子供はとかく |映畫が好きです\n見せてよいか悪いか\nAmi'),
#   0.8163841070241759),
#  (('大分合同新聞', '1956年', '9月', '5-y-4_02', '「大変良かった\nOmanners'),
#   0.8160726785081333),
#  (('大分新聞',
#    '1929年',
#    '8月',
#    '20-a-8_01',
#    '行儀の悪い子は 成績もよくない\nそれは不健康から よく運動させるが一番よい'),
#   0.8114529416591404),
#  (('大分新聞', '1925年', '7月', '12-a-4_08', '內心氣味悪く\n思ってるました」\nよくさんつは、'),
#   0.8110200862910957),
#  (('大分合同新聞', '1964年', '5月', '12-a-4_02', '食べ物にも相性 組み合わせが悪いと\ni訪果がなくなります'),
#   0.8095631028441769),
#  (('大分合同新聞', '1955年', '6月', '9-a-3_01', '評判の悪い縣産木'), 0.8072193701029241),
#  (('豊州新報', '1942年', '2月', '9-a-4_03', 'ハードで一番悪いこう I\nHMISTERI SURASTLINK'),
#   0.8070214724690835),
#  (('大分新聞', '1929年', '11月', '14-a-10_03', '「良い酒と 「悪い酒\nその見分け方'),
#   0.8048047413338693),
#  (('大分合同新聞', '1943年', '2月', '19-a-1_04', '「幾ERESSES\nTHIYORK\nまんので悪く'),
#   0.8042069510076788),
#  (('豊州新報', '1931年', '7月', '14-a-7_11', '05\n嫁さの仲悪く 自殺やり損ね'),
#   0.8030680143680644),
#  (('大分新聞', '1952年', '8月', '28-a-2_07', '待遇が大変悪い。'), 0.8021433025100663),
#  (('大分合同新聞', '1967年', '6月', '21-a-8_04', 'みんな雨が悪いの'), 0.7958609522892871),
#  (('大分合同新聞', '1965年', '9月', '9-a-9_06', '落ち着きがなく\n, 成績も概して悪い'),
#   0.7952649937797054),
#  (('大分合同新聞', '1966年', '4月', '23-a-4_04', 'まずムダをなくせ|\n日本の悪いクセだ」'),
#   0.7951157895049138),
#  (('大分合同新聞', '1953年', '9月', '21-y-2_09', '口の悪いガッチリ屋\n嫌われるが重質な'),
#   0.794343672507381),
#  (('大分合同新聞', '1943年', '3月', '29-a-2_08', '良き父母に悪る。\n若意熱血の岩瀬大'),
#   0.7905303860471427),
#  (('大分合同新聞',
#    '1960年',
#    '7月',
#    '7-a-3_08',
#    '貧血にもいろいろ|\n顔色の悪くなる病気|\nいやいやややややや\n14'),
#   0.7866565239920966),
#  (('大分新聞', '1953年', '4月', '16-a-2_08', '悪くなったら思いま\nお前何かの'),
#   0.7846750561305295),
#  (('大分合同新聞', '1957年', '3月', '3-y-2_06', '妻の病気の防ぎ方 肥料をやり過ぎると悪い'),
#   0.7840690023001136),
#  (('大分合同新聞', '1966年', '6月', '27-a-8_02', '態度が悪い\n『高校生がリリン'),
#   0.7836515478166545),
#  (('豊州新報', '1939年', '7月', '9-a-1_14', '氣持の悪かった」 尿中のが ャットきれいに取れました'),
#   0.783593702976219),
#  (('豊州新報',
#    '1929年',
#    '9月',
#    '13-a-7_01',
#    '鼻の悪い子は 成績がよくない\n子供の鼻の病氣に、\nあまりに冷淡な親たち'),
#   0.7831489090428403),
#  (('大分合同新聞', '1961年', '4月', '18-a-4_02', '道路が悪くて困る ・ 狭いうえにデコボコ'),
#   0.7830924998500388),
#  (('大分合同新聞', '1961年', '9月', '22-a-3_02', '知りすぎて悪い影響\nやはり旧すので'),
#   0.7828698939841556),
#  (('大分合同新聞', '1959年', '7月', '20-y-2_04', '小便の近いこども\nかえって悪い。'),
#   0.7805400769633136),
#  (('大分合同新聞', '1963年', '10月', '16-a-4_07', 'withore\n身体に悪いところは\n見過ごされやすい近視'),
#   0.7787580023054133),
#  (('大分新聞', '1930年', '2月', '21-a-10_10', '悪い味噌\nこんなにし'), 0.7772006824126207),
#  (('大分新聞',
#    '1930年',
#    '3月',
#    '12-a-10_08',
#    '鼻の悪い子は なぜ頭が悪いか\n口で呼吸をするから\n方々に故障が起つて來る'),
#   0.7770971526386168),
#  (('大分合同新聞', '1963年', '7月', '17-a-7_07', 'いうことやら。\nが」「いいのは悪くても いたるとはよくない?'),
#   0.7759253259136822),
#  (('豊州新報', '1932年', '12月', '10-a-5_03', '良い酒と悪い酒 「どこで判る?\n素人にも判る方法は、'),
#   0.7754956426985963),
#  (('豊州新報', '1932年', '1月', '31-a-5_02', '映畫が身体に 及ぼす影響 神經性の人には悪い 觀て良い人と悪い人'),
#   0.7744466908893293),
#  (('大分合同新聞', '1961年', '4月', '20-a-8_04', '過敏な体質はご用心\nいいいいいいいいいいいい'),
#   0.7743455424177268),
#  (('大分合同新聞', '1943年', '3月', '14-a-1_12', '上に、悪のはこもっ\n839'),
#   0.7740967944052354),
#  (('豊州新報', '1932年', '9月', '3-a-8_05', '老人に 熟つ湯は悪い 熱のある人には 必ずしも悪くない'),
#   0.7704818208989033),
#  (('大分合同新聞', '1966年', '11月', '22-y-4_05', '多くの病気の原因に |\nがまんは悪い習慣'),
#   0.7697159186946416),
#  (('豊州新報',
#    '1932年',
#    '8月',
#    '26-a-5_01',
#    '暑中休暇中の習慣 良い癖と悪い癖 、いつまでも残るから\nお子様の生活をよく見直'),
#   0.7682913473077104),
#  (('大分合同新聞', '1965年', '10月', '20-a-7_05', '頭と神経の調子が悪く\nいつも苦しんでいる方にきび・'),
#   0.7675670512735314),
#  (('大分合同新聞', '1964年', '11月', '12-a-5_05', '| やはり調子の悪い柏台'), 0.7673282863985651),
#  (('大分合同新聞', '1953年', '8月', '2-a-5_02', '悪い気をおっぱらってやるぞ。\nいばって通る人気の'),
#   0.7667449787620837),
#  (('大分合同新聞', '1963年', '10月', '23-a-1_02', '「意外に悪い稲作収 実がよくはいってない'),
#   0.7647937314926296),
#  (('大分合同新聞', '1967年', '7月', '14-a-4_05', 'いかに\nルの悪\nすい\nyaaom'),
#   0.764769260445804),
#  (('大分合同新聞', '1955年', '5月', '24-y-3_01', 'お行儀の悪い修派生 「騒いで散らし放題 目立つ先生の無監督ぶり'),
#   0.7647602212590754),
#  (('大分新聞',
#    '1922年',
#    '10月',
#    '29-a-4_10',
#    'イカもの商人\n罹るものが悪いのか 騙す奴が良く無のか 一の幹を...。'),
#   0.7646625620599972),
#  (('豊州新報', '1936年', '11月', '26-a-4_12', '酒”なぜ悪い」\n血液が濁り循環が悪くなる'),
#   0.76416371657162),
#  (('大分新聞', '1937年', '2月', '9-y-3_03', 'お茶をのんでる 心配ご無用\n悪くなるとはウソで、'),
#   0.7639337948100794),
#  (('大分合同新聞',
#    '1964年',
#    '2月',
#    '2-a-4_04',
#    '注意 消化の悪いもの\n神経をにぶくします。\nそうでないといっervintmでいいでいいです。'),
#   0.7617763136555981),
#  (('大分合同新聞', '1956年', '8月', '6-a-4_08', '子供を悪い遊びから守ろう'), 0.7615976846825394),
#  (('大分合同新聞', '1956年', '3月', '17-a-1_10', 'うひねっても夢が悪い'), 0.7614551904122172),
#  (('大分合同新聞', '1963年', '6月', '24-y-2_05', '胃が悪くて困る|\n薬を飲んだがよくなれ'),
#   0.7610252142984436),
#  (('大分合同新聞', '1959年', '3月', '21-y-2_04', '悪くてもしからずに\n温かく励ましてやろう'),
#   0.7610166848813469),
#  (('大分新聞', '1941年', '10月', '29-y-3_08', '入り過ぎは悪い 一\n正しい入浴の仕方'),
#   0.7605021805835626),
#  (('豊州新報',
#    '1929年',
#    '3月',
#    '9-a-7_02',
#    '子供をあやまり易い 悪い癖は先づ七つ 一番出來の悪い學科を\nよくのばすことが必'),
#   0.7601951030746554),
#  (('大分合同新聞', '1961年', '10月', '17-a-8_02', '道路の悪いのが悩み'), 0.7600100032084408),
#  (('大分新聞',
#    '1927年',
#    '10月',
#    '29-a-8_05',
#    '鼻が悪くなると 頭悪くなる。 殊に子供は影響が多い 感骨の節は注意が大切'),
#   0.7597755860513802),
#  (('大分新聞',
#    '1932年',
#    '2月',
#    '26-y-3_04',
#    '地成績が悪いとて 小言はやっての外\n小言をやめて成績をよくした話\nHP'),
#   0.7586883293638825),
#  (('大分合同新聞', '1957年', '10月', '21-y-2_02', 'こもり止場で考え 或情や皮肉は一番悪い.......'),
#   0.7585785668558195),
#  (('大分合同新聞', '1960年', '8月', '14-a-3_04', '原因をつかもう\n教え方の悪い場合もある'),
#   0.7578476777619014),
#  (('大分新聞', '1934年', '7月', '18-y-2_15', '頭を出を めった突き 血達磨になり荒廻る\n酒癖悪い別府の'),
#   0.7570129960986733),
#  (('大分新聞', '1953年', '2月', '20-a-2_16', '男で悪い訳はない'), 0.7567455913893935),
#  (('大分新聞', '1941年', '8月', '28-y-3_01', '不良ず狙女性\n断じて態度を崩すね うか、 をつくってるの'),
#   0.7552881278587781),
#  (('大分新聞', '1932年', '6月', '15-y-3_03', 'Formaterから\n汚點の拔き方\nPE」'),
#   0.7551399340940426),
#  (('豊州新報', '1930年', '1月', '14-a-7_05', 'ドビーマット35\nカルタ會は悪い\nやめるやうにしたい'),
#   0.7549859363273483),
#  (('豊州新報', '1940年', '11月', '7-a-5_01', '単に外せる\n不良兄の導き方\n無暗に叱っても駄目'),
#   0.7547391746288541),
#  (('大分新聞', '1939年', '6月', '21-y-2_05', '心配無用。雨が近い」'), 0.7545315875295651),
#  (('大分新聞', '1935年', '4月', '10-a-3_14', 'るこの私の子は | 栄養状態が悪く\nいや、まだ'),
#   0.7544062273807964),
#  (('豊州新報', '1930年', '9月', '16-a-8_07', '歯の汚れと その原因\n掃除は早く、 せいと駄目'),
#   0.7543194086708278),
#  (('豊州新報', '1938年', '4月', '30-a-3_10', '鼻の悪い 人が大喜び'), 0.7536688492359578),
#  (('大分新聞', '1951年', '11月', '8-a-3_07', '風紀が悪く\n夜の女がうるさい'), 0.7534630148405802),
#  (('大分新聞', '1934年', '6月', '14-y-3_06', '出不精は非常 な損'), 0.7533416195002315),
#  (('大分合同新聞', '1965年', '8月', '29-a-3_04', '「ビタールカ先務に\n「ミカンも太りが悪い'),
#   0.753298189395503),
#  (('大分合同新聞', '1957年', '7月', '2-y-2_06', '-頭を悪く "する虫歯'), 0.7530407109138889),
#  (('大分合同新聞', '1963年', '7月', '23-a-7_06', '頭の調子が悪い\nこんな病状の人に'),
#   0.7528242606571746),
#  (('大分合同新聞', '1963年', '9月', '27-a-7_11', '頭の調子悪い |\nこんな病状の人に'),
#   0.7528242606571746),
#  (('大分新聞', '1923年', '3月', '22-a-7_04', '浮かれ易い春先きに一 ・不良少年の悪化」\n檢舉の方法に営局の頭怖'),
#   0.7527656200026296),
#  (('豊州新報',
#    '1932年',
#    '2月',
#    '6-a-5_03',
#    '成績の悪い子供は 病氣をもつてゐる。 頭が悪いとあきらめる前に\n嚴密な健康診断を'),
#   0.7524832781778251),
#  (('大分合同新聞', '1959年', '9月', '12-y-2_02', '午後は空気が悪い\nLithの価値あう'),
#   0.7518076031613801),
#  (('大分新聞', '1924年', '8月', '10-a-6_01', '一の一具の\n良し悪し'), 0.7517811238479782),
#  (('大分新聞', '1918年', '2月', '27-a-4_03', '電悪いので\nBAT'), 0.7510155532336795),
#  (('大分新聞', '1918年', '4月', '27-a-4_03', '電悪いので\nBAT'), 0.7510155532336795),
#  (('豊州新報', '1940年', '1月', '18-a-5_01', '疲方が悪いと 風邪をひく\n隙間風も毒て'),
#   0.7509103603538798),
#  (('大分合同新聞', '1954年', '9月', '5-y-1_09', '危険なササヤキ'), 0.9999999999999998),
#  (('大分合同新聞', '1966年', '1月', '13-a-9_01', '危険な防空ごう'), 0.9999999999999998),
#  (('大分合同新聞', '1966年', '5月', '25-y-2_05', '「なるほど危険だね'), 0.9999999999999998),
#  (('大分合同新聞', '1967年', '5月', '27-y-5_06', 'ここに危険が...。'), 0.8788932046699296),
#  (('大分合同新聞', '1967年', '5月', '26-y-3_06', 'ここに危険が...'), 0.8788932046699296),
#  (('大分合同新聞', '1967年', '5月', '25-y-5_07', 'ここに危険が...'), 0.8788932046699296),
#  (('大分合同新聞', '1967年', '5月', '24-y-3_06', 'ここに危険が...'), 0.8788932046699296),
#  (('大分合同新聞', '1967年', '5月', '29-y-2_03', 'ここに危険が...'), 0.8788932046699296),
#  (('大分合同新聞', '1967年', '5月', '23-y-5_06', 'ここに危険が...'), 0.8788932046699296),
#  (('豊州新報', '1929年', '3月', '23-a-7_10', '危険をか\nを手に'), 0.8666672590896938),
#  (('大分合同新聞', '1963年', '9月', '27-a-1_02', '「危険防止にも全力を。'), 0.8382231931851475),
#  (('大分新聞', '1920年', '2月', '25-a-4_09', '身邊危険\n噂の如く\nther'),
#   0.8186335074824413),
#  (('豊州新報', '1937年', '8月', '22-a-2_08', '青島も危険に當面\n形勢は極めて重大化す'),
#   0.8118033804737076),
#  (('大分新聞', '1922年', '3月', '9-a-7_12', '新發見\n他人ので 危険はない'), 0.8073612935763785),
#  (('大分合同新聞', '1957年', '5月', '31-a-1_14', '危険のないよ う十分に注意'), 0.8065731447259997),
#  (('大分新聞', '1927年', '12月', '1-a-8_08', '手なデに\n添寝は危険\n壓死窒息の恐れがある。\nお母さん達へ御注意」'),
#   0.803945481928333),
#  (('大分新聞', '1924年', '10月', '10-a-4_06', '『危険に瀕す。 逃走ょ」\nもし、\nいつ'),
#   0.8021282903250334),
#  (('豊州新報', '1927年', '1月', '26-a-7_07', '勇敢なる水兵 火災の中に危険を冒し\n人命込みをさ'),
#   0.797400575978602),
#  (('大分合同新聞', '1967年', '4月', '7-a-10_03', '防止サクも役立たず\nヒヤヒャ 大事故の危険'),
#   0.7942811780127746),
#  (('大分合同新聞', '1967年', '7月', '22-a-8_02', 'これが危険花火'), 0.7887986459771833),
#  (('大分新聞', '1932年', '7月', '7-y-2_05', 'ガスタンク 危険防止\n警告する提督'),
#   0.7871591055397182),
#  (('豊州新報', '1935年', '8月', '24-a-4_06', '事現場は 見透し利かず、 非常に危険ヶ所 運轉者は過失致死'),
#   0.7864197564804908),
#  (('大分合同新聞', '1953年', '4月', '4-y-1_01', '世界の危険を除去せ'), 0.7844889701293439),
#  (('大分合同新聞', '1963年', '8月', '15-a-1_12', '危険を証明す。'), 0.7827043328960753),
#  (('大分新聞', '1923年', '7月', '6-a-4_01', '鰻危険迫る\n極力警戒中\nPHONYM.ninan'),
#   0.7826790810031763),
#  (('大分合同新聞', '1945年', '12月', '8-a-3_04', '危険を促進'), 0.7814748538149403),
#  (('大分合同新聞', '1962年', '12月', '14-y-5_05', '「こんなに危険です」\n分鉄 妨害防止にPR映'),
#   0.7762318049182421),
#  (('大分合同新聞', '1960年', '6月', '22-y-3_08', '大雨の危険去るF'), 0.7759136901171831),
#  (('大分合同新聞', '1959年', '1月', '20-y-3_01', 'あちこちに火災危険地帯、'), 0.7740156881508051),
#  (('大分新聞', '1937年', '7月', '15-y-3_02', 'ハイパーラー\n却って危険率が多い\n清潔第一、生物は危険'),
#   0.7715597227592913),
#  (('大分合同新聞', '1967年', '5月', '15-a-8_04', '自転車の事故防げ\n危険な道,から分離して'),
#   0.7705749192498246),
#  (('大分合同新聞', '1943年', '9月', '9-a-1_01', 'まづ方向を見極める\n悪天候に空頼みは危険'),
#   0.7703336324997834),
#  (('大分合同新聞', '1965年', '3月', '16-a-9_04', '注意をきかず惨事に\n嫌粧「すかし掘りは危険'),
#   0.7703318475822791),
#  (('大分新聞', '1953年', '6月', '28-a-2_08', '路上遊戯は危険!'), 0.7683288440466735),
#  (('豊州新報', '1940年', '10月', '8-a-5_02', '危険ですよ」 有毒きのこ\nこれだけの注意'),
#   0.7679531735608215),
#  (('豊州新報', '1937年', '7月', '30-a-3_08', '「準カー。 目に餘る暴戻\n危険に晒される邦人'),
#   0.7673466121199142),
#  (('大分合同新聞', '1966年', '8月', '30-y-4_02', '自己診断かえって危険'), 0.7667785225681302),
#  (('大分合同新聞', '1966年', '5月', '30-a-8_07', 'どん底人生の不満\n常にはらむ爆発の危険」'),
#   0.7657814320321757),
#  (('大分合同新聞', '1966年', '5月', '30-y-3_07', 'どん底人生の不満 常にはらむ爆発の危険'),
#   0.7657814320321757),
#  (('大分合同新聞', '1966年', '8月', '28-a-10_03', '| 危険家屋の'), 0.7652754910446095),
#  (('大分合同新聞', '1966年', '6月', '16-a-7_03', '一危険から身を守る力を'), 0.7648475686177081),
#  (('大分合同新聞', '1964年', '6月', '19-a-10_05', '延焼の危険去る」'), 0.7646896844291393),
#  (('大分合同新聞', '1962年', '6月', '21-y-3_01', '「危険な 睡眠薬決闘'), 0.7645832211897182),
#  (('大分合同新聞', '1962年', '11月', '8-a-8_01', '梶かけ賴()は危険です!'), 0.763930705440384),
#  (('大分合同新聞', '1942年', '6月', '14-a-1_09', 'よ重大危機へ'), 0.7638740161034078),
#  (('大分合同新聞', '1956年', '3月', '18-a-3_04', '危険個所の警戒\n防犯にも万全の備え'),
#   0.7627128244564819),
#  (('大分合同新聞', '1967年', '3月', '23-a-3_01', '「危険な農薬、を追放'), 0.7621125220462488),
#  (('豊州新報', '1939年', '11月', '2-a-5_06', '恐ろしい百日咳 * 注射豫防ても危険\nにインストールです'),
#   0.761335121100414),
#  (('大分合同新聞', '1956年', '3月', '4-y-4_01', '「死の灰の危険地域]'), 0.7610167382549936),
#  (('大分合同新聞', '1943年', '7月', '12-a-3_02', '危険性は感じない\n歩いてるても怪我はする'),
#   0.7604862663163924),
#  (('大分合同新聞', '1965年', '8月', '20-a-9_09', '特異体質者に は危険です'), 0.7601459899185302),
#  (('大分合同新聞', '1964年', '2月', '4-a-3_09', '安易な考えは危険\n大きな問題 すべて今'),
#   0.7582518764056101),
#  (('大分合同新聞', '1956年', '10月', '30-y-1_11', '第二のパレスチ ナ戦争の危険も。'),
#   0.7581308297641969),
#  (('大分新聞',
#    '1927年',
#    '10月',
#    '1-a-8_06',
#    '恐ろしい丹毒 これから罹り易い\n生命の危険率が頗る多い。 發柄の狀態は斯5'),
#   0.7568191391275317),
#  (('大分合同新聞', '1966年', '8月', '9-y-3_04', '命がけの自由」\n徴兵忌避者の危険な'),
#   0.7546953047918372),
#  (('大分合同新聞', '1962年', '7月', '11-y-1_02', '「危険な妙薬パラチオ\nちょっとの油断が命とり、'),
#   0.7537979985991526),
#  (('大分合同新聞', '1960年', '9月', '25-a-10_05', 'あざやかな色は危険\nにおいのひどいのも注意'),
#   0.7527962824372637),
#  (('大分合同新聞', '1959年', '12月', '2-a-4_05', '人工トンネルを作る\n9落石の危険防ぐ'),
#   0.7523365250342227),
#  (('大分合同新聞',
#    '1953年',
#    '8月',
#    '27-y-2_05',
#    '危険な兒童を守れ\n街に積極的保護をの声\nがAISTORY・mamaernmenm'),
#   0.7518739036671634),
#  (('大分合同新聞', '1961年', '10月', '10-a-6_08', '危険個所を パトロール あすからみ切り安全運t'),
#   0.75169521030842),
#  (('大分合同新聞', '1961年', '7月', '10-a-7_07', '危険な花火遊びはやめよう\n県警が事故防止を呼びかけ'),
#   0.7515156363928505),
#  (('大分合同新聞', '1958年', '8月', '19-y-3_01', '私スが主こですか!\n危険な遊びに注意を、 えと断なのでどのケガ'),
#   0.7503959465198118),
#  (('豊州新報', '1937年', '6月', '10-a-2_07', 'に注音の一 危機をはらむ\n重大問題と化す。'),
#   0.7503865898323256),
#  (('大分合同新聞', '1960年', '11月', '24-y-1_02', '多く\nやあ おめでとう'), 1.0000000000000002),
#  (('豊州新報', '1939年', '5月', '25-a-5_03', 'ができ\n多くの'), 0.8704211262541067),
#  (('大分合同新聞', '1954年', '12月', '28-y-2_04', '特に11\n0SPUNKINO\nrows 10'),
#   0.8376201278843647),
#  (('大分合同新聞', '1950年', '10月', '22-y-1_01', 'ほとんど'), 0.8334573437136749),
#  (('大分合同新聞', '1955年', '7月', '31-y-1_07', 'ほとんど廢案'), 0.8334573437136749),
#  (('大分合同新聞', '1966年', '2月', '9-a-8_04', 'ほとんどが'), 0.8334573437136749),
#  (('大分合同新聞', '1959年', '4月', '25-y-4_05', '就者户”多'), 0.8328993984306697),
#  (('大分新聞', '1925年', '2月', '15-a-2_09', '多。'), 0.8328993984306697),
#  (('大分合同新聞', '1962年', '4月', '11-a-2_08', '再び買い気が台頭」\n全般 なお安いものが多い'),
#   0.830697271796015),
#  (('大分合同新聞', '1959年', '10月', '30-y-1_06', '事ばかり多くの本が出ている。'),
#   0.8177104693978826),
#  (('大分合同新聞', '1959年', '5月', '29-a-6_01', '多くの人が困っている'), 0.8164147975845165),
#  (('大分合同新聞', '1964年', '8月', '31-a-2_09', 'は多いが強くはない。'), 0.8134749135231228),
#  (('大分合同新聞', '1960年', '4月', '27-y-3_09', 'のな\n多くて'), 0.8090697148525876),
#  (('大分合同新聞', '1965年', '6月', '28-y-4_03', '多くなった女性の'), 0.808769912448037),
#  (('大分合同新聞', '1951年', '1月', '28-a-1_03', '多くを期待するな\n日本へ與える言葉'),
#   0.8040377224535191),
#  (('大分合同新聞', '1958年', '6月', '19-y-2_03', '利用者の大半が青年\n最も多いのは小説類'),
#   0.7985063573630866),
#  (('大分新聞', '1920年', '4月', '11-a-2_04', '九年度征豫算內容\n特に注目すべき點'),
#   0.7984685266274016),
#  (('大分合同新聞', '1966年', '11月', '5-a-5_05', 'スムカット\n最も少ない'), 0.797762353410693),
#  (('大分合同新聞', '1951年', '5月', '10-y-2_07', '-縣は影響少ない'), 0.7941256408122598),
#  (('大分合同新聞', '1957年', '6月', '23-y-6_01', '多くの人を助けた'), 0.7902135334492579),
#  (('大分新聞', '1929年', '2月', '2-a-3_05', 'これにて以上の多り\n思想問題'), 0.7899985761604958),
#  (('大分合同新聞',
#    '1966年',
#    '10月',
#    '11-a-3_04',
#    'かなり積極的になる\n問題点はまだ多いが 企業の言語\nければならとの温かさ ているの苦しみの日'),
#   0.7891786102702344),
#  (('大分新聞',
#    '1924年',
#    '8月',
#    '15-a-7_03',
#    '大分縣の衛生狀態 今年は極めて不穩\n全國的に多い腸チフスも * 例年に比べて多くはない\n然し益後が最も危険な時季'),
#   0.7881779629498906),
#  (('豊州新報',
#    '1940年',
#    '2月',
#    '12-a-2_02',
#    '優遇對策を目に 依然 教員の不足\n殷賑產業への流入止まず\n*イで各所に設者の多い一角な体かしてとたって'),
#   0.787884381791025),
#  (('大分合同新聞', '1959年', '12月', '3-a-2_09', 'NE\nさらに一方で、そのほかも'),
#   0.7861870394351015),
#  (('大分合同新聞', '1967年', '7月', '22-a-7_03', 'やはり多い。中心部、\n悩みは少ない遊び時間'),
#   0.7828622550469465),
#  (('大分合同新聞', '1965年', '4月', '13-y-1_03', '年々盛んになるが...\n響なお半数近くがゼロ'),
#   0.782067243351326),
#  (('大分合同新聞', '1959年', '2月', '25-y-1_01', '各地で職場大会\n影響はほとんどない'),
#   0.7820639017883002),
#  (('豊州新報', '1937年', '1月', '30-a-4_14', '新しい手當法」 最近特に好評のある」 ー黄コロイド・マッサー:'),
#   0.7795685716802813),
#  (('大分合同新聞', '1966年', '3月', '1-y-6_02', 'これらに'), 0.7794333367815173),
#  (('豊州新報',
#    '1930年',
#    '6月',
#    '15-a-3_01',
#    '増加して行く\n映画說明志願者\nトーキーに脅かされる反面 注目を惹く此の傾向'),
#   0.7789419014141183),
#  (('大分合同新聞', '1964年', '8月', '16-a-2_01', '「農村にとくに多い 自活できるのは33,'),
#   0.778763457169682),
#  (('大分合同新聞', '1954年', '4月', '29-a-4_05', 'm2といって\n今年は非常に多い'),
#   0.7787566249567028),
#  (('大分合同新聞', '1958年', '3月', '23-a-3_03', '実質あまり変らぬ\n前途になお多くの困難'),
#   0.7786216044241242),
#  (('大分合同新聞', '1961年', '7月', '13-y-2_02', '数多くの刺激材料'), 0.778479921879963),
#  (('大分合同新聞', '1963年', '1月', '28-y-2_05', '上并不多'), 0.7775872184019254),
#  (('大分合同新聞', '1962年', '3月', '30-y-4_01', '種類は比較的少ない\n時期によっては大被害に'),
#   0.7775712925352348),
#  (('大分新聞', '1928年', '12月', '15-a-8_02', '最近に於ける。 婚人雜誌の傾向\n最も多いのは戀愛 結婚等に關する物'),
#   0.7769222362053668),
#  (('大分合同新聞', '1950年', '10月', '14-y-1_05', '各界へ明るい響き\n豫想外多く早い決定'),
#   0.7768692111482415),
#  (('大分合同新聞', '1942年', '6月', '23-y-2_11', '多い、映像のBの部へられる\n多い。勇氣、\nそれに見らず。'),
#   0.7758221520828871),
#  (('大分合同新聞', '1959年', '6月', '12-a-5_06', '最も悪質で恐ろしい\n大半が経験の浅い台'),
#   0.7738788488422785),
#  (('大分合同新聞', '1944年', '3月', '2-y-2_05', '私達も戦場へ\n一方の多くは'), 0.7737840366902001),
#  (('大分合同新聞', '1960年', '7月', '27-a-7_02', 'ほとんどカナヅチ\nTHれの用意いた!'),
#   0.7731269170775062),
#  (('大分新聞', '1931年', '7月', '2-a-8_01', '為にも色々あ るが一番多いの は胃酸過多症」'),
#   0.7729047896933051),
#  (('大分新聞',
#    '1918年',
#    '3月',
#    '9-a-7_01',
#    '●結婚の多い昨今\n◇殊に本年は例年よりも\n地の中の良いためか ます。また、\nうや戦のときである、が困'),
#   0.7725937063874551),
#  (('大分合同新聞', '1966年', '9月', '13-a-1_02', '特にひどい中、'), 0.7724924207739723),
#  (('大分合同新聞', '1945年', '12月', '28-a-2_11', '多くの支持が得られ'), 0.7712054789963987),
#  (('大分合同新聞', '1967年', '4月', '7-a-3_01', '商店どんどん大型化 「50人以上が激増\nしてくれました 古いて'),
#   0.7710375241811521),
#  (('豊州新報', '1932年', '8月', '14-a-8_05', 'ヴィタミンA・Dは何に一体 最も多く含有されて居るか?'),
#   0.7710302836700297),
#  (('大分新聞', '1951年', '5月', '4-a-3_08', 'これは珍しい。\nmine'), 0.7708491552908631),
#  (('大分新聞', '1951年', '5月', '7-a-2_10', '「これは珍しい?\nではでは'), 0.7708491552908631),
#  (('大分合同新聞', '1967年', '6月', '29-y-2_04', '出ているが、花序中心見が多い。\n続けてます.他'),
#   0.7707392369839515),
#  (('大分合同新聞', '1954年', '9月', '13-y-2_02', 'よく相談して出\n婦人が集る機会を多く'),
#   0.7705221244319899),
#  (('大分合同新聞', '1956年', '2月', '2-a-2_01', '自作地の手放し増加 中以下の農家に目立つ'),
#   0.7704302633917336),
#  (('豊州新報',
#    '1933年',
#    '4月',
#    '23-a-1_12',
#    'れず、大いに着目し、近く、 さくすることにならぬ。 これは決してではない。'),
#   0.7689431482223026),
#  (('大分合同新聞', '1962年', '9月', '4-y-1_03', '「少数で高い生産性 ■薄い地元との結びつき'),
#   0.7683352773501351),
#  (('大分新聞', '1924年', '12月', '12-a-4_09', '目の廻る多忙さ|\n激増したタオルの需要\n然し未だ移入品が却々多い'),
#   0.7674603724834115),
#  (('豊州新報', '1928年', '10月', '17-a-3_15', '警戒すべき秋 發病率最も多く\n死亡率又最も多き Jan'),
#   0.7672632097414744),
#  (('大分合同新聞', '1950年', '12月', '28-y-2_05', '若いほど多い\nさすが少ない。安全週間'),
#   0.7672140494157527),
#  (('大分合同新聞', '1966年', '9月', '10-y-2_04', '別大勢の若さを誇る。'), 0.7668601973030773),
#  (('大分合同新聞',
#    '1953年',
#    '11月',
#    '23-a-2_11',
#    'ルーンドプレーが多くなるだろうし\n国が高くなるだろう。 一週数でも不安定'),
#   0.7652198395130699),
#  (('豊州新報', '1930年', '2月', '7-a-5_02', '小避送を通じ\n農產物配給\n改善さへすれば 有利な傾向が多い\nこっち。'),
#   0.7646745876511477),
#  (('大分新聞', '1929年', '2月', '20-a-7_06', '八坂榊肛新年祭\n參詣者多く大いに賑ん'),
#   0.7643823843858377),
#  (('大分合同新聞', '1962年', '6月', '8-y-3_03', '評判のよい中高年層\n一方市の上品される'),
#   0.7638950744804697),
#  (('大分合同新聞',
#    '1965年',
#    '2月',
#    '15-a-5_02',
#    '" のない若い人をひきつけるため\n「これはデーベートーベリス ・ いる ! -POP スリート、 年間というのに」'),
#   0.7636754416028989),
#  (('豊州新報',
#    '1929年',
#    '6月',
#    '12-a-4_05',
#    '西瓜の増産計畫 新しい經濟的利用\n奈良漬にすれば利益が多い\n最近非常に注目さる'),
#   0.7636479283669472),
#  (('大分合同新聞', '1967年', '6月', '15-y-2_05', '安い、強いされ\n新しいカワロ'),
#   0.7635813440487971),
#  (('大分合同新聞', '1958年', '10月', '23-a-3_06', 'ほとんどがなお各界で活躍'), 0.7634262253196475),
#  (('大分合同新聞', '1962年', '12月', '28-a-6_03', '求人の多い中、高新卒\n中高齢層は減る一方'),
#   0.7629091984687282),
#  (('豊州新報', '1929年', '3月', '7-a-4_12', '『盛んな音樂會」\n何れも良い出來榮え |一般遮衆名多く堂に濡つー'),
#   0.762296897307696),
#  (('豊州新報',
#    '1932年',
#    '7月',
#    '31-a-4_03',
#    'どんな職業にも美貌が 有利である疑問? 女性の完全な經濟的獨立迄には まだ多くの幅がある'),
#   0.761333594697728),
#  (('豊州新報', '1929年', '6月', '15-a-3_05', '特に強調す'), 0.761025461068158),
#  (('大分合同新聞', '1964年', '8月', '9-a-7_02', 'これからが多い\nTHINTERITEINE\nBITIMEmaman'),
#   0.7608941535507714),
#  (('大分合同新聞', '1965年', '4月', '14-a-7_02', 'ハシカ | これからが多い」'),
#   0.7608941535507714),
#  (('大分合同新聞', '1964年', '10月', '18-a-2_01', 'あまり重視していない'), 0.7608320132783977),
#  (('大分新聞', '1926年', '4月', '1-a-3_01', '進展せぬ\n重要問題が多くて'), 0.7607076065356556),
#  (('大分合同新聞', '1949年', '4月', '12-a-2_10', '近來ない多 数の積残し'), 0.7606695193108253),
#  (('豊州新報', '1938年', '6月', '8-a-3_05', 'あるからむしろ日本の思 に ひこれ以上用 な記載を出す。あと'),
#   0.7605424442852439),
#  (('大分合同新聞', '1951年', '7月', '23-y-1_02', '前途に多くの難關'), 0.7604991665013577),
#  (('大分新聞', '1935年', '1月', '15-y-2_09', '近年ない活況|\n好景氣時代以來初めて'),
#   0.7604576872224214),
#  (('大分合同新聞',
#    '1964年',
#    '11月',
#    '18-a-6_01',
#    'いる。とくにのさいにはこのが最も多いの よりも、おとなくそれに自動車をする人の合意が必、\n(写真はで'),
#   0.759511407934014),
#  (('豊州新報', '1929年', '11月', '12-a-7_04', 'Lるの 何より悪い\nこれから多くなる 婦人特有の病氣\nこちらこちら'),
#   0.7594862260037228),
#  (('大分合同新聞', '1957年', '8月', '31-y-2_12', 'これられました'), 0.7591086552766689),
#  (('大分合同新聞', '1963年', '9月', '24-a-3_12', 'これられますが・・・'), 0.7591086552766689),
#  (('豊州新報', '1932年', '1月', '21-a-8_04', 'いささかのぼのえかな。 町中にある増えざるる'),
#   0.7590523384661836),
#  (('大分合同新聞', '1953年', '12月', '4-a-2_05', '注目される個々の力\nFWは日本ても一部'),
#   0.7579911292464657),
#  (('豊州新報', '1938年', '1月', '29-a-5_04', '今ごろは一番 便秘の多い時季\n軽視しては大變で'),
#   0.7578460452182273),
#  (('大分新聞',
#    '1929年',
#    '8月',
#    '6-a-8_05',
#    '子供の怪我は 朝の間に多い\n特に低學年兒童に多い\n一番のおさるのはいるのを'),
#   0.7576757363326518),
#  (('豊州新報', '1932年', '10月', '27-a-2_15', '他と比較して 遜色はない 名物中津の絹織物 然し生產品は激減'),
#   0.7575426947800566),
#  (('大分合同新聞',
#    '1960年',
#    '4月',
#    '26-y-1_02',
#    '|肺ジストマ\nと間違えられやすく、そのため の出が少なくない。まだ全県的に'),
#   0.7574474897837276),
#  (('豊州新報',
#    '1929年',
#    '10月',
#    '17-a-2_01',
#    '失業者に 殖れる一方 數字が雄辯に物語る 事業界萎靡沈装の姿\nはいくつか'),
#   0.7573553050647241),
#  (('大分合同新聞', '1957年', '3月', '5-y-4_01', '高まる教育テレビ熱 各社の名乗りも活発 だが多くの問題を残す'),
#   0.757347001274603),
#  (('大分合同新聞', '1967年', '4月', '7-a-8_06', 'ほとんどその日暮らし\n一方的に消費者へ?'),
#   0.7572672469534588),
#  (('豊州新報', '1941年', '5月', '18-a-5_04', '青壮年者に多い 胃酸過多症の手法'),
#   0.7571142622358772),
#  (('豊州新報', '1930年', '6月', '21-a-3_03', 'さうさせたか?」 資金難か人氣衰退か 斯界の興味深い問題'),
#   0.7569995980234302),
#  (('大分合同新聞', '1954年', '2月', '15-y-3_05', 'お得意は零細業者\nポコゲッキも多くなる'),
#   0.7569008088330789),
#  (('大分新聞', '1941年', '8月', '22-a-3_09', '依然不必要が多い。\n購雛遊興旅行が筆頭'),
#   0.7568609216422888),
#  (('大分合同新聞', '1956年', '5月', '29-a-3_05', '高い絶えぬ不平 一般に昨年よりは安いが'),
#   0.7566235303970279),
#  (('大分合同新聞', '1960年', '11月', '6-a-5_02', '優劣の差少なくなる\n参加者も毎年ふえる。'),
#   0.756578112888423),
#  (('大分合同新聞', '1958年', '10月', '29-y-2_05', '家族内伝染が多い\n特に母親は注意しよ'),
#   0.7564781081925148),
#  (('大分合同新聞', '1955年', '1月', '16-y-4_05', '脫落者も多く出る。\n激しい農場の修練'),
#   0.755935000802995),
#  (('大分合同新聞', '1957年', '5月', '23-y-4_05', 'W海外5話題多'), 0.7558558145097907),
#  (('大分合同新聞', '1957年', '6月', '7-a-3_01', '圧倒的に多い貯えと\nすっかだよ'),
#   0.7550067699972456),
#  (('大分新聞', '1921年', '12月', '1-a-3_07', '最近の商品產地況\n最も注目すべき現象は 金地さ戦前のルーい!'),
#   0.7547393736659719),
#  (('大分合同新聞',
#    '1953年',
#    '6月',
#    '29-a-4_05',
#    'いてある。写真は本来の自\n中に選び込まれたおびただしい! スズの\nイの時'),
#   0.7545190863317829),
#  (('大分合同新聞', '1957年', '9月', '13-a-1_04', '高さになお問題'), 0.7544856147608467),
#  (('大分新聞',
#    '1929年',
#    '1月',
#    '25-a-8_02',
#    '最も注意すべき 求職者の心得 如何にすれば目的を 達する事が出來るが\nまれていますw'),
#   0.754409221065571),
#  (('大分合同新聞',
#    '1959年',
#    '12月',
#    '20-a-6_01',
#    '中のなにより 多大の業 口を集め、多数 の有望な新人を 点んだこととい 下の子すみま FXに対する。\nていい。 意欲的な 強化策\n次に内最 男の\nあっせんに る花がなさ れたこと、それ !」ともなうし い校とが よいちえ たとも言い またベテラン 『Mもこ れらにされ て管に もやし、自然に\n、みごとな新人の台頭'),
#   0.7543808194760957),
#  (('大分新聞', '1941年', '10月', '12-y-4_05', '苗木不足の場合 特に重要\nインHDンター'),
#   0.754316157773088),
#  (('豊州新報',
#    '1930年',
#    '2月',
#    '13-a-7_03',
#    '最近利用者の 殖んた無盡の融通 それだけモグリの活躍も盛ん\n加入する方へ御注意\n・ ギ\nャラリー'),
#   0.7542855876185554),
#  (('大分合同新聞',
#    '1952年',
#    '2月',
#    '22-y-2-3_04',
#    '多い定貯の引出し\n_111、深\nさに\nTESHIされ151hahrashinmenirint itename'),
#   0.7541936754328973),
#  (('大分新聞', '1919年', '7月', '15-a-7_04', 'または\nおらん\n近く質時される 他せたらしい'),
#   0.7541893161725727),
#  (('大分合同新聞', '1959年', '10月', '19-a-1_04', '将来性は十分ある\n人気集まった竹製品'),
#   0.754145905578797),
#  (('大分合同新聞', '1959年', '2月', '4-y-1_04', '簡單にできようか? ブームの陰に不安も多い'),
#   0.7537925750619529),
#  (('豊州新報', '1937年', '5月', '17-a-7_04', '名前は多いが、 種類は只一つ'), 0.7537210861306425),
#  (('大分合同新聞',
#    '1962年',
#    '10月',
#    '11-a-5_01',
#    '全般に非常に高いレベル\n一つのテーマを徹底的に\nE:¥5,44石二人の'),
#   0.7536150751367345),
#  (('大分新聞', '1918年', '10月', '23-a-4_06', 'て必要品皆な高し\n◇安い物は一つもない\nやっすw'),
#   0.7534781024161665),
#  (('大分新聞',
#    '1928年',
#    '11月',
#    '1-a-8_06',
#    'ニートを含む 昆布はクスリー\nロイマチス、腺病質者 には殊に効果が多い。'),
#   0.7534106527833773),
#  (('豊州新報', '1929年', '1月', '18-a-3_08', '帆船の活躍\n最近利用者が多く 演いる目遣しくなる'),
#   0.7533134475580079),
#  (('大分新聞', '1926年', '12月', '18-a-4_11', 'さらに当ては\nよく具体的準愉'),
#   0.7533093919568563),
#  (('大分新聞', '1924年', '7月', '16-a-7_10', '雨の少ない事はない\n過去數年間との比較 ネージャーにより、 、 、 。'),
#   0.7530532700473705),
#  (('大分合同新聞',
#    '1952年',
#    '2月',
#    '27-a-2-2_03',
#    '母子援護に多くの問題 定職なしが約半数\nらっきされたシャインブラック/Weeさんいます。'),
#   0.7529367653944493),
#  (('大分合同新聞', '1966年', '7月', '14-y-6_05', '数字好き が多い ものおじせずにはっきり質問\n手軽に解答望む傾向。'),
#   0.7528108177477757),
#  (('大分新聞', '1922年', '4月', '23-a-5_01', '各地春竄狀況\n一般に減少の傾向'), 0.752709402093036),
#  (('大分新聞',
#    '1937年',
#    '10月',
#    '8-y-3_01',
#    '不急品の輸入が 禁止されました\n日常生活に關係深いものが\n多々あります'),
#   0.7526635136970713),
#  (('大分新聞', '1934年', '12月', '28-a-2_01', '近年ない歲晩景氣\n久方ぶりの活況'),
#   0.7523991032285362),
#  (('大分合同新聞', '1962年', '1月', '16-a-3_05', '大切なかれらの働き\n狩猟法にも多くの欠点'),
#   0.7522463787842917),
#  (('豊州新報', '1934年', '12月', '11-a-7_05', 'お取越し\n多詣者多く賑'), 0.7518472295744811),
#  (('大分合同新聞', '1967年', '12月', '7-a-4_05', '大半が九州のお客\n若い女性グルーブが多い'),
#   0.7517225420547999),
#  (('大分合同新聞', '1960年', '1月', '28-y-3_02', '出やや多い程度'), 0.7516889453081584),
#  (('大分合同新聞', '1959年', '5月', '15-a-5_04', 'ほとんど泣寝入り)\n補償があっても涙金程度'),
#   0.7516724813925323),
#  (('豊州新報', '1928年', '11月', '7-a-2_03', '御警術には 細心の注意\n一般市民も緊張して\n事故は極めて少ない'),
#   0.7516628932731123),
#  (('大分新聞', '1935年', '12月', '19-y-2_04', '多い。 大して影響なし。\n縣農園の話'),
#   0.7515019093200459),
#  (('大分新聞', '1923年', '7月', '26-a-4_06', '増え、\n以來の大賑い 毎夜、近郷近在から\n人出多く、非常な顔ざ上'),
#   0.751017432819642),
#  (('大分合同新聞',
#    '1961年',
#    '11月',
#    '8-a-3_02',
#    '年々充実する県美風\nOMIURISHIIIIIMITHINRIRIMIMIMINIIIIIIMMIINAIRIMO\n地方には珍しい質の高さ・'),
#   0.7506278166440085),
#  (('大分合同新聞',
#    '1958年',
#    '4月',
#    '28-a-1_02',
#    '定賃金には問題がある。\n一名「全国の述を第で多えられているよ\nTOWNの1000048WOE\nHISPELIT'),
#   0.7506031078542852),
#  (('豊州新報', '1929年', '9月', '26-a-9_14', '山縣稅滞納の\n最も多い\nー用'), 0.750601557891184),
#  (('大分合同新聞', '1946年', '4月', '18-a-3_07', 'なかなかいいまっさー!\n形式違反が多い'),
#   0.7505239560981688),
#  (('大分合同新聞', '1944年', '5月', '24-a-3_04', '今後の宮廷りはよくなる\n, 爆下各地に緩々流れる鮮'),
#   0.7504074305188687),
#  (('大分新聞', '1927年', '8月', '13-a-8_03', '| 黒糖から販薬る。 場合が最も\n多いのです'),
#   0.7502759381450481),
#  (('大分合同新聞',
#    '1967年',
#    '12月',
#    '7-a-7_07',
#    'ハラエティーに富んだ洋画\n望まれる底辺の拡大ー\n日本画は数は少ないが意欲的'),
#   0.7500999384067919),
#  (('大分合同新聞', '1960年', '11月', '24-y-1_02', '多く\nやあ おめでとう'), 1.0000000000000002),
#  (('豊州新報', '1939年', '5月', '25-a-5_03', 'ができ\n多くの'), 0.8704211262541067),
#  (('大分合同新聞', '1954年', '12月', '28-y-2_04', '特に11\n0SPUNKINO\nrows 10'),
#   0.8376201278843647),
#  (('大分合同新聞', '1950年', '10月', '22-y-1_01', 'ほとんど'), 0.8334573437136749),
#  (('大分合同新聞', '1955年', '7月', '31-y-1_07', 'ほとんど廢案'), 0.8334573437136749),
#  (('大分合同新聞', '1966年', '2月', '9-a-8_04', 'ほとんどが'), 0.8334573437136749),
#  (('大分合同新聞', '1959年', '4月', '25-y-4_05', '就者户”多'), 0.8328993984306697),
#  (('大分新聞', '1925年', '2月', '15-a-2_09', '多。'), 0.8328993984306697),
#  (('大分合同新聞', '1962年', '4月', '11-a-2_08', '再び買い気が台頭」\n全般 なお安いものが多い'),
#   0.830697271796015),
#  (('大分合同新聞', '1959年', '10月', '30-y-1_06', '事ばかり多くの本が出ている。'),
#   0.8177104693978826),
#  (('大分合同新聞', '1959年', '5月', '29-a-6_01', '多くの人が困っている'), 0.8164147975845165),
#  (('大分合同新聞', '1964年', '8月', '31-a-2_09', 'は多いが強くはない。'), 0.8134749135231228),
#  (('大分合同新聞', '1960年', '4月', '27-y-3_09', 'のな\n多くて'), 0.8090697148525876),
#  (('大分合同新聞', '1965年', '6月', '28-y-4_03', '多くなった女性の'), 0.808769912448037),
#  (('大分合同新聞', '1951年', '1月', '28-a-1_03', '多くを期待するな\n日本へ與える言葉'),
#   0.8040377224535191),
#  (('大分合同新聞', '1958年', '6月', '19-y-2_03', '利用者の大半が青年\n最も多いのは小説類'),
#   0.7985063573630866),
#  (('大分新聞', '1920年', '4月', '11-a-2_04', '九年度征豫算內容\n特に注目すべき點'),
#   0.7984685266274016),
#  (('大分合同新聞', '1966年', '11月', '5-a-5_05', 'スムカット\n最も少ない'), 0.797762353410693),
#  (('大分合同新聞', '1951年', '5月', '10-y-2_07', '-縣は影響少ない'), 0.7941256408122598),
#  (('大分合同新聞', '1957年', '6月', '23-y-6_01', '多くの人を助けた'), 0.7902135334492579),
#  (('大分新聞', '1929年', '2月', '2-a-3_05', 'これにて以上の多り\n思想問題'), 0.7899985761604958),
#  (('大分合同新聞',
#    '1966年',
#    '10月',
#    '11-a-3_04',
#    'かなり積極的になる\n問題点はまだ多いが 企業の言語\nければならとの温かさ ているの苦しみの日'),
#   0.7891786102702344),
#  (('大分新聞',
#    '1924年',
#    '8月',
#    '15-a-7_03',
#    '大分縣の衛生狀態 今年は極めて不穩\n全國的に多い腸チフスも * 例年に比べて多くはない\n然し益後が最も危険な時季'),
#   0.7881779629498906),
#  (('豊州新報',
#    '1940年',
#    '2月',
#    '12-a-2_02',
#    '優遇對策を目に 依然 教員の不足\n殷賑產業への流入止まず\n*イで各所に設者の多い一角な体かしてとたって'),
#   0.787884381791025),
#  (('大分合同新聞', '1959年', '12月', '3-a-2_09', 'NE\nさらに一方で、そのほかも'),
#   0.7861870394351015),
#  (('大分合同新聞', '1967年', '7月', '22-a-7_03', 'やはり多い。中心部、\n悩みは少ない遊び時間'),
#   0.7828622550469465),
#  (('大分合同新聞', '1965年', '4月', '13-y-1_03', '年々盛んになるが...\n響なお半数近くがゼロ'),
#   0.782067243351326),
#  (('大分合同新聞', '1959年', '2月', '25-y-1_01', '各地で職場大会\n影響はほとんどない'),
#   0.7820639017883002),
#  (('豊州新報', '1937年', '1月', '30-a-4_14', '新しい手當法」 最近特に好評のある」 ー黄コロイド・マッサー:'),
#   0.7795685716802813),
#  (('大分合同新聞', '1966年', '3月', '1-y-6_02', 'これらに'), 0.7794333367815173),
#  (('豊州新報',
#    '1930年',
#    '6月',
#    '15-a-3_01',
#    '増加して行く\n映画說明志願者\nトーキーに脅かされる反面 注目を惹く此の傾向'),
#   0.7789419014141183),
#  (('大分合同新聞', '1964年', '8月', '16-a-2_01', '「農村にとくに多い 自活できるのは33,'),
#   0.778763457169682),
#  (('大分合同新聞', '1954年', '4月', '29-a-4_05', 'm2といって\n今年は非常に多い'),
#   0.7787566249567028),
#  (('大分合同新聞', '1958年', '3月', '23-a-3_03', '実質あまり変らぬ\n前途になお多くの困難'),
#   0.7786216044241242),
#  (('大分合同新聞', '1961年', '7月', '13-y-2_02', '数多くの刺激材料'), 0.778479921879963),
#  (('大分合同新聞', '1963年', '1月', '28-y-2_05', '上并不多'), 0.7775872184019254),
#  (('大分合同新聞', '1962年', '3月', '30-y-4_01', '種類は比較的少ない\n時期によっては大被害に'),
#   0.7775712925352348),
#  (('大分新聞', '1928年', '12月', '15-a-8_02', '最近に於ける。 婚人雜誌の傾向\n最も多いのは戀愛 結婚等に關する物'),
#   0.7769222362053668),
#  (('大分合同新聞', '1950年', '10月', '14-y-1_05', '各界へ明るい響き\n豫想外多く早い決定'),
#   0.7768692111482415),
#  (('大分合同新聞', '1942年', '6月', '23-y-2_11', '多い、映像のBの部へられる\n多い。勇氣、\nそれに見らず。'),
#   0.7758221520828871),
#  (('大分合同新聞', '1959年', '6月', '12-a-5_06', '最も悪質で恐ろしい\n大半が経験の浅い台'),
#   0.7738788488422785),
#  (('大分合同新聞', '1944年', '3月', '2-y-2_05', '私達も戦場へ\n一方の多くは'), 0.7737840366902001),
#  (('大分合同新聞', '1960年', '7月', '27-a-7_02', 'ほとんどカナヅチ\nTHれの用意いた!'),
#   0.7731269170775062),
#  (('大分新聞', '1931年', '7月', '2-a-8_01', '為にも色々あ るが一番多いの は胃酸過多症」'),
#   0.7729047896933051),
#  (('大分新聞',
#    '1918年',
#    '3月',
#    '9-a-7_01',
#    '●結婚の多い昨今\n◇殊に本年は例年よりも\n地の中の良いためか ます。また、\nうや戦のときである、が困'),
#   0.7725937063874551),
#  (('大分合同新聞', '1966年', '9月', '13-a-1_02', '特にひどい中、'), 0.7724924207739723),
#  (('大分合同新聞', '1945年', '12月', '28-a-2_11', '多くの支持が得られ'), 0.7712054789963987),
#  (('大分合同新聞', '1967年', '4月', '7-a-3_01', '商店どんどん大型化 「50人以上が激増\nしてくれました 古いて'),
#   0.7710375241811521),
#  (('豊州新報', '1932年', '8月', '14-a-8_05', 'ヴィタミンA・Dは何に一体 最も多く含有されて居るか?'),
#   0.7710302836700297),
#  (('大分新聞', '1951年', '5月', '4-a-3_08', 'これは珍しい。\nmine'), 0.7708491552908631),
#  (('大分新聞', '1951年', '5月', '7-a-2_10', '「これは珍しい?\nではでは'), 0.7708491552908631),
#  (('大分合同新聞', '1967年', '6月', '29-y-2_04', '出ているが、花序中心見が多い。\n続けてます.他'),
#   0.7707392369839515),
#  (('大分合同新聞', '1954年', '9月', '13-y-2_02', 'よく相談して出\n婦人が集る機会を多く'),
#   0.7705221244319899),
#  (('大分合同新聞', '1956年', '2月', '2-a-2_01', '自作地の手放し増加 中以下の農家に目立つ'),
#   0.7704302633917336),
#  (('豊州新報',
#    '1933年',
#    '4月',
#    '23-a-1_12',
#    'れず、大いに着目し、近く、 さくすることにならぬ。 これは決してではない。'),
#   0.7689431482223026),
#  (('大分合同新聞', '1962年', '9月', '4-y-1_03', '「少数で高い生産性 ■薄い地元との結びつき'),
#   0.7683352773501351),
#  (('大分新聞', '1924年', '12月', '12-a-4_09', '目の廻る多忙さ|\n激増したタオルの需要\n然し未だ移入品が却々多い'),
#   0.7674603724834115),
#  (('豊州新報', '1928年', '10月', '17-a-3_15', '警戒すべき秋 發病率最も多く\n死亡率又最も多き Jan'),
#   0.7672632097414744),
#  (('大分合同新聞', '1950年', '12月', '28-y-2_05', '若いほど多い\nさすが少ない。安全週間'),
#   0.7672140494157527),
#  (('大分合同新聞', '1966年', '9月', '10-y-2_04', '別大勢の若さを誇る。'), 0.7668601973030773),
#  (('大分合同新聞',
#    '1953年',
#    '11月',
#    '23-a-2_11',
#    'ルーンドプレーが多くなるだろうし\n国が高くなるだろう。 一週数でも不安定'),
#   0.7652198395130699),
#  (('豊州新報', '1930年', '2月', '7-a-5_02', '小避送を通じ\n農產物配給\n改善さへすれば 有利な傾向が多い\nこっち。'),
#   0.7646745876511477),
#  (('大分新聞', '1929年', '2月', '20-a-7_06', '八坂榊肛新年祭\n參詣者多く大いに賑ん'),
#   0.7643823843858377),
#  (('大分合同新聞', '1962年', '6月', '8-y-3_03', '評判のよい中高年層\n一方市の上品される'),
#   0.7638950744804697),
#  (('大分合同新聞',
#    '1965年',
#    '2月',
#    '15-a-5_02',
#    '" のない若い人をひきつけるため\n「これはデーベートーベリス ・ いる ! -POP スリート、 年間というのに」'),
#   0.7636754416028989),
#  (('豊州新報',
#    '1929年',
#    '6月',
#    '12-a-4_05',
#    '西瓜の増産計畫 新しい經濟的利用\n奈良漬にすれば利益が多い\n最近非常に注目さる'),
#   0.7636479283669472),
#  (('大分合同新聞', '1967年', '6月', '15-y-2_05', '安い、強いされ\n新しいカワロ'),
#   0.7635813440487971),
#  (('大分合同新聞', '1958年', '10月', '23-a-3_06', 'ほとんどがなお各界で活躍'), 0.7634262253196475),
#  (('大分合同新聞', '1962年', '12月', '28-a-6_03', '求人の多い中、高新卒\n中高齢層は減る一方'),
#   0.7629091984687282),
#  (('豊州新報', '1929年', '3月', '7-a-4_12', '『盛んな音樂會」\n何れも良い出來榮え |一般遮衆名多く堂に濡つー'),
#   0.762296897307696),
#  (('豊州新報',
#    '1932年',
#    '7月',
#    '31-a-4_03',
#    'どんな職業にも美貌が 有利である疑問? 女性の完全な經濟的獨立迄には まだ多くの幅がある'),
#   0.761333594697728),
#  (('豊州新報', '1929年', '6月', '15-a-3_05', '特に強調す'), 0.761025461068158),
#  (('大分合同新聞', '1964年', '8月', '9-a-7_02', 'これからが多い\nTHINTERITEINE\nBITIMEmaman'),
#   0.7608941535507714),
#  (('大分合同新聞', '1965年', '4月', '14-a-7_02', 'ハシカ | これからが多い」'),
#   0.7608941535507714),
#  (('大分合同新聞', '1964年', '10月', '18-a-2_01', 'あまり重視していない'), 0.7608320132783977),
#  (('大分新聞', '1926年', '4月', '1-a-3_01', '進展せぬ\n重要問題が多くて'), 0.7607076065356556),
#  (('大分合同新聞', '1949年', '4月', '12-a-2_10', '近來ない多 数の積残し'), 0.7606695193108253),
#  (('豊州新報', '1938年', '6月', '8-a-3_05', 'あるからむしろ日本の思 に ひこれ以上用 な記載を出す。あと'),
#   0.7605424442852439),
#  (('大分合同新聞', '1951年', '7月', '23-y-1_02', '前途に多くの難關'), 0.7604991665013577),
#  (('大分新聞', '1935年', '1月', '15-y-2_09', '近年ない活況|\n好景氣時代以來初めて'),
#   0.7604576872224214),
#  (('大分合同新聞',
#    '1964年',
#    '11月',
#    '18-a-6_01',
#    'いる。とくにのさいにはこのが最も多いの よりも、おとなくそれに自動車をする人の合意が必、\n(写真はで'),
#   0.759511407934014),
#  (('豊州新報', '1929年', '11月', '12-a-7_04', 'Lるの 何より悪い\nこれから多くなる 婦人特有の病氣\nこちらこちら'),
#   0.7594862260037228),
#  (('大分合同新聞', '1957年', '8月', '31-y-2_12', 'これられました'), 0.7591086552766689),
#  (('大分合同新聞', '1963年', '9月', '24-a-3_12', 'これられますが・・・'), 0.7591086552766689),
#  (('豊州新報', '1932年', '1月', '21-a-8_04', 'いささかのぼのえかな。 町中にある増えざるる'),
#   0.7590523384661836),
#  (('大分合同新聞', '1953年', '12月', '4-a-2_05', '注目される個々の力\nFWは日本ても一部'),
#   0.7579911292464657),
#  (('豊州新報', '1938年', '1月', '29-a-5_04', '今ごろは一番 便秘の多い時季\n軽視しては大變で'),
#   0.7578460452182273),
#  (('大分新聞',
#    '1929年',
#    '8月',
#    '6-a-8_05',
#    '子供の怪我は 朝の間に多い\n特に低學年兒童に多い\n一番のおさるのはいるのを'),
#   0.7576757363326518),
#  (('豊州新報', '1932年', '10月', '27-a-2_15', '他と比較して 遜色はない 名物中津の絹織物 然し生產品は激減'),
#   0.7575426947800566),
#  (('大分合同新聞',
#    '1960年',
#    '4月',
#    '26-y-1_02',
#    '|肺ジストマ\nと間違えられやすく、そのため の出が少なくない。まだ全県的に'),
#   0.7574474897837276),
#  (('豊州新報',
#    '1929年',
#    '10月',
#    '17-a-2_01',
#    '失業者に 殖れる一方 數字が雄辯に物語る 事業界萎靡沈装の姿\nはいくつか'),
#   0.7573553050647241),
#  (('大分合同新聞', '1957年', '3月', '5-y-4_01', '高まる教育テレビ熱 各社の名乗りも活発 だが多くの問題を残す'),
#   0.757347001274603),
#  (('大分合同新聞', '1967年', '4月', '7-a-8_06', 'ほとんどその日暮らし\n一方的に消費者へ?'),
#   0.7572672469534588),
#  (('豊州新報', '1941年', '5月', '18-a-5_04', '青壮年者に多い 胃酸過多症の手法'),
#   0.7571142622358772),
#  (('豊州新報', '1930年', '6月', '21-a-3_03', 'さうさせたか?」 資金難か人氣衰退か 斯界の興味深い問題'),
#   0.7569995980234302),
#  (('大分合同新聞', '1954年', '2月', '15-y-3_05', 'お得意は零細業者\nポコゲッキも多くなる'),
#   0.7569008088330789),
#  (('大分新聞', '1941年', '8月', '22-a-3_09', '依然不必要が多い。\n購雛遊興旅行が筆頭'),
#   0.7568609216422888),
#  (('大分合同新聞', '1956年', '5月', '29-a-3_05', '高い絶えぬ不平 一般に昨年よりは安いが'),
#   0.7566235303970279),
#  (('大分合同新聞', '1960年', '11月', '6-a-5_02', '優劣の差少なくなる\n参加者も毎年ふえる。'),
#   0.756578112888423),
#  (('大分合同新聞', '1958年', '10月', '29-y-2_05', '家族内伝染が多い\n特に母親は注意しよ'),
#   0.7564781081925148),
#  (('大分合同新聞', '1955年', '1月', '16-y-4_05', '脫落者も多く出る。\n激しい農場の修練'),
#   0.755935000802995),
#  (('大分合同新聞', '1957年', '5月', '23-y-4_05', 'W海外5話題多'), 0.7558558145097907),
#  (('大分合同新聞', '1957年', '6月', '7-a-3_01', '圧倒的に多い貯えと\nすっかだよ'),
#   0.7550067699972456),
#  (('大分新聞', '1921年', '12月', '1-a-3_07', '最近の商品產地況\n最も注目すべき現象は 金地さ戦前のルーい!'),
#   0.7547393736659719),
#  (('大分合同新聞',
#    '1953年',
#    '6月',
#    '29-a-4_05',
#    'いてある。写真は本来の自\n中に選び込まれたおびただしい! スズの\nイの時'),
#   0.7545190863317829),
#  (('大分合同新聞', '1957年', '9月', '13-a-1_04', '高さになお問題'), 0.7544856147608467),
#  (('大分新聞',
#    '1929年',
#    '1月',
#    '25-a-8_02',
#    '最も注意すべき 求職者の心得 如何にすれば目的を 達する事が出來るが\nまれていますw'),
#   0.754409221065571),
#  (('大分合同新聞',
#    '1959年',
#    '12月',
#    '20-a-6_01',
#    '中のなにより 多大の業 口を集め、多数 の有望な新人を 点んだこととい 下の子すみま FXに対する。\nていい。 意欲的な 強化策\n次に内最 男の\nあっせんに る花がなさ れたこと、それ !」ともなうし い校とが よいちえ たとも言い またベテラン 『Mもこ れらにされ て管に もやし、自然に\n、みごとな新人の台頭'),
#   0.7543808194760957),
#  (('大分新聞', '1941年', '10月', '12-y-4_05', '苗木不足の場合 特に重要\nインHDンター'),
#   0.754316157773088),
#  (('豊州新報',
#    '1930年',
#    '2月',
#    '13-a-7_03',
#    '最近利用者の 殖んた無盡の融通 それだけモグリの活躍も盛ん\n加入する方へ御注意\n・ ギ\nャラリー'),
#   0.7542855876185554),
#  (('大分合同新聞',
#    '1952年',
#    '2月',
#    '22-y-2-3_04',
#    '多い定貯の引出し\n_111、深\nさに\nTESHIされ151hahrashinmenirint itename'),
#   0.7541936754328973),
#  (('大分新聞', '1919年', '7月', '15-a-7_04', 'または\nおらん\n近く質時される 他せたらしい'),
#   0.7541893161725727),
#  (('大分合同新聞', '1959年', '10月', '19-a-1_04', '将来性は十分ある\n人気集まった竹製品'),
#   0.754145905578797),
#  (('大分合同新聞', '1959年', '2月', '4-y-1_04', '簡單にできようか? ブームの陰に不安も多い'),
#   0.7537925750619529),
#  (('豊州新報', '1937年', '5月', '17-a-7_04', '名前は多いが、 種類は只一つ'), 0.7537210861306425),
#  (('大分合同新聞',
#    '1962年',
#    '10月',
#    '11-a-5_01',
#    '全般に非常に高いレベル\n一つのテーマを徹底的に\nE:¥5,44石二人の'),
#   0.7536150751367345),
#  (('大分新聞', '1918年', '10月', '23-a-4_06', 'て必要品皆な高し\n◇安い物は一つもない\nやっすw'),
#   0.7534781024161665),
#  (('大分新聞',
#    '1928年',
#    '11月',
#    '1-a-8_06',
#    'ニートを含む 昆布はクスリー\nロイマチス、腺病質者 には殊に効果が多い。'),
#   0.7534106527833773),
#  (('豊州新報', '1929年', '1月', '18-a-3_08', '帆船の活躍\n最近利用者が多く 演いる目遣しくなる'),
#   0.7533134475580079),
#  (('大分新聞', '1926年', '12月', '18-a-4_11', 'さらに当ては\nよく具体的準愉'),
#   0.7533093919568563),
#  (('大分新聞', '1924年', '7月', '16-a-7_10', '雨の少ない事はない\n過去數年間との比較 ネージャーにより、 、 、 。'),
#   0.7530532700473705),
#  (('大分合同新聞',
#    '1952年',
#    '2月',
#    '27-a-2-2_03',
#    '母子援護に多くの問題 定職なしが約半数\nらっきされたシャインブラック/Weeさんいます。'),
#   0.7529367653944493),
#  (('大分合同新聞', '1966年', '7月', '14-y-6_05', '数字好き が多い ものおじせずにはっきり質問\n手軽に解答望む傾向。'),
#   0.7528108177477757),
#  (('大分新聞', '1922年', '4月', '23-a-5_01', '各地春竄狀況\n一般に減少の傾向'), 0.752709402093036),
#  (('大分新聞',
#    '1937年',
#    '10月',
#    '8-y-3_01',
#    '不急品の輸入が 禁止されました\n日常生活に關係深いものが\n多々あります'),
#   0.7526635136970713),
#  (('大分新聞', '1934年', '12月', '28-a-2_01', '近年ない歲晩景氣\n久方ぶりの活況'),
#   0.7523991032285362),
#  (('大分合同新聞', '1962年', '1月', '16-a-3_05', '大切なかれらの働き\n狩猟法にも多くの欠点'),
#   0.7522463787842917),
#  (('豊州新報', '1934年', '12月', '11-a-7_05', 'お取越し\n多詣者多く賑'), 0.7518472295744811),
#  (('大分合同新聞', '1967年', '12月', '7-a-4_05', '大半が九州のお客\n若い女性グルーブが多い'),
#   0.7517225420547999),
#  (('大分合同新聞', '1960年', '1月', '28-y-3_02', '出やや多い程度'), 0.7516889453081584),
#  (('大分合同新聞', '1959年', '5月', '15-a-5_04', 'ほとんど泣寝入り)\n補償があっても涙金程度'),
#   0.7516724813925323),
#  (('豊州新報', '1928年', '11月', '7-a-2_03', '御警術には 細心の注意\n一般市民も緊張して\n事故は極めて少ない'),
#   0.7516628932731123),
#  (('大分新聞', '1935年', '12月', '19-y-2_04', '多い。 大して影響なし。\n縣農園の話'),
#   0.7515019093200459),
#  (('大分新聞', '1923年', '7月', '26-a-4_06', '増え、\n以來の大賑い 毎夜、近郷近在から\n人出多く、非常な顔ざ上'),
#   0.751017432819642),
#  (('大分合同新聞',
#    '1961年',
#    '11月',
#    '8-a-3_02',
#    '年々充実する県美風\nOMIURISHIIIIIMITHINRIRIMIMIMINIIIIIIMMIINAIRIMO\n地方には珍しい質の高さ・'),
#   0.7506278166440085),
#  (('大分合同新聞',
#    '1958年',
#    '4月',
#    '28-a-1_02',
#    '定賃金には問題がある。\n一名「全国の述を第で多えられているよ\nTOWNの1000048WOE\nHISPELIT'),
#   0.7506031078542852),
#  (('豊州新報', '1929年', '9月', '26-a-9_14', '山縣稅滞納の\n最も多い\nー用'), 0.750601557891184),
#  (('大分合同新聞', '1946年', '4月', '18-a-3_07', 'なかなかいいまっさー!\n形式違反が多い'),
#   0.7505239560981688),
#  (('大分合同新聞', '1944年', '5月', '24-a-3_04', '今後の宮廷りはよくなる\n, 爆下各地に緩々流れる鮮'),
#   0.7504074305188687),
#  (('大分新聞', '1927年', '8月', '13-a-8_03', '| 黒糖から販薬る。 場合が最も\n多いのです'),
#   0.7502759381450481),
#  (('大分合同新聞',
#    '1967年',
#    '12月',
#    '7-a-7_07',
#    'ハラエティーに富んだ洋画\n望まれる底辺の拡大ー\n日本画は数は少ないが意欲的'),
#   0.7500999384067919),
#  (('大分合同新聞', '1951年', '7月', '24-a-2_02', '県F'), 1.0000000000000002),
#  (('大分合同新聞', '1959年', '1月', '13-a-3_01', 'の向\n県傾一'), 1.0000000000000002),
#  (('大分合同新聞', '1967年', '9月', '13-y-1_01', 'です\n県かを'), 1.0000000000000002),
#  (('豊州新報', '1932年', '4月', '23-a-3_13', '県「'), 1.0000000000000002),
#  (('豊州新報', '1933年', '7月', '12-a-4_05', 'フォ県の'), 1.0000000000000002),
#  (('大分合同新聞', '1965年', '7月', '27-a-3_01', '県県 と連'), 0.9426032721074673),
#  (('大分合同新聞', '1965年', '10月', '4-a-2_02', '「国の大県'), 0.8890503720159207),
#  (('大分新聞', '1941年', '8月', '31-a-2_07', '県各地だより'), 0.8695607535856439),
#  (('大分合同新聞', '1958年', '3月', '18-a-5_09', '名古屋に一番乗り\n県 他県に先がけて'),
#   0.8614607520361167),
#  (('大分合同新聞', '1960年', '3月', '29-y-3_02', '県外\nレー(18)'), 0.846303142481749),
#  (('大分合同新聞', '1964年', '4月', '11-a-3_02', '宮崎県のSAPH'), 0.8416534900612873),
#  (('大分合同新聞', '1967年', '5月', '22-a-8_03', '県代表に舞鶴県予選'), 0.8392605186356755),
#  (('大分合同新聞', '1965年', '2月', '19-y-2_04', '愛知県の危険は大分県でも...'),
#   0.8385555543388452),
#  (('大分合同新聞', '1961年', '3月', '7-y-4_01', '県青少年ク\n県代表の体験'), 0.835348456259027),
#  (('大分合同新聞', '1960年', '7月', '5-a-1_09', '反省の日,県と共催に\n県教委 県の申し入れいれる。'),
#   0.8336086305157113),
#  (('大分合同新聞', '1958年', '8月', '7-y-1_02', '県、あす県北へ救援苗'), 0.8303168218970348),
#  (('大分合同新聞', '1961年', '9月', '26-a-5_02', '県体\n%。'), 0.8303141680252047),
#  (('大分合同新聞', '1967年', '4月', '4-a-3_01', '県づくり'), 0.8298732340416141),
#  (('大分合同新聞', '1964年', '1月', '26-a-7_04', '大分市が県に申し入れ'), 0.8296986837925193),
#  (('大分合同新聞', '1960年', '7月', '28-a-1_04', '県選出議員 相ついて帰県'), 0.8292846220986712),
#  (('大分合同新聞', '1960年', '5月', '31-a-3_06', 'で楽二つの意見」\n県と県中央4'),
#   0.8283720871551457),
#  (('大分合同新聞', '1960年', '7月', '5-a-5_01', '大分県を美し\n県を中心に運動'),
#   0.8276340717708719),
#  (('大分合同新聞', '1958年', '5月', '31-a-1_01', 'mina\n義 県'), 0.8273656198264504),
#  (('大分合同新聞', '1960年', '12月', '18-a-2_10', 'ンアイ\n県高教組の拡'), 0.8270735694673803),
#  (('大分合同新聞', '1958年', '9月', '15-a-5_02', '県教委もやはり強腰'), 0.8256021340613279),
#  (('大分合同新聞', '1966年', '2月', '12-a-3_01', '新產都建設\n県と市町村にスレ'),
#   0.8237270808504132),
#  (('大分合同新聞', '1964年', '5月', '31-a-1_02', '県、市町村にも指導'), 0.8236673322160353),
#  (('大分合同新聞', '1958年', '7月', '23-a-1_03', '主役県'), 0.822327320062337),
#  (('大分合同新聞', '1955年', '10月', '25-a-3_04', '| 期待県'), 0.8211742227791349),
#  (('大分合同新聞', '1965年', '11月', '20-a-5_07', 'Xぎょうの木 県 県高校新体操'),
#   0.8207604088755857),
#  (('大分合同新聞', '1965年', '12月', '10-y-2_01', 'く県相つぐ>'), 0.8192901461751033),
#  (('大分合同新聞', '1967年', '6月', '1-y-4_01', '県らだ'), 0.8191127908722123),
#  (('大分合同新聞', '1961年', '6月', '27-a-1_12', 'きう疑県)'), 0.8188642010442275),
#  (('大分合同新聞', '1961年', '10月', '19-a-11_01', '大分県'), 0.8184677785310951),
#  (('大分合同新聞', '1964年', '7月', '25-a-2_01', '大分県から'), 0.8184677785310951),
#  (('大分合同新聞', '1961年', '6月', '10-a-7_03', '県病に鉄の肺'), 0.8179262331953948),
#  (('大分合同新聞', '1960年', '12月', '17-y-3_02', '大分県呉市'), 0.814946872764054),
#  (('大分合同新聞', '1963年', '8月', '15-a-3_07', '県 近くあっせん案\n県畜連と経済連の統合'),
#   0.8145978584251948),
#  (('大分合同新聞', '1967年', '7月', '24-a-6_02', '佐藤 2千パに県新\n.域県新4大会新1'),
#   0.8135171490188738),
#  (('大分合同新聞', '1958年', '9月', '14-a-1_05', '県教組 県教委いぜん強腰'), 0.8069120435895284),
#  (('大分合同新聞', '1964年', '1月', '9-a-3_02', 'でも県労\n勞果'), 0.805690031885037),
#  (('大分合同新聞', '1967年', '6月', '14-y-1_09', '県北各地でも'), 0.8055232961206329),
#  (('大分合同新聞', '1953年', '1月', '22-a-2_06', '県農委を法人組織に\n(各県に農協中央会'),
#   0.803740595964164),
#  (('大分合同新聞', '1960年', '9月', '15-a-2_04', '着工促進働きかけ\n県 愛媛県が政府'),
#   0.8021535460838568),
#  (('大分合同新聞', '1962年', '5月', '10-a-3_01', '=県農政連が運動'), 0.8006320198798975),
#  (('大分合同新聞', '1957年', '8月', '5-a-1_04', '8県が単年度黒字\n県、赤字類似公県を調査\n"imitmlPE.'),
#   0.7986767375359712),
#  (('大分合同新聞', '1966年', '7月', '18-a-1_03', '県が県北開発構想 作成へ'), 0.7985249988939196),
#  (('大分合同新聞',
#    '1964年',
#    '7月',
#    '4-a-4_04',
#    'seasumalsenseaseturesensolistarote\n米県'),
#   0.7973616660166277),
#  (('大分新聞', '1921年', '7月', '26-a-1_01', '大分県の人々へ'), 0.796890392438519),
#  (('大分合同新聞', '1966年', '5月', '11-a-3_04', '県が調停をでエ'), 0.7961078961798927),
#  (('大分合同新聞', '1958年', '12月', '21-a-2_07', '県北に森林区\n県への答申案決まる。'),
#   0.7950209243676264),
#  (('大分合同新聞', '1957年', '3月', '21-y-1_10', '宮崎県と提携強む\n県 原乳の買入れ増な'),
#   0.7946866718610702),
#  (('大分合同新聞', '1959年', '12月', '3-y-1_09', '県酪人り決まる\n波多野県農地林業部長'),
#   0.7941146524934428),
#  (('大分合同新聞', '1957年', '11月', '21-a-1_13', '県、9日宮崎 県側と話合い'),
#   0.7940566629973942),
#  (('大分合同新聞', '1959年', '8月', '25-a-1_06', 'ょう。県職労大会'), 0.793776768386355),
#  (('大分合同新聞', '1966年', '8月', '21-a-7_01', '県美馬県\n秋に備えて手入れを'),
#   0.793259769539263),
#  (('大分合同新聞', '1965年', '12月', '18-a-10_05', '県地域青少年スポー|'), 0.7921093371126762),
#  (('大分合同新聞', '1959年', '10月', '5-a-1_06', 'きょうから実態調査\n崎県教委、西日本各県で'),
#   0.7918427976330475),
#  (('大分合同新聞', '1960年', '3月', '26-y-3_01', '県年'), 0.790558801621475),
#  (('大分合同新聞', '1960年', '11月', '22-a-6_03', '県外へ県外へに待った'), 0.7904404083159736),
#  (('大分合同新聞', '1953年', '6月', '26-y-1_12', '県、調査に乗出す。'), 0.7901327733834953),
#  (('大分合同新聞', '1962年', '9月', '4-a-3_12', '表砂Lなとに分剛彦\n政府、大分県など十県を指定'),
#   0.789161652949116),
#  (('大分合同新聞', '1961年', '5月', '3-a-4_06', '県赤ちゃんコンクー'), 0.7889904488184474),
#  (('大分合同新聞', '1958年', '7月', '31-a-1_08', '県北の水利事業急げ!\nホ県、地元に声高まる'),
#   0.7887792932753626),
#  (('大分合同新聞', '1958年', '3月', '26-a-1_09', '/とりあえず県案か\n苦しくなった県教委'),
#   0.7886856919703312),
#  (('豊州新報', '1933年', '9月', '19-a-6_01', '見本県'), 0.7879476593224076),
#  (('大分新聞', '1927年', '10月', '29-a-4_12', '県|岐阜地方に\n激、'), 0.787861207100384),
#  (('大分合同新聞', '1963年', '12月', '17-a-5_07', 'Xょのネッ 県内、県外とし'),
#   0.7876449994670621),
#  (('大分合同新聞', '1957年', '1月', '23-y-4_05', '県北、県南相補う要\n県産のみかん改善点'),
#   0.7875317363106087),
#  (('大分合同新聞', '1956年', '7月', '24-a-3_09', '県教委も実情調査へ\n● きょう九県に出発'),
#   0.787241505536119),
#  (('大分合同新聞', '1962年', '11月', '6-y-3_08', '千葉県の海岸に'), 0.7871124710510543),
#  (('大分合同新聞', '1960年', '4月', '5-y-3_01', '客県\n...... (22) では!'),
#   0.7866962812448705),
#  (('大分合同新聞', '1957年', '10月', '9-y-3_13', '大分県の道'), 0.7858791851239599),
#  (('大分合同新聞', '1963年', '1月', '10-a-1_09', '来月初めから準備へ\n県 県教委 異動で説明'),
#   0.7858078464083844),
#  (('大分新聞', '1939年', '11月', '28-a-2_08', '県 大分の選舉違\nミコト'), 0.7857398337017972),
#  (('大分合同新聞', '1967年', '2月', '5-a-3_06', '県国に協力を要請\n県 七市町村がスクラム'),
#   0.7853100868519415),
#  (('大分合同新聞', '1960年', '12月', '13-a-3_03', 'ガタガタの県農政連'), 0.7843752798990782),
#  (('大分合同新聞', '1961年', '1月', '8-y-3_02', '各県共同で宣伝へ\n大分県が音頭をとって'),
#   0.7840335133116616),
#  (('大分合同新聞', '1960年', '6月', '21-a-6_01', '「県代表に分鉄'), 0.7835821776091408),
#  (('大分合同新聞', '1959年', '8月', '28-a-1_04', '県教委 勤評修正に踏切る。'), 0.7824889504734754),
#  (('大分合同新聞', '1957年', '2月', '23-a-1_07', '高校に重点はおかぬ\n県 県教委 異動で説明'),
#   0.7815849339510158),
#  (('大分合同新聞', '1967年', '1月', '7-a-3_07', '「分県農業を考える。'), 0.7813145621727796),
#  (('大分合同新聞', '1966年', '10月', '7-y-3_05', 'なすりあう県と別府市'), 0.7811273032460533),
#  (('大分合同新聞', '1959年', '6月', '15-a-6_02', '^ 県代表に分'), 0.7809572065442741),
#  (('大分合同新聞', '1963年', '1月', '4-y-3_11', 'にし\n大分県から'), 0.7808087255415006),
#  (('大分合同新聞', '1954年', '9月', '1-a-2_03', '|県農業会議きょう発足\n20115日がたった県従って県知事は同ッ'),
#   0.7807714450345014),
#  (('大分合同新聞', '1960年', '9月', '21-a-3_01', '県職労のこんご'), 0.7799691841480535),
#  (('大分合同新聞', '1961年', '9月', '8-y-1_03', '工業県への反省'), 0.7791574478941949),
#  (('大分合同新聞', '1961年', '4月', '23-a-7_03', '長崎県にお入り。'), 0.7783096706547442),
#  (('大分合同新聞', '1961年', '6月', '14-a-3_03', '五号地に製材団地\n県木連が県に申し入れ'),
#   0.7782299973442289),
#  (('大分合同新聞', '1954年', '11月', '14-a-2_06', '県代表に大工.中津東\n九州高校サッカー県豫選'),
#   0.7780066233396827),
#  (('大分合同新聞', '1964年', '4月', '14-a-1_13', '県教委、教職員の'), 0.777697768601178),
#  (('大分合同新聞', '1964年', '11月', '25-a-10_10', 'きょう県高校\n( WX'),
#   0.7773476865196184),
#  (('大分合同新聞', '1955年', '8月', '21-a-4_07', '日田市県選手決不'), 0.7769445198492765),
#  (('大分合同新聞', '1964年', '4月', '9-a-3_02', '宮崎県のSAP運動'), 0.7766399515055188),
#  (('大分合同新聞', '1964年', '4月', '14-a-3_02', '宮崎県のSAP運動'), 0.7766399515055188),
#  (('大分合同新聞',
#    '1960年',
#    '3月',
#    '29-y-1_09',
#    '大分市建設」を明記\n県4 自民 県の意向了承\nmirainmentiatm-tower SAY:INT催に'),
#   0.7764926212962941),
#  (('大分合同新聞', '1961年', '7月', '28-a-6_06', '県B GS大会始ま'), 0.7760332291413007),
#  (('大分合同新聞', '1966年', '12月', '19-a-1_07', '市町村に秘)等の 準 補体制を指示\n県と県'),
#   0.7756871958287586),
#  (('大分合同新聞', '1965年', '3月', '20-a-7_09', '(短歌県)'), 0.7756819860833482),
#  (('大分合同新聞', '1962年', '9月', '21-a-3_11', '県畜連の組織再編\n県が指静に乗り出す'),
#   0.7753605203648055),
#  (('大分合同新聞', '1966年', '5月', '5-a-3_08', '県内組 からバルブコ 県外'), 0.7742353824217636),
#  (('大分合同新聞', '1960年', '6月', '9-y-4_02', '計画出荷を強める\n県や県販購連の計画'),
#   0.7740937656065238),
#  (('大分合同新聞', '1961年', '5月', '16-a-1_05', '統一を申し入れ、\n県職労が県職組に'),
#   0.7740233022758056),
#  (('大分合同新聞', '1955年', '7月', '18-a-2_07', '県代表に中津南A\n全日本高校相撲県豫'),
#   0.7739402242959403),
#  (('大分合同新聞', '1967年', '7月', '29-a-1_12', '九州全県が 汚染地区に'), 0.7732683878942495),
#  (('大分合同新聞', '1966年', '3月', '9-a-1_05', '名古屋に県事務所\n県産品の伸びを期待'),
#   0.773259378010302),
#  (('大分合同新聞', '1957年', '12月', '14-y-3_04', '県との交涉が安結\n県建設労連の年末手当'),
#   0.773090364909682),
#  (('大分合同新聞', '1962年', '11月', '26-a-8_02', '舞鶴が県代表\n高校ラグビー県予選'),
#   0.7725642396325927),
#  (('大分合同新聞', '1966年', '11月', '8-a-5_05', '中津南が県代表に'), 0.7724495201899889),
#  (('大分合同新聞', '1959年', '9月', '22-a-4_04', '関市の県体出場'), 0.7724142000767552),
#  (('豊州新報', '1935年', '10月', '29-a-3_09', 'フケータ\n暗渠陳情\n・大分市から県へ'),
#   0.7723497304292956),
#  (('大分合同新聞',
#    '1963年',
#    '6月',
#    '25-a-7_08',
#    'ッュに逆もどり 県 きょうからまた下\n| |\n||||||listed'),
#   0.7723014116395224),
#  (('大分合同新聞', '1958年', '8月', '16-a-5_07', '「Fを重メディ\n銀知事、県教委に申入れ'),
#   0.7721410946135313),
#  (('大分合同新聞', '1955年', '7月', '4-a-2_02', '県代表に国東鶴城高\n全国高校柔道県予選'),
#   0.7721380281696223),
#  (('大分合同新聞', '1966年', '11月', '2-a-9_03', '赤ちゃん大分県一は |\nきょう コンテスト県大会'),
#   0.7719854327239906),
#  (('大分合同新聞', '1956年', '8月', '21-y-1_12', '参考に各県を調査\n県教委、教員の定数を'),
#   0.771594314305309),
#  (('大分合同新聞', '1955年', '7月', '15-a-2_11', '分鉄が県代表\n天皇不次代野球県予'),
#   0.7715858641990543),
#  (('大分合同新聞', '1953年', '3月', '12-a-2_10', '県箕と地元負担て\n8年度分を県に要請'),
#   0.7712698417323026),
#  (('大分合同新聞', '1962年', '10月', '5-a-7_01', '大分県のお百姓'), 0.7711875768319498),
#  (('大分合同新聞', '1959年', '9月', '9-a-2_05', '3日から県高校農 業クラブ県大会'),
#   0.7710623898560456),
#  (('大分合同新聞', '1958年', '12月', '29-a-3_04', 'このあと福岡県ても'), 0.770951641289902),
#  (('大分合同新聞', '1959年', '2月', '1-a-2_07', '季県体として行う\n大分県一周駅伝'),
#   0.7703040011497316),
#  (('大分合同新聞', '1960年', '1月', '30-a-5_03', 'にらみあう県教委と県連青\n|ては在と'),
#   0.7702968350560144),
#  (('大分合同新聞', '1962年', '6月', '28-a-1_05', '県 南部\n地元を固め'), 0.7699299984475443),
#  (('大分合同新聞', '1953年', '1月', '6-a-1_08', '各県の教育方針'), 0.7697041996857751),
#  (('大分合同新聞', '1961年', '8月', '10-a-1_02', '県と六市町村で\n新市の名は 大分市に'),
#   0.7694966087406045),
#  (('大分合同新聞', '1956年', '3月', '11-y-3_07', '県 なきや西や、'), 0.7693601411623606),
#  (('大分合同新聞', '1955年', '11月', '20-a-2_07', '大分県い觀光'), 0.7690298755282889),
#  (('大分合同新聞', '1962年', '5月', '17-y-3_09', '九州各県が共同で」\n吓一跳出出离奇哥'),
#   0.7689270814896473),
#  (('大分合同新聞', '1964年', '9月', '14-a-10_03', '県から5人が参加'), 0.7683048257592685),
#  (('大分合同新聞', '1956年', '6月', '11-a-1_03', '県財政再建案に反対\n県高教組の臨時大会'),
#   0.7682501627843176),
#  (('大分合同新聞', '1964年', '2月', '26-a-7_06', '図書館に冷たい県\n県教委に 計画縮小の注文'),
#   0.7677402718781409),
#  (('大分新聞', '1941年', '6月', '26-y-3_08', 'おっさ\n|県のお化粧'), 0.7676552302545208),
#  (('大分合同新聞',
#    '1954年',
#    '4月',
#    '19-y-3_04',
#    '山川県る時\nmatreathatterthattlettoothety.that thatthtmtm'),
#   0.7676514882295591),
#  (('大分合同新聞', '1953年', '12月', '11-a-2_07', '売惜むと他県が進出\n県農政課が呼掛け'),
#   0.7676318415810466),
#  (('大分合同新聞', '1954年', '9月', '9-a-4_05', '県体の部市代表'), 0.7674658173914829),
#  (('大分合同新聞', '1966年', '8月', '7-a-3_02', '県椎茸農協の運営\nあすから県が検査へ'),
#   0.7670350048769617),
#  (('大分合同新聞', '1966年', '8月', '29-y-2_01', 'Look\n1県でも独自の調査を'),
#   0.7667266157293897),
#  (('大分合同新聞', '1958年', '1月', '13-y-2_04', '(ラジオ大分県のNHK)'), 0.7666650994562139),
#  (('大分合同新聞', '1961年', '3月', '18-y-4_01', '大分県の酒'), 0.7657425921626027),
#  (('大分合同新聞', '1966年', '8月', '27-a-10_04', '県学生始まる'), 0.7655490480022715),
#  (('大分合同新聞', '1962年', '7月', '28-a-5_01', '県中学新3、同タイ\nthe-\nLALA'),
#   0.7653460072197535),
#  (('大分合同新聞', '1965年', '7月', '6-y-2_07', '長崎県に内定鮮\n国44'), 0.7652288984883759),
#  (('大分合同新聞', '1962年', '6月', '28-a-1_08', '県北部\n農村部では、'), 0.7652256844612357),
#  (('大分合同新聞', '1967年', '1月', '10-a-3_09', '大分県農業を考える。'), 0.7650898276783961),
#  (('大分合同新聞', '1959年', '8月', '25-a-4_08', '県代表決まる。\n全九州高校対県陸上'),
#   0.7647412148139888),
#  (('大分合同新聞', '1962年', '10月', '3-y-3_02', '酪農、かんきつを奨励 県、県拓連が構想ねる'),
#   0.7647094358532277),
#  (('大分合同新聞', '1965年', '2月', '24-a-2_11', 'witty\n国東塔など県'), 0.7642526232985652),
#  (('大分合同新聞', '1959年', '1月', '18-y-3_01', '「県北の大雪'), 0.7642008171139093),
#  (('大分合同新聞', '1967年', '12月', '25-a-1_03', '県がきょう提案へ'), 0.7634137207305035),
#  (('大分合同新聞', '1965年', '1月', '3-a-4_01', '大分県の産業を\n14時26'), 0.7633623526504858),
#  (('大分合同新聞', '1959年', '4月', '27-a-6_06', '県代表六決まる。\n全国実業団卓球県予區'),
#   0.7632471152200407),
#  (('大分合同新聞', '1962年', '10月', '24-a-3_04', '「大分県の新しい農業'), 0.7631496963169305),
#  (('大分合同新聞', '1962年', '10月', '25-a-3_03', '大分県の新しい農業'), 0.7631496963169305),
#  (('大分合同新聞', '1962年', '10月', '26-a-3_03', '「大分県の新しい農業'), 0.7631496963169305),
#  (('大分合同新聞', '1962年', '10月', '30-a-3_03', '大分県の新しい農業'), 0.7631496963169305),
#  (('大分合同新聞', '1962年', '10月', '28-a-3_05', '大分県の新しい農業」'), 0.7631496963169305),
#  (('大分合同新聞', '1962年', '11月', '2-a-3_03', '「大分県の新しい農業'), 0.7631496963169305),
#  (('大分合同新聞', '1962年', '11月', '1-a-3_03', '「大分県の新しい農業\n..........・・・mani'),
#   0.7631496963169305),
#  (('大分合同新聞', '1962年', '11月', '6-a-3_02', '大分県の新しい農業」'), 0.7631496963169305),
#  (('大分合同新聞',
#    '1962年',
#    '11月',
#    '13-a-3_03',
#    '「大分県の新しい農業」\n..............................\nKURYUYA'),
#   0.7631496963169305),
#  (('大分合同新聞', '1962年', '11月', '16-a-3_02', '大分県の新しい農業'), 0.7631496963169305),
#  (('大分合同新聞', '1962年', '11月', '4-a-3_06', '大分県の新しい農業」'), 0.7631496963169305),
#  (('大分合同新聞', '1962年', '11月', '11-a-3_04', '大分県の新しい農業'), 0.7631496963169305),
#  (('大分合同新聞', '1962年', '11月', '23-a-3_01', '「大分県の新しい農業'), 0.7631496963169305),
#  (('大分合同新聞', '1962年', '11月', '17-a-3_03', '大分県の新しい農業」'), 0.7631496963169305),
#  (('大分合同新聞', '1962年', '11月', '20-a-3_02', '大分県の新しい農業」'), 0.7631496963169305),
#  (('大分合同新聞', '1962年', '11月', '3-a-3_02', '「大分県の新しい農業」'), 0.7631496963169305),
#  (('大分合同新聞', '1962年', '11月', '15-a-3_03', '「大分県の新しい農業'), 0.7631496963169305),
#  (('大分合同新聞', '1962年', '11月', '25-a-3_04', '大分県の新しい農業」'), 0.7631496963169305),
#  (('大分合同新聞', '1962年', '11月', '18-a-3_03', '大分県の新しい農業'), 0.7631496963169305),
#  (('大分合同新聞', '1962年', '11月', '7-a-3_02', '大分県の新しい農業'), 0.7631496963169305),
#  (('大分合同新聞', '1962年', '11月', '21-a-3_02', '「大分県の新しい農業'), 0.7631496963169305),
#  (('大分合同新聞', '1962年', '11月', '22-a-3_02', '「大分県の新しい農業」'), 0.7631496963169305),
#  (('大分合同新聞', '1962年', '11月', '14-a-3_02', '大分県の新しい農業'), 0.7631496963169305),
#  (('大分合同新聞', '1967年', '9月', '22-a-3_08', '県と懇談会\n県経営者協'), 0.763008990852886),
#  (('大分合同新聞', '1964年', '1月', '12-a-3_02', 'TILSLUTTE13\n州開発が県に説明'),
#   0.7629665085179137),
#  (('大分合同新聞', '1955年', '11月', '1-y-4_04', '県代表選手決る。\n佐伯 県学校農業ク大'),
#   0.7626490213880693),
#  (('大分合同新聞', '1962年', '12月', '9-a-3_05', '県があっせん再開へ |\n- 日田、豊前、県の合併'),
#   0.7622319460138955),
#  (('大分合同新聞', '1962年', '8月', '17-a-5_02', '| 大分県の盆踊り'), 0.7621016317146002),
#  (('大分合同新聞', '1967年', '12月', '13-a-7_10', '大介など!」 県が新加盟'), 0.7618568678077295),
#  (('大分合同新聞', '1957年', '2月', '28-a-1_07', '県と市が保証措置'), 0.7618499319856694),
#  (('大分合同新聞', '1963年', '1月', '1-a-15_01', '大分県を美しく'), 0.7614487782091164),
#  (('大分合同新聞', '1957年', '1月', '18-y-1_03', '宮崎県てはこうして解決'), 0.76128654640674),
#  (('大分合同新聞', '1960年', '6月', '9-a-1_12', '大分県佐 県営林事業公債の\n支払いについて'),
#   0.7612861695223239),
#  (('大分合同新聞', '1964年', '7月', '15-a-9_08', 'きょう県入り。'), 0.7610920920383849),
#  (('大分合同新聞', '1958年', '4月', '29-a-1_07', '県教委が申合せ\n九州各県と歩調合せる'),
#   0.761049706959806),
#  (('大分合同新聞', '1960年', '8月', '27-a-2_05', '県職員のべ・ア勧告\n県人事委が2月ごろに'),
#   0.7606750269368825),
#  (('大分合同新聞', '1956年', '2月', '16-a-1_02', 'FIL五月\n知事、県教委に折れる'),
#   0.7606082915291147),
#  (('大分合同新聞', '1962年', '9月', '8-a-3_05', '| 陳情ぜめの県教委'), 0.7605197172137644),
#  (('大分合同新聞', '1956年', '12月', '29-a-1_03', '県の子要求出そろう。'), 0.7605121390136437),
#  (('大分合同新聞', '1962年', '8月', '30-a-8_04', '県代表に中津東\n国体高校サッカー県予選'),
#   0.760413857510112),
#  (('大分合同新聞', '1956年', '7月', '9-a-4_04', '中学校も県新記録'), 0.7603105187825587),
#  (('大分合同新聞', '1964年', '1月', '28-y-1_02', '中小企業の振興など\n県 県予算で申し入れ'),
#   0.7599071794723816),
#  (('大分合同新聞', '1957年', '9月', '5-a-1_01', '- 県教委の二つの改選\nIntermis'),
#   0.7596981299170424),
#  (('大分合同新聞', '1962年', '8月', '26-y-2_04', 'の題です。 で、県県\nなどは 知っている ようで'),
#   0.7595809990717834),
#  (('大分合同新聞', '1966年', '3月', '30-y-3_04', '悪路事故 県の責任。\n山口県が損害賠優'),
#   0.7594650391192214),
#  (('大分合同新聞', '1967年', '6月', '21-a-3_04', '異動の手直しを要求\n県教組が県教委に'),
#   0.7593078905889098),
#  (('大分合同新聞', '1964年', '9月', '5-a-1_09', '三県と北九州 市が同一步調'), 0.7591015183333159),
#  (('大分合同新聞', '1955年', '7月', '17-a-2_11', '各県に農業振 興指定町村'), 0.7590974772920366),
#  (('大分合同新聞', '1962年', '1月', '6-a-2_02', '県音連を吸収する |\n県経済連 近く申し入れ'),
#   0.7586620641093078),
#  (('大分合同新聞', '1955年', '8月', '18-a-3_08', '(THE\n県初の国設票漁'), 0.7585472874730584),
#  (('大分合同新聞', '1967年', '12月', '27-a-1_07', '県酪農協が再建へ\n久住場 県のバックアップで'),
#   0.7581351293602134),
#  (('大分合同新聞', '1966年', '3月', '11-a-1_05', '県北に工場誘致\n県 新年度から重的に'),
#   0.7579536614029855),
#  (('大分合同新聞', '1961年', '5月', '30-a-4_03', '大分県とびある記」'), 0.757907529363397),
#  (('大分合同新聞', '1958年', '9月', '9-a-3_01', '県側も現地に乗込む'), 0.7578251424004914),
#  (('大分合同新聞', '1954年', '12月', '17-a-1_06', '民主、県同は旧選挙区\n県、各蒸派の意向聴取'),
#   0.75778587377554),
#  (('大分合同新聞', '1962年', '6月', '22-a-2_06', '県 新産業都市 指定など陳情'),
#   0.7576834860215526),
#  (('大分合同新聞', '1957年', '9月', '4-a-2_05', '県外から万個\n県のワガキ移入計画'),
#   0.7573067363879482),
#  (('大分合同新聞', '1958年', '12月', '29-a-2_05', '県経協と県中、 小企業中央会'),
#   0.7569098189555673),
#  (('大分合同新聞', '1961年', '4月', '28-a-3_04', '九州各県なみに」\n県小学・中学校長会'),
#   0.7563687107274083),
#  (('大分合同新聞', '1963年', '11月', '21-y-3_05', '私立のことも考えて、\n高校定員普県や県教委に訴え'),
#   0.7561590700082101),
#  (('大分合同新聞', '1955年', '11月', '8-a-2_07', '県代表決まる'), 0.7561543822954757),
#  (('大分合同新聞', '1959年', '11月', '9-a-5_06', '県代表決まる'), 0.7561543822954757),
#  (('大分合同新聞', '1961年', '8月', '21-a-5_03', '県代表決まる'), 0.7561543822954757),
#  (('大分合同新聞', '1962年', '6月', '4-a-6_04', '県代表決まる'), 0.7561543822954757),
#  (('大分合同新聞', '1962年', '7月', '23-a-6_04', '県代表が決まる。'), 0.7561543822954757),
#  (('大分合同新聞', '1962年', '9月', '12-y-1_07', '両大臣、県北を回る。'), 0.7561181864948352),
#  (('大分合同新聞', '1962年', '11月', '1-a-1_07', '「大分県百景 決まる。\n県内全地域にわたる'),
#   0.7559090380378123),
#  (('大分新聞', '1951年', '9月', '16-a-1_01', '耕地災害全県指定か'), 0.7557353588430342),
#  (('大分合同新聞', '1961年', '12月', '19-y-3_02', 'メクラ指導の県社協\n進みぐあいがつかめぬ」'),
#   0.755657293350171),
#  (('大分合同新聞', '1959年', '7月', '17-a-1_11', '県十一市校よ'), 0.7556528154470353),
#  (('大分合同新聞', '1954年', '1月', '31-y-2_03', '毎日オリオンズ来県\nロックストランク・キャント]'),
#   0.7554529397866298),
#  (('大分合同新聞', '1966年', '5月', '18-a-3_07', '県が切り替えを指導'), 0.7554081686311322),
#  (('大分合同新聞', '1954年', '8月', '7-a-2_05', '県農協中央会で決定'), 0.7549290222795318),
#  (('大分新聞', '1918年', '4月', '7-a-2_01', '●県競-SK\nThinnHahHAKAEOm'),
#   0.7547485876196025),
#  (('大分合同新聞', '1963年', '2月', '16-y-3_05', '奇型児が県下でも'), 0.754437462267751),
#  (('大分合同新聞', '1967年', '5月', '28-a-4_02', '県新1高校新3\n梅木()が36 22'),
#   0.7539998754223903),
#  (('大分合同新聞', '1965年', '5月', '20-a-1_08', '密漁船を取り締まれ\n県 愛媛県側に抗議'),
#   0.7539718336290545),
#  (('大分合同新聞', '1964年', '4月', '12-a-3_02', '宮崎県のSAP運'), 0.7534306247509882),
#  (('大分合同新聞', '1957年', '7月', '15-a-2_06', '大分市が二連勝遂ぐ\n県軟庭郡市対抗中央大会'),
#   0.7533200562907735),
#  (('大分合同新聞', '1960年', '8月', '26-a-2_04', '勤評中止で十項目 県教組 県教委に申し入れ'),
#   0.7531620356176768),
#  (('大分合同新聞', '1954年', '10月', '21-a-1_10', '県下稲作況調査始る\n県と県農業会議合同で'),
#   0.7528197168474311),
#  (('大分合同新聞', '1966年', '12月', '19-a-1_02', '崎県 大詰め段階に\n県教委の日までに決定へ'),
#   0.7524637879194296),
#  (('大分合同新聞', '1959年', '10月', '15-a-2_10', '4Fに\n[ 県教委の主張通'),
#   0.752362390688485),
#  (('大分合同新聞', '1959年', '6月', '22-a-6_07', '県代表に豊クラブ'), 0.752301315351534),
#  (('大分合同新聞', '1958年', '9月', '14-a-3_02', '14日の混乱シリ目に\n県 文教委が県外視察へ'),
#   0.7522677069138248),
#  (('大分合同新聞', '1963年', '12月', '8-a-1_04', '県教委、あす 一から予外折衝'),
#   0.7522168330100522),
#  (('大分合同新聞', '1955年', '10月', '26-a-2_03', '県開地の3'), 0.7521870239804966),
#  (('大分合同新聞', '1959年', '3月', '27-y-3_04', '「ウルト』\nのゆく大分県'), 0.7520609643038887),
#  (('大分合同新聞', '1961年', '8月', '24-a-1_08', '勤評の取り扱い公表\n県教組 県教委に申し入れ'),
#   0.751712145320406),
#  (('大分合同新聞', '1965年', '8月', '14-a-5_06', '橋本が県中学新!!'), 0.7516152033721922),
#  (('大分合同新聞', '1964年', '5月', '19-a-1_02', '市町村への援助に\n国体県準備委で決める。'),
#   0.751561438297907),
#  (('大分合同新聞', '1956年', '3月', '16-a-1_13', '県農林事務所'), 0.7515124195535928),
#  (('大分合同新聞', '1967年', '1月', '13-a-3_06', '「大分県農業を考る。'), 0.7514364766575311),
#  (('大分合同新聞', '1958年', '2月', '10-y-4_03', '白馬渓の整備など\n県 市に実現を要予'),
#   0.7512392290210819),
#  (('大分合同新聞', '1960年', '7月', '15-a-4_03', 'ピンチの県奨学会\n県の援助を要望'),
#   0.7512042193562992),
#  (('大分合同新聞', '1966年', '2月', '2-a-3_01', '具) とエラー\n珈ぐ県、各県の協力求める'),
#   0.751115814216588),
#  (('大分合同新聞', '1958年', '8月', '1-a-2_07', '県に出資金'), 0.750833430824942),
#  (('大分合同新聞', '1958年', '1月', '18-y-1_03', '県酪農協'), 0.7508286619948213),
#  (('大分合同新聞', '1961年', '2月', '7-a-4_04', '在円のイメなと\n県教委、文化財を指'),
#   0.7507252562027859),
#  (('大分合同新聞', '1958年', '6月', '30-a-4_02', '県代表に津久見など一\n高校弓道県予選'),
#   0.750620922402624),
#  (('大分合同新聞', '1965年', '11月', '27-a-5_04', '群を抜く大野、大分市\nあす 県中学郡市対抗駅伝'),
#   0.7506160310768959),
#  (('大分合同新聞', '1967年', '4月', '5-a-3_04', '冊 地元で1確保へ\n県の交涉煮つまる'),
#   0.7504178300909752),
#  (('大分合同新聞', '1959年', '7月', '7-a-5_09', '大分県は2番目\n全国各県の生活水準分る'),
#   0.7503606192410927),
#  (('大分新聞', '1951年', '7月', '3-a-1_02', '県税も実情に應じて'), 0.7502885485823896),
#  (('大分合同新聞', '1963年', '5月', '29-a-3_03', '九州各県の観光政策'), 0.7502309511430351),
#  (('大分合同新聞', '1956年', '7月', '28-a-1_10', '現教員数は減らせg\n(県教育庁、県案に反対'),
#   0.7501481770742827)]

# %% [markdown]
# ## 全部連結して

# %%
token_list = []
for token in tokens:
    hypernyms = search_upper_concept_words(token, hierarchy_dict)
    
    # 翻訳
    for hypernym in hypernyms:
        print(f'翻訳前: {hypernym}')
        translated = translator.translate(hypernym, src='en', dest='ja')
        print(f'翻訳後: {translated.text}')
        token_list.append(translated.text)
# Out:
# 「危険」の上位概念を出力します。
# ------------------parlous---------------------
# ------------------risky---------------------
# ------------------severe---------------------
# ------------------bad---------------------
# ------------------unsafe---------------------
# 翻訳前: parlous
# 翻訳後: par par
# 翻訳前: risky
# 翻訳後: リスキーな
# 翻訳前: severe
# 翻訳後: ひどい
# 翻訳前: bad
# 翻訳後: 悪い
# 翻訳前: unsafe
# 翻訳後: 危険な
# 「大分」の上位概念を出力します。
# ------------------considerably---------------------
# ------------------much---------------------
# ------------------a_lot---------------------
# 翻訳前: considerably
# 翻訳後: consider
# 翻訳前: much
# 翻訳後: 多くの
# 翻訳前: a_lot
# 翻訳後: 多くの
# 「[UNK]」は存在しない単語です。
# 「愛知」は存在しない単語です。
# 「県」の上位概念を出力します。
# ------------------prefecture---------------------
# 翻訳前: prefecture
# 翻訳後: 県

# %%
token_list
# Out:
# ['par par', 'リスキーな', 'ひどい', '悪い', '危険な', 'consider', '多くの', '多くの', '県']

# %%
token_list = ','.join(token_list)

# %%
token_list
# Out:
# 'par par,リスキーな,ひどい,悪い,危険な,consider,多くの,多くの,県'

# %%
# %%time
similarity_headlines = get_all_similarity(headline_list, token_list)
# Out:
# Wall time: 13.1 s

# %%
len(similarity_headlines)
# Out:
# 13835

# %%
for n, headline in enumerate(similarity_headlines):
    if n < 10:
        print(headline)
# Out:
# (('大分合同新聞', '1966年', '9月', '13-a-1_02', '特にひどい中、'), 0.8717839873097029)
# (('大分合同新聞', '1960年', '4月', '26-y-1_02', '|肺ジストマ\nと間違えられやすく、そのため の出が少なくない。まだ全県的に'), 0.8608060145002486)
# (('豊州新報', '1938年', '6月', '23-a-8_03', '入梅中は特に 疲労がひどい\n恢復には何が良いか'), 0.8595951747733489)
# (('大分新聞', '1941年', '10月', '14-y-3_07', '悪い齒並び\n馬鹿に出來ぬ影響'), 0.8567515849865073)
# (('豊州新報', '1938年', '1月', '24-a-7_03', 'こり早\n煙。落ちたとの噂\n品切れが多いのは何故か 認識不足だと專賣局が難解\nBOOOOOOOOoooood'), 0.8545327537002515)
# (('大分合同新聞', '1967年', '3月', '17-a-11_06', 'に時 国間 難的\n難こわい甘い診断 とても責任もてぬ'), 0.8528478137664636)
# (('豊州新報', '1933年', '10月', '30-a-8_04', '大多勢の人が 悩むのは疣痔 燃り易いが放任は危険」'), 0.8510280852928934)
# (('大分新聞', '1927年', '10月', '29-a-8_05', '鼻が悪くなると 頭悪くなる。 殊に子供は影響が多い 感骨の節は注意が大切'), 0.8499047345647598)
# (('大分新聞', '1937年', '4月', '11-y-3_02', '著しく違ふ 家庭に不良見が多い\n何が彼らを罪に導いたか\nきも、いいwwwwww\nww.m'), 0.8491878166320749)
# (('大分合同新聞', '1958年', '7月', '22-a-1_03', '千害いよいよ深刻一\n特にひどい宇佐地方'), 0.8485901023982497)

# %% [markdown]
# ### どちらがいいか
# 重複がどうなのかを考慮していないため確定はできないが、連結したほうが量が多い<br>
# 時間に関しても、連結して１回にまとめた方が当然早い(そりゃそうだ)
