# %%
import os
import openpyxl

# %%
path_list = []

for curDir, dirs, files in os.walk("新聞"):
    #         print('=='*20)
    #         print('現在のフォルダ: ' + curDir)
    #         print('内包するフォルダ: ', end='')
    #         print(dirs)
    #         print('内包するファイル: ', end='')
    #         print(files)
    path = curDir + '\\'
    for file in files:
        path += file
        #             print('ファイルパス: ' + path)
        path_list.append(path)
        path = curDir + '\\'

# %%
headlines = []  # 格納用辞書

wb1 = openpyxl.load_workbook(path_list[0])
sheet = wb1['シート1']
# [社名、年、月、名前、見出し、ベクトル]
headlines = [(row[0].value, row[1].value, row[2].value, row[3].value, row[4].value) for row in sheet.rows]

wb2 = openpyxl.load_workbook(path_list[1])
sheet = wb2['シート1']
headlines2 = [(row[0].value, row[1].value, row[2].value, row[3].value, row[4].value) for row in sheet.rows]

# %%
headlines += headlines2

# %% [markdown]
# # 分かち書き

# %%
import MeCab as mc
import mojimoji
m = mc.Tagger("-Ochasen")

# %%
def mecab_tokenizer(text: str):
    """テキストを分かち書き

    Args:
        text (str): 分割したいテキスト

    Returns:
        [List(str,str,...)]: 分割後のテキスト
    """

    node = m.parseToNode(text)
    word_list = list()
    while node:
        if node.surface != "":
            res = node.feature.split(",")
            word_type = res[0]
            if word_type in ['名詞', "動詞", "形容詞", "副詞"]:  # 名詞, 動詞, 形容詞, 副詞のみを抽出
                basic_word = res[6]
                if basic_word != "*":
                    word_list.append(basic_word)
                else:
                    word_list.append('[UNK]')  # 未知語の場合は[UNK]トークンに置き換え
        node = node.next
        if node is None:
            break
    return word_list

# %%
def clean_text(text: str):
    """[summary]

    Args:
        text (str): 正規化するテキスト

    Returns:
        str: 正規化されたテキスト
    """

    text = mojimoji.han_to_zen(text, digit=False, ascii=False)  # 半角文字を全角文字に統一(数字, 英語以外)
    text = mojimoji.zen_to_han(text, kana=False)  # 全角文字を半角文字に統一(かな以外)
    text = text.lower()  # 小文字に統一
    return text

# %% [markdown]
# # ベクトル化

# %%
from gensim.models import KeyedVectors

# %%
import numpy as np

# %%
file_name = "jawiki.all_vectors.200d-002.txt"

model = KeyedVectors.load_word2vec_format(file_name)

# %%
def vectorize_word(text: str):
    """word2vecを用いたテキストのベクトル化

    元word_analysis()

    Args:
        text (str): ベクトル化するテキスト

    Returns:
        numpy.ndarray: テキストのベクトル
    """

    text = clean_text(text)

    V = list()  # 文章のベクトル(200次元)を格納

    # 文章の対して, 文章中の単語のベクトルの平均を求める処理を行う
    word_list = mecab_tokenizer(text)
    v = np.array([0.0] * 200)
    word_num = 0
    for word in word_list:
        try:
            v += np.array(model[word])
        except KeyError as error:
            continue
        except ValueError as verror:
            continue
        word_num += 1

    try:
        v = v / word_num
    except ZeroDivisionError as e:
        print(f'ZeroDivisionError: {e}')

    return v

def cos_sim(v1, v2):
    """2つのベクトルのcos類似度を計算

    Args:
        v1 (numpy.ndarray): word2vecによりベクトル化したテキスト1
        v2 (numpy.ndarray): word2vecによりベクトル化したテキスト2

    Returns:
        [float]: 二つのテキストのcos類似度
    """
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

# %%
def get_news_dict(filename: str):
    """テキストのparseとベクトル化

    エクセルから見出しのタイトル(識別番号？)とテキストを取り出しベクトル化して辞書として返す

    Args:
        similarity (SimilarityByWord2vec): sim_by_w2vオブジェクト<br>ベクトル化に使用
        filename (str): excelファイル名

    Returns:
        {(str, str, str, str): (str, numpy.ndarray)}: ひと月分の辞書<br>一つの要素に{(会社名、年、月、名前):(見出し, ベクトル)} -> の形で返す
    """

    wb = openpyxl.load_workbook(filename)
    sheet = wb['シート1']
    dict = {}  # 格納用辞書
    for row in sheet.rows:

        if row[4].value is not None:
            vector = vectorize_word(row[4].value)  # 見出しをベクトル化
            dict[(row[0].value, row[1].value, row[2].value, row[3].value)] = (row[4].value, vector)  # (会社名、年、月、名前)と(見出し、ベクトル)の組

    return dict

# %%
all_newspapers = [get_news_dict(path) for path in path_list]

headline_list = [(name[0], name[1], name[2], name[3], headline[0], headline[1]) for news in all_newspapers \
                for name, headline in news.items()]

del all_newspapers
# Out:
# C:\Users\kenbun\anaconda3\envs\nlp_bot\lib\site-packages\ipykernel_launcher.py:31: RuntimeWarning: invalid value encountered in true_divide

# %%
def get_all_similarity(headline_list, speech_text: str):
    """全見出しと発言の類似度分析

    全ての見出しと発言の類似度分析を行い, 類似度で降順にソートして返す

    Args:
        headline_list (List(str, str, tuple(str, numpy.ndarray))): 見出しをまとめたリスト<br> 
        ひとつの要素に(ファイルパス, 番号, (見出し, ベクトル)) -> の形で格納している
        speech_text (str): 類似度分析を行うテキスト

    Returns:
        List(tuple(tuple(str, str, str, str, str), float)): 類似度で降順にソートしたリスト [((会社名, 出版年, 出版付き, 番号, 見出し), 類似度)] -> この形になっている
    """
    
    # speech_text = '物価下がらなかったのね'
    speech_v = vectorize_word(speech_text)  # 発言をベクトル化

    similarity_dic = {}

    for company, year, month, day, headline, vector in headline_list:
        cs = cos_sim(speech_v, vector)  # 発言と見出しテキストのcos類似度を計算

        if cs >= 0.75:  # cos類似度が閾値以上であれば提示する見出しリストに加える
            similarity_dic[(company, year, month, day, headline)] = cs

    return sorted(similarity_dic.items(), key=lambda x: x[1], reverse=True)

# %%
import json

# %%
from PIL import Image

def make_json(sim_result):
    """類似度分析の結果をjsonファイルに書き出し

    Args:
        sim_result (List(tuple(tuple(str, str, str, str, str), float))): 類似度で降順にソートしたリスト [((会社名, 出版年, 出版付き, 番号, 見出し), 類似度)]

    Returns:
        flask.json.jsonify: json形式にparseされた類似度分析の結果
    """

    # 見出し画像を格納しているパス
    PIC_DIR_PATH = 'C:\\xampp\\htdocs\\KENBUN_landmark_Integration_nakano\\img\\landmark\\769_hl_10_trimLandmark\\scale0\\SNBN\\'

    result_list = []

    for result in sim_result:

        # if i < 10:  # 類似度が高い順に10個選出
        append_dic = {}  # 初期化

        company_name = result[0][0]  # 会社名
        year = result[0][1]  # 出版年
        month = result[0][2]  # 出版月
        day = result[0][3]  # 識別番号
        value = result[0][4].replace('\n', ' ')  # 見出しテキスト, 改行排除
        cs = result[1]  # cos類似度

        path = PIC_DIR_PATH + '\\'.join([company_name, year, month, day]) + '.jpg'
        if os.path.exists(path):
            img = Image.open(path)
            width, height = img.size  # 画像の幅と高さを取得
        else:  # エラーを避けるために0を代入
            width = height = 0

        append_dic = {"company_name": company_name,
                      "year": year,
                      "month": month,
                      "day": day,
                      "value": value,
                      "width": width,
                      "height": height
                      # "cos_sim": cs
                      }

        result_list.append(append_dic)

    # pprint.pprint(result_list) # 中身確認

    with open('test_result.json', 'w', encoding='utf-8') as f:
        json.dump(result_list, f, ensure_ascii=False, indent=4)  # 非asciiでjsonファイルに保存

# %%
test_text = '大分'

# %%
similarity_headlines = get_all_similarity(headline_list, test_text)

# %%
similarity_headlines
# Out:
# [(('大分合同新聞', '1942年', '7月', '23-a-3_18', '2にゃい\nに對策\n大分'), 1.0000000000000002),
#  (('大分合同新聞', '1943年', '8月', '26-a-3_11', '什隊 大分發招'), 1.0000000000000002),
#  (('大分合同新聞', '1946年', '6月', '27-a-2_01', '「生產大分,頗落'), 1.0000000000000002),
#  (('大分合同新聞', '1949年', '11月', '6-a-2_08', '大分縣將棋人會'), 1.0000000000000002),
#  (('大分合同新聞', '1949年', '2月', '25-a-2_01', '(サリナ大分) マオマオ'), 1.0000000000000002),
#  (('大分合同新聞', '1950年', '3月', '18-a-2_05', '大分縣圍大會附'), 1.0000000000000002),
#  (('大分合同新聞', '1950年', '3月', '19-y-2_06', '大分縣回售0'), 1.0000000000000002),
#  (('大分合同新聞', '1950年', '3月', '15-y-2_05', '大分縣回售AO'), 1.0000000000000002),
#  (('大分合同新聞', '1952年', '1月', '27-y-2_10', '大分别府对抗棋戰'), 1.0000000000000002),
#  (('大分合同新聞', '1952年', '2月', '13-y-2_08', '大分别府对抗棋戰'), 1.0000000000000002),
#  (('大分合同新聞', '1952年', '2月', '24-y-2-3_12', '大分别府对抗棋戰'), 1.0000000000000002),
#  (('大分合同新聞', '1953年', '6月', '8-a-3_13', '大分に'), 1.0000000000000002),
#  (('大分合同新聞', '1954年', '5月', '17-a-3_08', '大分\n6A='), 1.0000000000000002),
#  (('大分合同新聞', '1956年', '10月', '30-a-6_05', '【DIATCHY)\n大分IIュース ネ大テ'),
#   1.0000000000000002),
#  (('大分合同新聞', '1956年', '1月', '27-y-3_05', 'おおャリ、 いやマリク!!\n(大分・抜'),
#   1.0000000000000002),
#  (('大分合同新聞', '1957年', '6月', '2-y-1_06', '大分の'), 1.0000000000000002),
#  (('大分合同新聞', '1958年', '2月', '26-y-4_06', '(大分哥省就'), 1.0000000000000002),
#  (('大分合同新聞', '1958年', '3月', '14-y-4_04', '大分哥佐就'), 1.0000000000000002),
#  (('大分合同新聞', '1958年', '3月', '20-y-1_01', '大分卑人'), 1.0000000000000002),
#  (('大分合同新聞', '1959年', '6月', '22-y-2_09', '大分'), 1.0000000000000002),
#  (('大分合同新聞', '1960年', '11月', '6-a-4_01', '大分"'), 1.0000000000000002),
#  (('大分合同新聞', '1960年', '2月', '14-y-1_03', '大分ューア'), 1.0000000000000002),
#  (('大分合同新聞', '1960年', '2月', '19-y-1_01', '大分ュア'), 1.0000000000000002),
#  (('大分合同新聞', '1960年', '2月', '18-y-1_01', '大分ユーカ'), 1.0000000000000002),
#  (('大分合同新聞', '1960年', '2月', '20-y-1_01', '大分N-ア'), 1.0000000000000002),
#  (('大分合同新聞', '1961年', '10月', '24-a-3_01', '大分で'), 1.0000000000000002),
#  (('大分合同新聞', '1961年', '9月', '14-y-2_07', '(大分'), 1.0000000000000002),
#  (('大分合同新聞', '1962年', '12月', '11-y-1_06', '大分'), 1.0000000000000002),
#  (('大分合同新聞', '1962年', '12月', '10-y-1_09', '大分檢番'), 1.0000000000000002),
#  (('大分合同新聞', '1962年', '12月', '26-y-1_06', '大分'), 1.0000000000000002),
#  (('大分合同新聞', '1963年', '2月', '23-y-1_06', '大分'), 1.0000000000000002),
#  (('大分合同新聞', '1963年', '2月', '18-y-1_07', '大分\n= 1'), 1.0000000000000002),
#  (('大分合同新聞', '1963年', '7月', '1-y-3_01', '||||||\n大分'), 1.0000000000000002),
#  (('大分合同新聞', '1964年', '10月', '9-a-7_11', '大分の古戰場\n(34)'), 1.0000000000000002),
#  (('大分合同新聞', '1964年', '6月', '24-a-5_10', '大分6戰場'), 1.0000000000000002),
#  (('大分合同新聞', '1965年', '11月', '6-a-3_09', '大分ラカン'), 1.0000000000000002),
#  (('大分合同新聞', '1965年', '12月', '15-a-1_06', '大分バ'), 1.0000000000000002),
#  (('大分合同新聞', '1966年', '10月', '27-a-10_01', '| 大分\nOFF'), 1.0000000000000002),
#  (('大分合同新聞', '1966年', '12月', '11-a-12_03', 'ととも大分、'), 1.0000000000000002),
#  (('大分合同新聞', '1966年', '4月', '17-a-12_01', 'ととも大分'), 1.0000000000000002),
#  (('大分合同新聞', '1966年', '8月', '28-a-12_04', '(VSも大分)'), 1.0000000000000002),
#  (('大分合同新聞', '1966年', '8月', '17-a-9_01', '大分职位大混雜'), 1.0000000000000002),
#  (('大分合同新聞', '1967年', '11月', '10-y-3_01', '| ツイコンのマ大分'), 1.0000000000000002),
#  (('大分新聞', '1918年', '10月', '8-a-4_10', '大分縣下'), 1.0000000000000002),
#  (('大分新聞', '1918年', '11月', '27-a-2_01', '@大分縣蘭縣會'), 1.0000000000000002),
#  (('大分新聞', '1918年', '12月', '22-a-2_03', '| 大分縣縣會'), 1.0000000000000002),
#  (('大分新聞', '1918年', '12月', '17-a-2_02', '大分縣縣會'), 1.0000000000000002),
#  (('大分新聞', '1918年', '12月', '20-a-2_01', '大分縣縣會。'), 1.0000000000000002),
#  (('大分新聞', '1918年', '2月', '26-a-7_09', '大分縣一。\n高齡者逝'), 1.0000000000000002),
#  (('大分新聞', '1923年', '9月', '26-f-2_01', '带HNH\n大分縣'), 1.0000000000000002),
#  (('大分新聞', '1929年', '11月', '23-a-1_08', '大分縣下の\n獻金'), 1.0000000000000002),
#  (('大分新聞', '1932年', '12月', '22-a-2_06', '「大分縣會\n一向進玄幻委員會'),
#   1.0000000000000002),
#  (('大分新聞', '1932年', '5月', '30-a-3_14', '長咀競會 大分會館にて'), 1.0000000000000002),
#  (('大分新聞', '1933年', '3月', '30-a-3_09', '大分檢藝妓 溫習會'), 1.0000000000000002),
#  (('大分新聞', '1934年', '12月', '27-a-1_02', '大分縣會如斬。\nn)'), 1.0000000000000002),
#  (('大分新聞', '1934年', '12月', '26-a-1_02', '大分縣會斬。'), 1.0000000000000002),
#  (('大分新聞', '1934年', '12月', '19-a-4_02', '大分俳」\n析網'), 1.0000000000000002),
#  (('大分新聞', '1934年', '6月', '17-a-2_13', '> 大分\n淺利'), 1.0000000000000002),
#  (('大分新聞', '1936年', '10月', '23-y-3_02', '大分圍大會ing」'), 1.0000000000000002),
#  (('大分新聞', '1936年', '10月', '14-y-3_01', '大分圍大會;'), 1.0000000000000002),
#  (('大分新聞', '1936年', '11月', '14-y-2_13', '大分縣無盡協 會總會'), 1.0000000000000002),
#  (('大分新聞', '1936年', '4月', '1-a-2_10', '產組大分支會'), 1.0000000000000002),
#  (('大分新聞', '1936年', '8月', '24-a-3_02', '大分縣の新產業'), 1.0000000000000002),
#  (('大分新聞', '1937年', '3月', '15-a-2_10', '大分會所 圍碁大會'), 1.0000000000000002),
#  (('大分新聞', '1937年', '4月', '28-a-1_08', '大分'), 1.0000000000000002),
#  (('大分新聞', '1937年', '5月', '1-y-4_01', '大分批把 豐作'), 1.0000000000000002),
#  (('大分新聞', '1939年', '12月', '21-a-4_02', '大分'), 1.0000000000000002),
#  (('大分新聞', '1939年', '8月', '14-a-1_07', '大分'), 1.0000000000000002),
#  (('大分新聞', '1951年', '9月', '20-a-3_08', 'ラッォ大分 |'), 1.0000000000000002),
#  (('大分新聞', '1953年', '11月', '27-a-2_06', '大分にジフテリヤ'), 1.0000000000000002),
#  (('日田新報', '1902年', '12月', '1-a-11_01', '●大分縣會 -'), 1.0000000000000002),
#  (('豊州新報', '1928年', '3月', '24-a-3_06', '大分縣 醫師會'), 1.0000000000000002),
#  (('豊州新報', '1931年', '6月', '9-a-4_09', '大分のダベー\nRUNITRomi.io'),
#   1.0000000000000002),
#  (('豊州新報', '1932年', '10月', '12-a-2_12', '大分の 檢增殖獎勵'), 1.0000000000000002),
#  (('豊州新報', '1933年', '10月', '6-a-7_16', '大分営の'), 1.0000000000000002),
#  (('豊州新報', '1933年', '4月', '7-a-7_17', '大分日白大會'), 1.0000000000000002),
#  (('豊州新報', '1935年', '10月', '4-a-2_12', '大分縣無盡協 會總會'), 1.0000000000000002),
#  (('豊州新報', '1936年', '4月', '29-a-2_09', '「プチ\n大分でう\n臺博'), 1.0000000000000002),
#  (('豊州新報', '1937年', '7月', '26-a-2_07', '大分縣\nME'), 1.0000000000000002),
#  (('豊州新報', '1941年', '1月', '31-a-4_07', 'AT\n大分獵友會\nAX'), 1.0000000000000002),
#  (('大分新聞', '1929年', '12月', '6-a-5_05', '熊本大分兩 縣交會'), 0.9622988945082345),
#  (('大分合同新聞', '1952年', '11月', '12-a-2_10', '大分地の\n大分'), 0.9496731524264892),
#  (('大分合同新聞', '1965年', '5月', '10-a-3_02', '大分、佐賀に'), 0.9467715278165136),
#  (('大分合同新聞', '1951年', '9月', '23-y-2_13', '大分ドレ\n大分ド'), 0.9440577454290544),
#  (('大分新聞', '1928年', '9月', '7-a-3_12', '大分福岡\n故請所發='), 0.9422966471812165),
#  (('大分合同新聞', '1948年', '6月', '22-a-2_06', "大分と長崎\ndy\n'ー\n)までの"),
#   0.9336139597676051),
#  (('大分合同新聞', '1953年', '9月', '1-a-2_04', '| 世方兴\n大分県大分月 大分类大分土地\n大分'),
#   0.9306914185647571),
#  (('大分新聞', '1936年', '12月', '11-a-3_16', 'IMANAYI\n中津對大分の'),
#   0.9299999973494765),
#  (('大分合同新聞', '1942年', '4月', '24-a-4_01', '|九州 大分縣'), 0.9289710371828334),
#  (('豊州新報', '1937年', '10月', '4-a-4_11', '大分 九州ラヂオ'), 0.9289710371828334),
#  (('大分合同新聞', '1965年', '11月', '20-y-3_03', '大分鶴崎'), 0.9262443166543646),
#  (('日曜大分', '1935年', '7月', '8-a-2_02', '大分s鳥栖1'), 0.9221854710071058),
#  (('豊州新報', '1935年', '5月', '8-a-2_17', '大分、別府を、 荒した新\n大分に出'),
#   0.9172705184923708),
#  (('大分合同新聞', '1955年', '8月', '2-y-1_06', '| 東京の - 大分の'), 0.9104749864471107),
#  (('大分新聞', '1925年', '3月', '13-a-7_14', '大分ても\n水涸れ'), 0.8984419167822509),
#  (('大分合同新聞', '1963年', '7月', '20-a-6_01', 'MWLALUEEN\n大分,熊本・ヘリの'),
#   0.8941307048551551),
#  (('大分合同新聞', '1958年', '4月', '6-y-5_03', 'とも大分'), 0.8902404891049404),
#  (('大分合同新聞', '1948年', '7月', '18-a-2_01', '| 大分別府風」'), 0.8896536450202718),
#  (('大分合同新聞', '1953年', '10月', '20-a-1_18', 'てナーいる。\n大分、別府で'),
#   0.8881314698873953),
#  (('大分新聞', '1929年', '11月', '23-a-11_05', '大分高商音樂大會\n大分、別府、中津で'),
#   0.8867525591295504),
#  (('豊州新報', '1929年', '10月', '12-a-9_09', '會場 大分縣公會堂 主催 大分商工會」'),
#   0.8867233952912299),
#  (('大分合同新聞', '1964年', '2月', '19-y-3_07', 'バーに売りとばす。\n大分や北九州から'),
#   0.8863817734139173),
#  (('豊州新報', '1933年', '1月', '27-a-3_08', '、別府大分市で'), 0.8841093713028458),
#  (('大分新聞', '1937年', '7月', '2-y-1_09', '大分、日田間'), 0.8840630271373394),
#  (('大分新聞', '1925年', '10月', '3-a-7_14', '大分別府兩市で\n大モグリを動・'),
#   0.8836054434620517),
#  (('大分合同新聞', '1950年', '6月', '10-y-1_11', '大分別府新義'), 0.8818642775379907),
#  (('大分合同新聞', '1964年', '11月', '2-a-1_07', '大分・熊本・長崎 第4回九州橫斷职佐'),
#   0.8805375879925211),
#  (('大分合同新聞', '1965年', '1月', '28-a-9_01', '大分福同桌》 */'), 0.878937028754697),
#  (('大分合同新聞', '1967年', '3月', '10-y-3_04', '大分、日田でもやった'), 0.8787284883605777),
#  (('豊州新報', '1934年', '3月', '26-a-4_14', '大分縣社會課 " 大分新聞社\n主编经'),
#   0.8776545913944506),
#  (('大分合同新聞', '1946年', '6月', '29-a-2_04', '盡大分合同新聞社 授大分'), 0.8770743728212228),
#  (('大分新聞', '1930年', '9月', '11-a-5_11', '大分縣參事會'), 0.8744507834477631),
#  (('田舎新聞', '1880年', '6月', '12-a-1_01', '大分縣錄事'), 0.8744507834477631),
#  (('豊州新報', '1930年', '7月', '17-a-9_07', 'るであらう。\n大分縣參事\n11.\n1 ----'),
#   0.8744507834477631),
#  (('豊州新報', '1932年', '1月', '20-a-4_09', '大分那間斷部'), 0.8740916520337113),
#  (('大分合同新聞', '1960年', '3月', '18-y-4_01', '大分、鶴崎両市'), 0.8737685488772978),
#  (('大分合同新聞', '1954年', '10月', '6-y-1_07', '大分高'), 0.8735482270178524),
#  (('大分新聞', '1937年', '6月', '5-a-2_04', '大分高么附屬0'), 0.8735482270178524),
#  (('大分新聞', '1938年', '2月', '2-y-3_06', '大分高雜記單校'), 0.8735482270178524),
#  (('豊州新報', '1940年', '9月', '15-a-4_08', '大分有り'), 0.871829866665552),
#  (('大分合同新聞', '1953年', '2月', '19-a-2_11', '大分縣 主催 大分縣農政會議\n大分合同新聞社'),
#   0.8707027064595059),
#  (('大分合同新聞', '1943年', '6月', '29-a-3_06', '大分地方の'), 0.8683589742183324),
#  (('大分新聞', '1929年', '5月', '10-a-2_15', 'mm4\n大分地方は りで'), 0.8683589742183324),
#  (('豊州新報', '1935年', '3月', '6-a-4_07', '大分地方辯護'), 0.8683589742183324),
#  (('豊州新報', '1936年', '6月', '15-a-7_04', '大分地方'), 0.8683589742183324),
#  (('大分新聞', '1932年', '3月', '2-a-1_09', '一個處產物販賣高,\n大分縣法第三'),
#   0.8677036155218913),
#  (('大分合同新聞', '1956年', '8月', '16-a-2_07', '大分県に中央会 大分泉 大分会 大分合同斯壯'),
#   0.8674465358270361),
#  (('大分合同新聞', '1952年', '12月', '30-y-1_07', '大分楽'), 0.8674121268781448),
#  (('大分新聞', '1934年', '6月', '11-a-1_07', 'カートニーです。\n| 大分不野及び'),
#   0.8670003808511118),
#  (('豊州新報', '1931年', '6月', '20-a-4_11', '別府、大分の 「味の素'), 0.8664230337295351),
#  (('大分合同新聞', '1958年', '6月', '3-a-1_05', '大分鶴崎臨時'), 0.8648078765592175),
#  (('大分合同新聞', '1958年', '9月', '3-a-1_05', '大分鶴崎臨時'), 0.8648078765592175),
#  (('大分合同新聞', '1966年', '9月', '17-a-8_05', '大分の美'), 0.8647979620242361),
#  (('大分合同新聞', '1956年', '6月', '15-a-3_08', '大分前の'), 0.8645257733216992),
#  (('大分合同新聞', '1964年', '7月', '9-a-1_01', '大分前の'), 0.8645257733216992),
#  (('豊州新報', '1937年', '8月', '20-a-5_02', '大分通り 九州ラチオ'), 0.8641055228497425),
#  (('大分合同新聞', '1963年', '4月', '11-y-1_03', '大分地区'), 0.8640518097815454),
#  (('大分合同新聞', '1965年', '2月', '24-a-4_02', '大分地区'), 0.8640518097815454),
#  (('大分新聞', '1936年', '5月', '7-y-2_22', '大分新'), 0.8636559573713167),
#  (('大分合同新聞', '1965年', '7月', '29-a-9_07', '活気づく大分 別府'), 0.863268484602966),
#  (('大分新聞', '1937年', '6月', '10-y-3_04', '大分縣ZOi物語!。'), 0.8631910617686274),
#  (('豊州新報', '1927年', '7月', '11-y-2_03', '全國釀造大會 熊本縣側の開催說, 大分、佐賀、長崎各様の反對'),
#   0.8631084491691056),
#  (('大分新聞', '1931年', '6月', '18-a-4_06', '『大分小唄」の練習。\n大分檢番の樓上で'),
#   0.862551258334017),
#  (('大分合同新聞', '1952年', '3月', '12-y-2-2_05', '大分别府对抗棋戰一'), 0.8620817206892153),
#  (('大分合同新聞', '1958年', '3月', '13-y-1_01', '大分卑人一'), 0.8620817206892153),
#  (('大分合同新聞', '1958年', '3月', '19-y-1_02', '||大分卑人一'), 0.8620817206892153),
#  (('大分合同新聞', '1958年', '3月', '18-y-1_02', '大分卑人一'), 0.8620817206892153),
#  (('大分合同新聞', '1962年', '4月', '13-a-7_10', '生ワクきょ」 一う大分へ'), 0.8620817206892153),
#  (('豊州新報', '1929年', '7月', '27-a-2_20', '不按\n空氣漂\n大分縣膽'), 0.8619245407099845),
#  (('大分新聞', '1933年', '7月', '16-a-3_09', '大分師範の遠泳\n大分別府間を突席'),
#   0.8611345154815346),
#  (('大分合同新聞', '1955年', '10月', '2-y-4_01', '大分泉新闻史'), 0.8602308752363055),
#  (('大分新聞', '1932年', '1月', '5-y-1_09', 'ーーーーーーっす。\n大分大では 御用始め'),
#   0.8600332617467003),
#  (('大分合同新聞', '1955年', '7月', '31-a-3_03', '大分の最アパー ト入る'), 0.8596305703694975),
#  (('豊州新報', '1937年', '3月', '18-a-4_05', '|別府博プロローグ 躍進!產業大分 の誇り大分縣舘'),
#   0.8593086759329691),
#  (('大分合同新聞', '1958年', '12月', '11-y-2_01', '二の\nまった\nサンプ\nチャー\n大分」'),
#   0.8585702955341655),
#  (('大分合同新聞', '1955年', '7月', '13-y-3_11', '大分別府 が10円に'), 0.8584391684426753),
#  (('豊州新報', '1936年', '7月', '29-a-4_08', '大分車掌優勝\n6–1大分驛敗る|'),
#   0.8582384465953992),
#  (('大分合同新聞', '1944年', '3月', '31-a-3_04', '- あす時の新發足\n大分經事と大分第二工業'),
#   0.8577412812635428),
#  (('豊州新報', '1942年', '1月', '24-a-2_11', '大分別府兩市 共催歡迎會.'), 0.8566878083509861),
#  (('豊州新報', '1936年', '5月', '29-a-3_05', '大連大分縣人 會總會'), 0.8556467311379331),
#  (('大分合同新聞', '1944年', '2月', '29-y-2_05', '「大分駅前\nのに、'), 0.8555371505730845),
#  (('大分合同新聞', '1966年', '5月', '11-y-3_04', '大分駅前に渡線橋'), 0.8555371505730845),
#  (('大分新聞', '1922年', '11月', '28-a-3_06', '通常大分縣會 第四日歲出經常部第四部'),
#   0.8554453183023832),
#  (('大分新聞', '1922年', '12月', '5-a-2_12', '大分通常縣會\n第九日目產業費仍續'),
#   0.8554453183023832),
#  (('大分新聞', '1922年', '12月', '9-a-3_05', '大分通常縣會\n「第十日前生气荒費可大'),
#   0.8554453183023832),
#  (('大分新聞', '1922年', '12月', '3-a-2_07', '大分通常縣會'), 0.8554453183023832),
#  (('大分新聞', '1923年', '12月', '1-a-3_06', '通常大分縣會 (第四已縣會議諸費外四案'),
#   0.8554453183023832),
#  (('日田新報', '1900年', '12月', '15-a-2_01', '通常大分縣會'), 0.8554453183023832),
#  (('大分合同新聞', '1963年', '10月', '17-y-3_11', '大分入り'), 0.8546275937969181),
#  (('大分合同新聞', '1942年', '12月', '24-a-3_12', '即泳會 大分會議所'), 0.8546146069604386),
#  (('大分新聞', '1936年', '12月', '17-a-2_11', '大分會議所の會計'), 0.8546146069604386),
#  (('日曜大分', '1936年', '3月', '30-a-1_01', '大分e私'), 0.8545621457650306),
#  (('大分新聞', '1931年', '3月', '6-a-4_09', 'あすは地久節.\n大分、別府の拜賀式'),
#   0.8545000986711806),
#  (('大分合同新聞', '1963年', '1月', '27-y-3_04', '| 別府と大分で相つぎ強盗」'),
#   0.8542896242674356),
#  (('大分新聞', '1953年', '10月', '3-a-2_06', '大分カン一本倉'), 0.8541072259179595),
#  (('大分新聞', '1930年', '10月', '2-a-3_05', '大分產院\n名っけず'), 0.8536779054749044),
#  (('両豊新報', '1938年', '5月', '25-a-4_01', '關西大分縣人會 大阪盛產聲舉。'), 0.8532964654030766),
#  (('大分新聞', '1938年', '1月', '7-a-1_09', '主懇談會\n大分・中津m'), 0.8532854992540263),
#  (('豊州新報', '1933年', '2月', '4-a-3_12', 'Fum\n調查票互審會 大分、玖珠兩郡と大分市\n日購公會堂で開く'),
#   0.8530943314317998),
#  (('大分合同新聞', '1966年', '8月', '4-a-5_03', 'まさに 大分テー'), 0.8528567253084474),
#  (('大分合同新聞', '1956年', '9月', '30-a-2_05', '大分 熊本対県\n九州橫斷歇后'),
#   0.8528156261749466),
#  (('豊州新報', '1940年', '2月', '2-a-4_13', '「宮崎大分\n雨間にも臨列'), 0.8521700542208583),
#  (('豊州新報', '1939年', '4月', '11-a-1_03', '入營者宿舍割\n大分、別府兩市內S'),
#   0.8520127563700463),
#  (('大分合同新聞', '1960年', '7月', '14-y-2_02', '大分の話'), 0.85199954892809),
#  (('大分新聞', '1925年', '7月', '23-a-4_11', '大分牛*賣|\n香川縣にもまた發生'),
#   0.8517584628804095),
#  (('大分新聞', '1930年', '4月', '12-a-5_15', '小泉遞和 大分、宮崎縣'), 0.8513425427627853),
#  (('大分合同新聞', '1965年', '9月', '24-y-4_05', '大分が九州代表に 警'), 0.8511639218393899),
#  (('豊州新報', '1927年', '3月', '10-a-2_06', '大分縣下 「徵兵檢查日割\n| 大分久留米兩聯隊區管内'),
#   0.8509901383073161),
#  (('豊州新報', '1932年', '7月', '30-a-7_10', '・大分縣軟式野球\n大分地方大會\n1 |'),
#   0.8507106111037128),
#  (('大分新聞', '1936年', '4月', '10-y-2_14', '春は大分縣へ'), 0.8506940964565518),
#  (('豊州新報', '1936年', '4月', '10-a-4_03', 'ドー39mm\n春は大分縣へ'), 0.8506940964565518),
#  (('大分合同新聞', '1959年', '1月', '11-y-1_02', '大分女性'), 0.8497491129879103),
#  (('大分合同新聞', '1962年', '4月', '6-a-6_08', '額LV拉力FW\n大分女子高、大分中央'),
#   0.8494386125642036),
#  (('大分合同新聞', '1966年', '6月', '7-a-6_04', '「大分」人\n0- 30 タイアです'),
#   0.8491837009035615),
#  (('大分新聞', '1921年', '9月', '27-a-8_02', '大分那 澳軍人會總會'), 0.8491837009035615),
#  (('大分新聞', '1936年', '4月', '9-y-1_11', '大分鹽小賣人'), 0.8491837009035615),
#  (('豊州新報', '1936年', '6月', '25-a-3_08', '全大分縣少年劍道大會'), 0.8481254744773802),
#  (('大分合同新聞', '1957年', '2月', '15-y-4_02', 'ジオ大分のNHK)\n15日\nne'),
#   0.8481131805596024),
#  (('大分新聞', '1935年', '9月', '5-y-2_06', '+11日\n大分縣の發展'), 0.8481131805596024),
#  (('大分合同新聞', '1961年', '4月', '7-y-2_06', '大分市内ペー'), 0.8475662369612498),
#  (('大分合同新聞', '1962年', '8月', '5-a-1_08', 'mitambNR\n大分市内で'),
#   0.8475662369612498),
#  (('大分新聞', '1925年', '9月', '6-a-4_10', '大分市内と\nロバートンのROM'), 0.8475662369612498),
#  (('大分新聞', '1927年', '1月', '27-a-4_04', '大分市内の 就學兒童\n121011'),
#   0.8475662369612498),
#  (('大分新聞', '1928年', '9月', '22-a-2_13', '熊本齡團'), 0.8471250251609099),
#  (('大分新聞', '1930年', '12月', '20-a-1_08', '于是,\n熊本縣會'), 0.8471250251609099),
#  (('大分新聞', '1932年', '12月', '19-a-2_06', '熊本縣會'), 0.8471250251609099),
#  (('豊州新報', '1931年', '2月', '14-a-2_14', '(熊本'), 0.8471250251609099),
#  (('豊州新報', '1938年', '4月', '15-a-2_06', 'わガラた\n熊本へ轉出'), 0.8471250251609099),
#  (('大分新聞', '1935年', '7月', '4-a-2_08', '- 大分、鶴崎問」 自動車合同\n大分バに權利譲渡'),
#   0.846835966144748),
#  (('大分新聞', '1930年', '2月', '1-a-9_02', '大分徘壇\n日田亞視選'), 0.8466725918097496),
#  (('大分合同新聞', '1966年', '2月', '5-a-9_01', '中津-大分は400円'), 0.8465812683248549),
#  (('大分合同新聞', '1960年', '5月', '17-y-2_04', '大分合同臼杵地聚四戰\n||||-'),
#   0.8464236147132272),
#  (('豊州新報', '1931年', '5月', '29-a-2_14', '减條橫額\n大分縣勝て見る'), 0.8463691670380867),
#  (('大分新聞', '1936年', '2月', '23-g-2_06', '大分縣の當選者'), 0.84522816367176),
#  (('豊州新報', '1940年', '11月', '29-a-3_06', '大分縣の參列者\nThanne'), 0.84522816367176),
#  (('大分合同新聞', '1961年', '10月', '19-a-11_01', '大分県'), 0.8450012723838962),
#  (('大分合同新聞', '1964年', '7月', '25-a-2_01', '大分県から'), 0.8450012723838962),
#  (('大分合同新聞', '1943年', '2月', '1-a-1_09', '大分合同新阳社'), 0.8448101835272017),
#  (('大分合同新聞', '1960年', '10月', '2-a-4_01', '大分合同\nへの支'), 0.8448101835272017),
#  (('大分合同新聞', '1960年', '6月', '20-a-4_01', '大分合同'), 0.8448101835272017),
#  (('大分合同新聞', '1962年', '7月', '21-y-3_04', 'PHITEKITh\n大分合同'),
#   0.8448101835272017),
#  (('大分合同新聞', '1963年', '3月', '29-y-1_12', '大分合同'), 0.8448101835272017),
#  (('大分合同新聞', '1964年', '7月', '9-a-9_03', '大分合同'), 0.8448101835272017),
#  (('大分合同新聞', '1966年', '2月', '9-a-5_09', '大分合同职业'), 0.8448101835272017),
#  (('豊州新報', '1938年', '6月', '4-a-2_17', 'ATREENS\n大分合同タク'), 0.8448101835272017),
#  (('豊州新報', '1935年', '1月', '7-a-2_08', '大分に一\n鶴崎町へ\n鶴崎倶樂部で休憩 ー再び大分ヘ'),
#   0.8445265390569436),
#  (('大分新聞', '1936年', '6月', '18-y-1_11', '大分 別府 中津 三市小賣物價比較\n依然中津办割安'),
#   0.8441721210118132),
#  (('大分合同新聞', '1966年', '5月', '11-a-4_01', 'やすら大分国'), 0.8436563865465492),
#  (('大分合同新聞', '1966年', '5月', '5-a-6_02', '大分国'), 0.8436563865465492),
#  (('大分合同新聞', '1943年', '2月', '1-a-4_07', '大分市'), 0.8435632770673006),
#  (('大分合同新聞', '1947年', '12月', '26-a-2_06', 'NYN\n大分市のク'), 0.8435632770673006),
#  (('大分合同新聞', '1954年', '2月', '13-a-2_08', '大分市でー'), 0.8435632770673006),
#  (('大分合同新聞', '1957年', '3月', '28-y-3_13', '(大分市'), 0.8435632770673006),
#  (('大分合同新聞', '1961年', '3月', '21-y-3_01', '大分市历年'), 0.8435632770673006),
#  (('大分合同新聞', '1964年', '1月', '29-a-7_05', '大分市でも'), 0.8435632770673006),
#  (('大分合同新聞', '1965年', '9月', '8-a-9_09', '大分市の大 マートで'), 0.8435632770673006),
#  (('大分合同新聞', '1966年', '10月', '22-y-3_02', '24\n大分市'), 0.8435632770673006),
#  (('大分合同新聞', '1967年', '4月', '1-y-2_01', '大分市)'), 0.8435632770673006),
#  (('大分新聞', '1919年', '1月', '28-a-3_03', '> 落\n大分市廳舍'), 0.8435632770673006),
#  (('大分新聞', '1919年', '2月', '4-a-3_05', 'トーマ\n- 大分市其經營。'), 0.8435632770673006),
#  (('大分新聞', '1919年', '2月', '21-a-4_06', '大分市其經營'), 0.8435632770673006),
#  (('大分新聞', '1919年', '9月', '19-a-3_04', '大分市會'), 0.8435632770673006),
#  (('大分新聞', '1920年', '5月', '26-a-4_11', '大分市。'), 0.8435632770673006),
#  (('大分新聞', '1921年', '5月', '28-a-2_02', '大分市縣公會堂々於て'), 0.8435632770673006),
#  (('大分新聞', '1921年', '6月', '2-a-3_09', '大分市縣公會堂於心'), 0.8435632770673006),
#  (('大分新聞', '1931年', '12月', '13-a-3_11', '大分市會'), 0.8435632770673006),
#  (('大分新聞', '1933年', '10月', '8-a-1_12', '大分市會'), 0.8435632770673006),
#  (('大分新聞', '1933年', '3月', '9-a-2_09', '九州洋服商大會\n來年は大分市にて'),
#   0.8435632770673006),
#  (('大分新聞', '1934年', '1月', '30-y-2_15', '大分市でも 數名檢舉'), 0.8435632770673006),
#  (('大分新聞', '1934年', '5月', '8-y-1_08', 'In\n大分市會'), 0.8435632770673006),
#  (('大分新聞', '1936年', '9月', '23-a-1_10', '大分市會'), 0.8435632770673006),
#  (('大分新聞', '1937年', '10月', '1-a-2_06', 'ーーーーーーーー!VOLKS\n大分市の新區長'),
#   0.8435632770673006),
#  (('大分新聞', '1937年', '12月', '11-a-4_05', '三市學事協議會\nH4大分市飞開'),
#   0.8435632770673006),
#  (('大分新聞', '1938年', '10月', '15-a-2_05', '大分市會協'), 0.8435632770673006),
#  (('大分新聞', '1938年', '4月', '1-y-2_07', '大分市赛事\nTY'), 0.8435632770673006),
#  (('大分新聞', '1939年', '10月', '7-y-1_09', '大分市會流會才'), 0.8435632770673006),
#  (('大分新聞', '1941年', '10月', '16-a-2_08', '大分市爱梵會'), 0.8435632770673006),
#  (('豊州新報', '1927年', '7月', '17-a-4_11', '大分市に\nチブス」'), 0.8435632770673006),
#  (('豊州新報', '1928年', '10月', '30-a-7_11', '大分市网'), 0.8435632770673006),
#  (('豊州新報', '1928年', '3月', '18-a-2_07', '大分市會'), 0.8435632770673006),
#  (('豊州新報', '1930年', '7月', '29-a-2_11', '大分市の'), 0.8435632770673006),
#  (('豊州新報', '1931年', '6月', '6-a-4_10', '大分市 產婆會'), 0.8435632770673006),
#  (('豊州新報', '1932年', '4月', '23-a-1_11', '大分市の 囑託齒科醫\nTANT'),
#   0.8435632770673006),
#  (('豊州新報', '1932年', '5月', '29-a-3_13', '大分市會'), 0.8435632770673006),
#  (('豊州新報', '1935年', '4月', '24-a-3_08', '一件無際學新里譜]\n大分市徵兵 檢查'),
#   0.8435632770673006),
#  (('豊州新報', '1936年', '6月', '28-a-2_10', '大分市會'), 0.8435632770673006),
#  (('豊州新報', '1937年', '10月', '27-a-2_10', '大分市蕭品'), 0.8435632770673006),
#  (('豊州新報', '1937年', '5月', '18-a-2_03', '大分市廳舍聽祝辭'), 0.8435632770673006),
#  (('豊州新報', '1940年', '10月', '12-a-2_06', '大分市'), 0.8435632770673006),
#  (('豊州新報', '1940年', '7月', '7-a-4_16', '大分市の'), 0.8435632770673006),
#  (('豊州新報', '1940年', '8月', '30-a-3_09', '大分市の區'), 0.8435632770673006),
#  (('豊州新報', '1941年', '1月', '23-a-4_10', '大分市の 就學兒童'), 0.8435632770673006),
#  (('大分新聞', '1899年', '6月', '28-a-1_02', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1929年', '9月', '7-a-1_01', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1931年', '6月', '28-a-8_03', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1932年', '7月', '24-y-1_02', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1933年', '7月', '2-y-1_02', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1934年', '7月', '26-y-1_01', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1935年', '11月', '17-y-1_01', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1935年', '3月', '12-y-1_01', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1935年', '4月', '14-y-1_01', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1936年', '12月', '12-y-1_01', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1936年', '1月', '10-y-1_01', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1936年', '4月', '11-y-1_01', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1936年', '6月', '9-y-1_02', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1937年', '8月', '8-y-1_01', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1938年', '10月', '19-a-2_17', '大分新聞を訪'), 0.8433204254715226),
#  (('大分新聞', '1938年', '4月', '11-y-1_08', '「大分新聞を\nるな!'), 0.8433204254715226),
#  (('大分新聞', '1939年', '3月', '1-y-1_01', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1939年', '8月', '23-y-1_01', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1939年', '8月', '11-y-1_02', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1941年', '8月', '11-a-1_01', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1941年', '9月', '16-a-1_03', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1941年', '9月', '23-y-1_01', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1951年', '11月', '7-a-1_03', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1953年', '1月', '12-a-1_01', '大分新聞'), 0.8433204254715226),
#  (('大分新聞', '1938年', '10月', '28-a-2_09', '港灣修築座談會\n・大分、鶴崎、津久見で'),
#   0.8431219779245607),
#  (('豊州新報', '1931年', '4月', '19-a-2_08', '南大分 i. ii'), 0.8427989436486671),
#  (('大分新聞', '1930年', '3月', '20-a-6_03', '大分工業'), 0.8427270499381325),
#  (('大分新聞', '1936年', '5月', '6-y-2_13', '大分工業鮮滿'), 0.8427270499381325),
#  (('大分新聞', '1937年', '5月', '18-a-3_06', '大分工業'), 0.8427270499381325),
#  (('大分新聞', '1937年', '5月', '22-a-3_13', '大分工業'), 0.8427270499381325),
#  (('大分新聞', '1937年', '7月', '15-a-3_03', '大分工業'), 0.8427270499381325),
#  (('豊州新報', '1935年', '4月', '24-a-4_08', '大分工業の'), 0.8427270499381325),
#  (('大分合同新聞', '1962年', '3月', '24-a-5_01', '大分日田で火事'), 0.8423686611607369),
#  (('大分新聞', '1941年', '7月', '18-a-3_06', '大分商業優勝\nNo大分工'), 0.842233887917351),
#  (('大分新聞', '1937年', '2月', '25-a-4_05', '大分漢詩境\n亲民黨思'), 0.8421166962965603),
#  (('大分合同新聞', '1961年', '1月', '1-a-17_02', '大分の思い'), 0.8420027541251656),
#  (('大分合同新聞', '1967年', '7月', '15-a-11_01', 'できるか大分演'), 0.8418753719326703),
#  (('大分新聞', '1934年', '12月', '24-a-1_07', '大分縣會斬5\n衛藤\n" |\nFal'),
#   0.8415496881837946),
#  (('豊州新報', '1936年', '8月', '30-a-4_05', '大分から熊本 時計泥'), 0.8414840007477588),
#  (('大分合同新聞', '1962年', '7月', '24-a-3_01', '中津ュースも出発\nニュースから大分'),
#   0.8412826007784796),
#  (('豊州新報', '1932年', '2月', '3-a-2_11', '大分管内の 略聯合會 大分南延岡'), 0.8404801712871385),
#  (('大分新聞', '1933年', '10月', '28-a-2_06', '大分メリヂスト教」'), 0.8402357196186823),
#  (('大分合同新聞', '1961年', '3月', '5-y-1_12', '大分职·大分市 後设 大分商工会議所'),
#   0.8392750652405592),
#  (('豊州新報', '1937年', '10月', '21-a-4_13', '大分人形 | 大分市が昭7'), 0.8390923164110169),
#  (('大分合同新聞', '1961年', '7月', '6-a-5_03', '大分、別府も同時に充実'), 0.8389658497135002),
#  (('大分合同新聞', '1949年', '3月', '29-a-2_08', '- 出発は大分'), 0.8388959154830252),
#  (('大分合同新聞', '1952年', '9月', '7-a-4_02', 'ことも大分'), 0.8386378122353201),
#  (('大分合同新聞', '1959年', '7月', '4-y-5_03', 'ことも。 (大分)'), 0.8386378122353201),
#  (('大分合同新聞', '1959年', '7月', '11-y-5_03', '(ことも大分'), 0.8386378122353201),
#  (('大分合同新聞', '1961年', '11月', '26-a-9_03', 'ことも大分'), 0.8386378122353201),
#  (('大分合同新聞', '1963年', '1月', '13-a-9_03', '(ことも大分)'), 0.8386378122353201),
#  (('大分合同新聞', '1963年', '2月', '3-a-9_01', '(ことも大分)'), 0.8386378122353201),
#  (('大分合同新聞', '1964年', '9月', '6-a-12_03', '(ことも大分'), 0.8386378122353201),
#  (('大分合同新聞', '1965年', '5月', '16-a-12_03', 'ことも大分'), 0.8386378122353201),
#  (('大分合同新聞', '1966年', '11月', '13-a-12_03', '(ことも大分)'), 0.8386378122353201),
#  (('大分合同新聞', '1966年', '12月', '18-a-12_03', 'ことも大分。'), 0.8386378122353201),
#  (('大分合同新聞', '1966年', '1月', '9-a-12_02', '(ことも大分)'), 0.8386378122353201),
#  (('大分新聞', '1930年', '1月', '18-a-9_02', '大分俳壇」\n日田亞词'), 0.838535854894313),
#  (('大分合同新聞', '1953年', '11月', '14-y-1_11', '大分高校生'), 0.8382457897157638),
#  (('大分合同新聞', '1953年', '6月', '14-a-1_12', 'ラジオ大分'), 0.8381957057411448),
#  (('大分合同新聞', '1954年', '2月', '9-y-2_03', 'ラジオ大分(\n)NHE\nБаскс\n100\n15'),
#   0.8381957057411448),
#  (('大分合同新聞', '1954年', '2月', '23-y-2_05', '(ラジオ大分)\nsnake'),
#   0.8381957057411448),
#  (('大分合同新聞', '1954年', '5月', '5-y-2_05', 'ラジオ大分の各\nST'), 0.8381957057411448),
#  (('大分合同新聞', '1955年', '2月', '5-y-2_04', '主大分聞社ラジオ大\nポットクラブ・オブー'),
#   0.8381957057411448),
#  (('大分合同新聞', '1956年', '1月', '10-y-4_02', 'ラジオ大分X 4DMXNHK]'),
#   0.8381957057411448),
#  (('大分合同新聞',
#    '1956年',
#    '12月',
#    '10-y-1_03',
#    '大分市春日浦)\n" ""\n" """"" | www.wrecitory Wory./prom .wrotter witterror| menTrap h y\ns is Drially), 199ipsy,19999; prisharlinior'),
#   0.837359464019321),
#  (('大分合同新聞', '1963年', '4月', '6-y-2_06', '大分前[ジマ 出し'), 0.8373319110405127),
#  (('大分新聞', '1926年', '10月', '30-a-6_01', '大分は\n打擊甚大 | 大分縣に於ける和感が生がm'),
#   0.8373231912730268),
#  (('大分合同新聞', '1961年', '9月', '20-a-3_09', '= 別府、大分の二会場)'), 0.8373191488331797),
#  (('大分新聞', '1933年', '7月', '19-y-1_05', '續夕認可 別府三、大分'), 0.8365037510102766),
#  (('大分合同新聞', '1951年', '5月', '24-y-1_10', '大分放送局 主確大分合同新阳社'),
#   0.8361868438268228),
#  (('大分合同新聞', '1964年', '12月', '14-y-3_01', 'きれいな大分\nて さあどうぞ'),
#   0.83587037496408),
#  (('日曜大分', '1936年', '8月', '31-a-3_11', '認可さる。 大分|佐賀關'), 0.8354859409502269),
#  (('大分新聞', '1936年', '1月', '22-a-2_13', '大分丸の漁況'), 0.8354057433729856),
#  (('大分新聞', '1923年', '9月', '15-y-4_07', 'ニーに定 大分縣からの救植品'), 0.8351517595826258),
#  (('大分合同新聞', '1953年', '6月', '21-a-5_04', '卡内活之大分关心'), 0.8350841857069181),
#  (('大分新聞', '1918年', '12月', '24-a-3_04', '大分縣羅縣會(大日)\ntaminish is *'),
#   0.8350400431570667),
#  (('大分合同新聞', '1965年', '4月', '23-a-4_01', '大分真珠'), 0.8348436901898841),
#  (('大分合同新聞', '1964年', '6月', '21-a-8_02', 'アメリカと即時に\n大分・鶴崎・別府の電'),
#   0.8348383357482648),
#  (('大分合同新聞', '1965年', '8月', '19-a-3_09', '大分に総合食堂|\n大分、別府の七店が'),
#   0.8344621648129376),
#  (('大分合同新聞', '1954年', '9月', '9-a-3_13', '九州電力株式会社大分支'), 0.8342403774994512),
#  (('大分合同新聞', '1967年', '11月', '15-a-7_03', '大分の祭り'), 0.834144532797851),
#  (('大分合同新聞', '1967年', '12月', '10-a-9_06', '「大分の祭り。'), 0.834144532797851),
#  (('大分合同新聞', '1967年', '5月', '18-a-7_04', '大分の祭り、'), 0.834144532797851),
#  (('大分合同新聞', '1967年', '8月', '10-a-7_10', '大分の祭り。'), 0.834144532797851),
#  (('大分新聞', '1951年', '7月', '11-a-2_07', '大分大学生\nlor\n= re'),
#   0.8339212371790913),
#  (('大分合同新聞', '1965年', '11月', '5-a-3_06', '大分力。'), 0.8338015620136325),
#  (('大分合同新聞', '1942年', '5月', '28-a-3_06', '大分市の蟹特配 大分では 、'),
#   0.8337751880693695),
#  (('大分合同新聞', '1943年', '9月', '16-a-3_14', '大分辩道士會了'), 0.8336032479011573),
#  (('豊州新報', '1940年', '9月', '18-a-3_12', '大分辯護士 會總會'), 0.8336032479011573),
#  (('大分合同新聞', '1965年', '8月', '29-a-12_01', '之大分'), 0.8330191685382927),
#  (('豊州新報', '1928年', '12月', '28-y-2_10', '大分縣廳B 年末氣分'), 0.8325691609986521),
#  (('大分新聞', '1920年', '7月', '17-a-4_10', '西大分の'), 0.8322670511983767),
#  (('豊州新報', '1940年', '3月', '20-a-1_04', '大分縣教 晴れの'), 0.8318357747537125),
#  (('大分合同新聞', '1966年', '4月', '25-a-6_05', '大分舞鶴 高田 大分教員\n又南九州大会〈出招'),
#   0.8316622174614593),
#  (('豊州新報', '1927年', '2月', '26-a-2_09', '大分縣 農產物'), 0.8313080816003895),
#  (('大分新聞', '1930年', '3月', '20-a-6_05', '大分商業'), 0.8308539996171489),
#  (('大分新聞', '1935年', '3月', '21-a-1_06', '大分商業'), 0.8308539996171489),
#  (('大分新聞', '1937年', '7月', '13-a-3_05', '大分商業'), 0.8308539996171489),
#  (('大分新聞', '1939年', '9月', '4-f-3_06', '大分商業'), 0.8308539996171489),
#  (('豊州新報', '1938年', '12月', '15-a-2_14', '大分吳服商業'), 0.8308539996171489),
#  (('大分新聞', '1927年', '9月', '16-a-3_03', '一摸擬選舉會\n「けふ大分縣雁'), 0.8307773981239694),
#  (('大分合同新聞', '1961年', '5月', '16-a-5_01', 'タクシー申請 目白押し\n鶴崎・大分・別府、'),
#   0.8307638358899182),
#  (('大分新聞', '1934年', '8月', '13-a-2_04', '大分高小優勝\n2 0 別府恨を呑れ'),
#   0.8304494315650739),
#  (('大分合同新聞', '1956年', '5月', '19-y-3_01', 'あす日田・大分川開き'), 0.8304192662041232),
#  (('豊州新報', '1936年', '9月', '26-a-2_14', '謠曲大會 大分で開く'), 0.8303399987237559),
#  (('大分合同新聞', '1942年', '10月', '5-a-2_09', '大分 大分合同新聞\n社縣'), 0.8302450811704615),
#  (('豊州新報', '1939年', '12月', '14-a-2_15', '大分縣醫師會\n大分市で開く'), 0.8300468580764143),
#  (('豊州新報', '1931年', '1月', '9-a-7_10', '大分市在住 熊本縣人會\n十日每年定會'),
#   0.830032381651326),
#  (('大分新聞', '1919年', '8月', '25-y-3_08', '习船舶檢疫開始 別府大分佐賀關津久見\n二十四日占的實施'),
#   0.8298069078832582),
#  (('大分新聞', '1929年', '5月', '15-a-9_16', '大分、別府を 荒した男'), 0.8295504564184072),
#  (('大分合同新聞', '1965年', '12月', '3-a-7_05', '沖縄の「大分の塔」'), 0.829383127207094),
#  (('大分合同新聞', '1966年', '7月', '26-a-6_02', '「おはよう」 にっぽん」 大分からま'),
#   0.8293615340095176),
#  (('豊州新報', '1942年', '4月', '2-a-2_02', '空から大分入り 大分飛行場からが廳へ'),
#   0.8291388425488746),
#  (('大分合同新聞', '1965年', '10月', '8-a-4_05', '大分国体だより'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '1月', '18-a-4_02', '大分国体へ'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '1月', '13-a-5_03', '大分国体へ'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '1月', '17-a-5_02', '大分国体へ。'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '1月', '20-a-5_02', '大分国体へ'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '1月', '8-a-5_01', '(大分国体へ'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '1月', '6-a-5_02', '(大分国体へ'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '1月', '31-a-5_02', '大分国体へ'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '1月', '30-a-5_02', '(大分国体へ)'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '1月', '12-a-5_02', '(大分国体へ\nってだが,'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '1月', '24-a-5_02', '大分国体へ'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '1月', '9-a-5_03', '(大分国体へ」'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '2月', '2-a-5_02', 'ハ大分国体へ'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '2月', '10-a-5_03', '(大分国体へ)'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '2月', '13-a-5_04', '大分国体へ'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '2月', '1-a-5_04', '大分国体へ'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '2月', '4-a-5_07', '大分国体へ'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '2月', '6-a-5_05', '大分国体へ'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '2月', '11-a-5_06', '大分国体へ'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '2月', '3-a-5_03', '(大分国体へ\n1..\nイマンでOKET'),
#   0.8291125057948692),
#  (('大分合同新聞', '1965年', '7月', '14-a-4_04', '大分国体だより'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '7月', '15-a-4_01', '大分国体だより」'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '7月', '8-a-4_03', '大分国体だよりー'), 0.8291125057948692),
#  (('大分合同新聞', '1965年', '9月', '28-a-9_01', '大分国体'), 0.8291125057948692),
#  (('大分合同新聞', '1966年', '10月', '27-a-12_01', '「大分国体へ'), 0.8291125057948692),
#  (('大分合同新聞', '1966年', '6月', '3-a-4_02', '大分国体'), 0.8291125057948692),
#  (('大分合同新聞', '1966年', '9月', '18-a-13_01', 'さあ 大分国体だ'), 0.8291125057948692),
#  (('大分新聞', '1931年', '8月', '28-a-4_08', '大分地方での 盆踊りの皮切り\nまった大分。'),
#   0.8289957477188481),
#  (('大分新聞', '1933年', '5月', '19-a-3_09', '安中縣% 大分縣人\nmlm'), 0.8288318328379679),
#  (('豊州新報', '1933年', '5月', '6-a-3_16', '大分縣 藥事協會'), 0.8284614278070316),
#  (('日曜大分', '1937年', '3月', '1-a-1_02', '口曜大分'), 0.8284106157819643),
#  (('大分合同新聞', '1948年', '8月', '19-a-2_08', '四大分別府 間该冰'), 0.8282599713661579),
#  (('大分合同新聞', '1954年', '3月', '4-a-1_12', '榨作業說明\n大分會'), 0.8280892586806644),
#  (('大分合同新聞', '1959年', '2月', '9-y-5_02', '大分界。\n澳業'), 0.8272788893355938),
#  (('豊州新報', '1940年', '11月', '16-a-4_11', '大分、別府の各部前藤!'), 0.8272020460985358),
#  (('豊州新報', '1934年', '11月', '18-a-1_05', '大分視察'), 0.8271233947905479),
#  (('大分新聞', '1924年', '5月', '22-a-3_10', '大分縣收購豫想'), 0.8271116593091116),
#  (('大分新聞', '1923年', '3月', '11-a-4_03', '大分市御成,\n大分縣側の希望'), 0.8270818708738545),
#  (('大分合同新聞', '1964年', '10月', '3-a-11_06', '熊本から阿蘇へ'), 0.8264035948699825),
#  (('大分新聞', '1924年', '8月', '29-a-3_06', '大分系での'), 0.8262441729514405),
#  (('大分新聞', '1934年', '4月', '17-y-2_14', '大分日白競技 大分市西斯等において'),
#   0.8257003817002718),
#  (('大分新聞', '1931年', '11月', '6-a-7_12', '大分熊本兩縣 對抗卓球戰\n來名八日熊本市'),
#   0.8254863701602689),
#  (('大分合同新聞', '1958年', '5月', '8-a-3_02', '大分 鼻'), 0.825048999015308),
#  (('大分新聞', '1924年', '3月', '23-a-2_08', '大分縣の竹林」'), 0.8247048907158877),
#  (('大分合同新聞', '1953年', '1月', '4-a-4_01', 'こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1956年', '6月', '3-y-5_01', 'こどもでは\n大分'), 0.82453225068552),
#  (('大分合同新聞', '1957年', '11月', '24-y-5_02', 'こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1957年', '4月', '7-y-5_02', 'こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1957年', '9月', '29-ｙ-5_01', 'こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1958年', '11月', '30-a-5_01', 'こども 大分'), 0.82453225068552),
#  (('大分合同新聞', '1959年', '11月', '14-y-5_02', 'こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1959年', '11月', '28-y-5_02', 'こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1959年', '1月', '25-a-5_02', 'こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1959年', '2月', '1-y-5_02', 'こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1959年', '5月', '30-y-5_01', 'こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1959年', '5月', '2-y-5_04', '「こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1959年', '8月', '1-y-5_03', '(こども 大分'), 0.82453225068552),
#  (('大分合同新聞', '1961年', '10月', '29-a-9_02', 'こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1961年', '4月', '23-a-9_03', '(こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1961年', '7月', '2-a-9_04', '(こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1962年', '7月', '1-a-9_03', 'こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1962年', '8月', '12-a-9_03', 'こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1963年', '12月', '1-a-9_06', '(こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1963年', '5月', '5-a-11_04', '(こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1963年', '6月', '30-a-11_02', '(こども大分と'), 0.82453225068552),
#  (('大分合同新聞', '1964年', '11月', '1-a-11_03', '(こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1964年', '12月', '13-a-12_06', '(こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1964年', '12月', '6-a-14_06', 'こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1964年', '2月', '23-a-9_05', 'こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1964年', '4月', '26-a-9_01', 'こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1964年', '5月', '10-a-9_02', 'こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1964年', '6月', '14-a-9_03', '(こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1964年', '7月', '19-a-9_04', '(こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1964年', '9月', '13-a-12_03', 'こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1965年', '10月', '3-a-14_05', 'こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1965年', '1月', '31-a-12_02', '(こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1965年', '4月', '11-a-12_01', '(こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1965年', '4月', '4-a-12_04', '(こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1965年', '5月', '23-a-12_02', '(こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1965年', '8月', '15-a-14_03', '(こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1965年', '9月', '5-a-12_04', 'こども大分。'), 0.82453225068552),
#  (('大分合同新聞', '1966年', '11月', '6-a-12_02', '(こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1966年', '1月', '30-a-12_02', 'こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1966年', '1月', '23-a-12_06', 'こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1966年', '4月', '3-a-12_01', '(こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1966年', '6月', '19-a-14_03', '(こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1966年', '7月', '3-a-12_02', '「こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1967年', '10月', '6-a-16_02', 'こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1967年', '11月', '26-a-12_04', '(こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1967年', '11月', '19-a-12_05', 'こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1967年', '12月', '17-a-12_04', '(こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1967年', '12月', '10-a-14_04', '- こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1967年', '12月', '3-a-14_04', '(こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1967年', '1月', '8-a-12_01', 'こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1967年', '2月', '12-a-12_03', 'こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1967年', '2月', '5-a-12_01', '(こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1967年', '2月', '19-a-12_01', '(こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1967年', '5月', '7-a-12_04', 'こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1967年', '5月', '28-a-12_02', 'こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1967年', '6月', '11-a-12_06', '(こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1967年', '6月', '4-a-12_03', '(こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1967年', '7月', '2-a-12_02', 'こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1967年', '7月', '9-a-12_03', '(こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1967年', '8月', '20-a-12_03', 'こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1967年', '8月', '13-a-14_03', '(こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1967年', '9月', '3-a-12_03', 'こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1967年', '9月', '24-a-14_04', '(こども大分)'), 0.82453225068552),
#  (('大分合同新聞', '1967年', '9月', '17-a-14_04', '(こども大分'), 0.82453225068552),
#  (('大分合同新聞', '1948年', '2月', '26-a-1_01', '大分商議の'), 0.8243845982168139),
#  (('豊州新報', '1940年', '12月', '28-a-2_12', '大豐漁 大分商議而'), 0.8243845982168139),
#  (('大分新聞', '1952年', '10月', '26-a-1_08', '躍進大分 發告'), 0.8243699994587659),
#  (('大分合同新聞', '1960年', '2月', '10-y-1_01', '大分ュア,\n・カットはテクモー'),
#   0.824233189731918),
#  (('大分合同新聞', '1950年', '2月', '5-a-2_10', '大分合同新聞社 ・こども大分'), 0.8239275508479086),
#  (('豊州新報', '1936年', '7月', '3-a-4_11', '大分縣下で、 職工の争奪\n中国と延岡とて'),
#   0.8235890186708414),
#  (('大分新聞', '1937年', '2月', '1-a-2_10', '下關市在住 大分縣人會'), 0.8234799151047848),
#  (('豊州新報', '1935年', '8月', '16-a-3_10', '大分在住鄉軍 將校會'), 0.8234799151047848),
#  (('大分新聞', '1931年', '6月', '7-a-2_05', '320\n大分新聞勝っ\n大分局恨を吞れ'),
#   0.8230569449386937),
#  (('大分新聞', '1933年', '7月', '2-y-2_10', 'で大分に入った。 飛行機別府號 t览'),
#   0.8229819304613143),
#  (('大分合同新聞', '1953年', '7月', '23-y-2_09', '大分商Geoge06\nese #'),
#   0.822790069349815),
#  (('大分合同新聞', '1955年', '9月', '25-y-2_02', '口才大分晓 08月 NHK'), 0.8224213380347598),
#  (('大分新聞', '1929年', '5月', '5-a-9_11', '大分熊本 麟庭球戦\n大分軍出後'), 0.8217077341564782),
#  (('大分合同新聞', '1959年', '2月', '2-a-1_05', '円 大分鶴崎て奪い合い'), 0.8214668322000127),
#  (('豊州新報', '1930年', '9月', '11-a-10_07', '大分縣に\n新言邏船'), 0.8211026749602921),
#  (('大分合同新聞', '1953年', '10月', '15-a-2_10', '大分支部Aが優勝\n大分躍―別府棄間壁伸'),
#   0.8210983346350654),
#  (('豊州新報', '1937年', '7月', '5-a-2_05', '¥ion\n大分おてん'), 0.8210014403466395),
#  (('大分合同新聞',
#    '1950年',
#    '12月',
#    '30-a-1_04',
#    'WWWWWWWWWWWWWWWWWWWYMAN\nこども大分」 女剂大分 夺合同新間'),
#   0.8209505717735839),
#  (('豊州新報', '1933年', '5月', '3-a-7_16', '大分目白大會'), 0.8207814018535404),
#  (('大分合同新聞', '1961年', '10月', '5-y-3_06', '別府鶴崎は来月'), 0.8207138452355068),
#  (('大分合同新聞', '1967年', '11月', '14-a-8_02', '「大分のくらし.'), 0.8204311859676274),
#  (('豊州新報', '1939年', '2月', '28-a-7_11', 'コロムビアの 演奏自動車 | 大分から別府へ'),
#   0.8204299835635143),
#  (('大分合同新聞', '1946年', '1月', '26-a-2_05', '大分と共同戰線'), 0.8203858243763429),
#  (('大分合同新聞', '1963年', '7月', '23-y-3_01', '大分の業'), 0.8202130400760277),
#  (('大分合同新聞', '1963年', '7月', '29-y-3_01', '大分の業'), 0.8202130400760277),
#  (('大分合同新聞', '1963年', '7月', '31-y-3_01', '大分の業'), 0.8202130400760277),
#  (('大分合同新聞', '1963年', '8月', '2-y-3_02', '大分遍業'), 0.8202130400760277),
#  (('大分新聞', '1930年', '2月', '28-a-5_11', '大分市の 蕭市場 裙司附大分'), 0.8199743000434192),
#  (('大分合同新聞', '1958年', '7月', '13-a-5_02', 'こど大分'), 0.8198497754080267),
#  (('大分新聞', '1934年', '11月', '20-a-3_03', '日田で特產品展\n大分の7をそのま'),
#   0.8192253662057605),
#  (('大分合同新聞', '1955年', '8月', '17-a-3_08', 'ブロレス大分大会'), 0.8191907177426735),
#  (('大分合同新聞', '1956年', '10月', '12-a-4_08', '大分合同説ニュース ライオ大分\n【ききもの'),
#   0.8187067133026139),
#  (('豊州新報', '1935年', '1月', '11-a-1_10', '本會話被命 大分縣農會'), 0.8184937853892172),
#  (('大分新聞', '1930年', '4月', '29-a-6_12', '熊本大分兩關 對抗庭球戰\nば三十日熊本で\n大分の所車'),
#   0.81843093288115),
#  (('大分合同新聞', '1964年', '3月', '25-a-9_08', '九州軽備大分支社 は2日に'), 0.8184268796199374),
#  (('豊州新報', '1938年', '6月', '11-a-3_14', '4E5 ·精神般講演會\n大分別府兩市下'),
#   0.8183515799553092),
#  (('大分新聞', '1936年', '11月', '7-a-2_07', '大分ミーm 日は大分と部が北すす'),
#   0.8179282652771502),
#  (('大分合同新聞', '1955年', '8月', '5-y-2_02', 'ハラジオ大分)\nの番組:NHK'),
#   0.8178407187884826),
#  (('大分合同新聞', '1949年', '11月', '17-a-2_01', 'マラソン大會 -\n大分→'),
#   0.8176031032154998),
#  (('大分合同新聞', '1955年', '5月', '4-y-4_01', '《岁岁才大分X全新XNHKD'), 0.8175724612341622),
#  (('大分合同新聞', '1956年', '4月', '4-y-4_01', '《岁岁才大分X全新XNHKD'), 0.8175724612341622),
#  (('大分新聞', '1935年', '7月', '28-a-3_05', '大分、別府 兩市の住吉祭'), 0.8174785611435829),
#  (('大分新聞', '1898年', '9月', '1-a-2_01', 'バッグ\n辯術と大分縣人'), 0.8169159588474006),
#  (('大分新聞', '1928年', '12月', '13-a-2_12', '熊本メら豊肥線で一\n吳光新氏別府へ\n昨夕大分驛通過'),
#   0.8166457500445689),
#  (('豊州新報', '1934年', '11月', '25-a-6_02', '大分購産の 木炭價下押\n大分舘より報'),
#   0.8165283118619784),
#  (('大分合同新聞', '1964年', '4月', '11-a-1_04', '九州は熊本 鹿児島署'), 0.8164768714138791),
#  (('大分合同新聞', '1965年', '4月', '7-a-3_05', '大分 国東が皮切り\n大分共同海運を設立'),
#   0.8162099572423999),
#  (('大分合同新聞', '1960年', '9月', '1-y-2_02', '大分の民謠'), 0.8160709263034706),
#  (('大分新聞', '1919年', '6月', '3-a-4_06', 'の機ゃ大分・'), 0.8159864443675423),
#  (('大分合同新聞', '1956年', '7月', '5-a-2_08', '* 垢石と大分県\n木下'), 0.8158286131118553),
#  (('豊州新報', '1937年', '5月', '20-a-4_04', '經濟調查 大分縣構內'), 0.8155013753925588),
#  (('豊州新報', '1930年', '10月', '9-a-4_03', '大分縣 獵友會 各役員囑託'), 0.815472394006667),
#  (('大分新聞', '1926年', '6月', '8-a-1_01', '大分俳增\n白田亞選'), 0.8146847864037698),
#  (('大分新聞', '1929年', '6月', '21-a-1_01', '大分徘壇\n白田亞躍'), 0.8146847864037698),
#  (('大分新聞', '1918年', '12月', '14-a-2_02', '大分縣觀縣會(6\n备。“是'), 0.8145127199152473),
#  (('大分合同新聞', '1964年', '3月', '5-a-5_02', '大分市 大野が続く\n津久見c玖珠がトップ'),
#   0.81443191858498),
#  (('大分合同新聞', '1965年', '1月', '30-y-1_10', '大分 川'), 0.8143218320243297),
#  (('大分合同新聞', '1963年', '4月', '22-a-7_04', '大分、別府に分かれ\n大分銀行両組合の大'),
#   0.8142840733830949),
#  (('豊州新報', '1928年', '9月', '5-a-3_03', '牙宋书馆义上\n「數萬枚在撒~\n大分、宮崎兩縣 「及至大分市的企'),
#   0.8137858278792205),
#  (('大分新聞', '1925年', '6月', '18-a-3_09', '一好分\n大分洋灰'), 0.8132104186227963),
#  (('大分新聞', '1937年', '10月', '15-y-2_13', '大分、津久見| 兩救難船'), 0.812725708845618),
#  (('豊州新報', '1937年', '6月', '25-a-2_12', '大分の山口謡'), 0.8124979788258044),
#  (('大分合同新聞', '1967年', '5月', '30-a-4_04', '大分電材\n大分市千代可)。'),
#   0.8121390311460389),
#  (('大分新聞', '1933年', '7月', '7-a-3_07', '別れたい\n大分に相ま\nSS.'), 0.8117618873247983),
#  (('大分新聞', '1936年', '4月', '23-y-3_02', '大分壇'), 0.8116363952265409),
#  (('大分合同新聞', '1955年', '9月', '11-a-3_01', '具体一色の大分・別府,'), 0.8114443480675346),
#  (('大分合同新聞', '1965年', '12月', '8-y-3_02', '11王国大分'), 0.8111354075529272),
#  (('豊州新報', '1936年', '2月', '26-a-2_17', '大分檢番の一 出演もの\n大分産業市へ'),
#   0.8108578845667104),
#  (('大分新聞', '1935年', '11月', '6-a-1_06', '--\n大分※御造過\n::HEL'),
#   0.8106244751706029),
#  (('大分新聞', '1930年', '9月', '23-a-2_05', '大分、別府、中津 三市小學校長會\nけふ中津南部校で'),
#   0.8102442134435062),
#  (('大分新聞', '1933年', '7月', '29-a-1_07', '柳井大分別府 同盟會'), 0.810216244895088),
#  (('大分合同新聞', '1965年', '8月', '22-a-12_05', '(/ども大分)'), 0.8098734934868986),
#  (('大分合同新聞', '1956年', '8月', '4-a-4_03', '大分市民レクリェーシー'), 0.8098715360589314),
#  (('大分新聞', '1953年', '3月', '24-a-2_01', 'J航空大分-大阪'), 0.8097073782343606),
#  (('大分合同新聞', '1964年', '7月', '25-a-5_05', '福岡商か九州」か\nあす大分で九州高校別'),
#   0.8093165813124044),
#  (('大分新聞', '1935年', '12月', '11-a-3_16', '大分聯隊便り 大分は来年1月'), 0.8091694918463717),
#  (('大分新聞', '1952年', '7月', '31-a-1_01', '三山\n大分新周\n| L\nIT ISA 大分新聞社'),
#   0.808950506115893),
#  (('豊州新報', '1936年', '11月', '13-a-1_13', '华也抄近 叫學們业圖文\n大分類'),
#   0.808842229365939),
#  (('大分合同新聞', '1963年', '1月', '27-a-5_05', '大分からも1校|'), 0.8087944376246213),
#  (('豊州新報', '1936年', '12月', '10-a-4_07', '| Shirl\n玖珠郡人會 大分別府在'),
#   0.80876250643436),
#  (('大分合同新聞', '1946年', '10月', '26-a-1_11', '大分縣公根\n---'), 0.8085286758005147),
#  (('大分合同新聞', '1961年', '9月', '18-a-1_03', '|新大分別府港の青写真'), 0.808489424009345),
#  (('大分合同新聞', '1963年', '1月', '1-a-23_03', '大分のおんが、'), 0.8084321007252546),
#  (('豊州新報', '1939年', '6月', '15-a-8_02', '大分から東京、東 京から大分まで -\n豐田孝知'),
#   0.8083304901964042),
#  (('大分合同新聞', '1955年', '12月', '13-a-3_13', 'きのう大分で'), 0.8080291293387276),
#  (('大分新聞', '1932年', '4月', '19-y-2_13', '別府県の 宮崎觀光\n豫定ざほり'),
#   0.8076665949512849),
#  (('大分新聞', '1933年', '9月', '18-a-1_06', '大分縣下の行事\n大分市の諸集會'),
#   0.8071612405956797),
#  (('大分新聞', '1935年', '1月', '21-y-3_03', '| 大分トンスタン |ブ圖案募集'),
#   0.8069248509903254),
#  (('大分合同新聞', '1953年', '10月', '30-y-1_11', '大分銀行株'), 0.8069207449461011),
#  (('豊州新報', '1937年', '5月', '4-a-2_10', '大分丸歸る\n三日大分港へ'), 0.8068818053590553),
#  (('大分新聞', '1934年', '4月', '9-a-3_16', '亞細亞探檢購\n大分新用語'), 0.8068801896576356),
#  (('大分新聞', '1930年', '3月', '1-a-2_15', '有1譯育 補助交附 大分宮崎の分'), 0.8068688571496669),
#  (('大分合同新聞', '1957年', '4月', '22-y-3_09', '元大分購鱗倒れる'), 0.8062038753903719),
#  (('大分合同新聞', '1963年', '9月', '5-y-3_04', '別府をアジトに\n大分 福岡 佐賀 三県を荒らす'),
#   0.8061938413426664),
#  (('大分合同新聞', '1965年', '10月', '28-y-3_01', 'がんばる大分'), 0.8061075353505016),
#  (('大分新聞', '1936年', '3月', '18-a-2_03', '中津市の物質\n大分、別府より安い'),
#   0.8060599649264631),
#  (('豊州新報', '1930年', '11月', '23-a-3_08', '大分洋灰\n來月1日から 三井が販賣'),
#   0.8060161026199886),
#  (('大分合同新聞', '1966年', '8月', '20-a-9_05', '大分 九州観光の中心に'), 0.8059809082254777),
#  (('豊州新報', '1937年', '3月', '17-a-7_13', '小ys\n赤札大分)\n<p:“'),
#   0.8057320593859257),
#  (('大分新聞',
#    '1929年',
#    '3月',
#    '9-a-3_15',
#    '久大線全通後の 旅貨客移動狀態\n玖珠は大分に日田は久留米に 大分運輸事務所の操想'),
#   0.8048811816423254),
#  (('大分新聞', '1937年', '7月', '8-y-3_04', '「大分縣のナンバーワン'), 0.8047645404583287),
#  (('大分合同新聞', '1960年', '1月', '10-a-5_05', '大分県は九州で中位'), 0.8044252639017968),
#  (('豊州新報', '1935年', '7月', '28-a-2_06', '大分縣下の 「國勢調查委員\n大分、別府、中津、西郡'),
#   0.8043361507766679),
#  (('大分合同新聞', '1954年', '7月', '8-a-3_12', '別府の古賀ーしよう\n熊本で暴る。'),
#   0.8042801206705508),
#  (('大分合同新聞', '1955年', '9月', '17-y-1_03', 'al\n大分のれん'), 0.8042418875390042),
#  (('大分新聞', '1933年', '5月', '10-a-2_11', '殘背\n存米 大分、宮崎'), 0.8041191218633086),
#  (('大分新聞', '1934年', '5月', '11-a-2_08', '【大分師範】'), 0.8039113881891131),
#  (('豊州新報', '1938年', '12月', '16-a-3_11', '大分師範の\n發業\ndmmiharm'),
#   0.8039113881891131),
#  (('大分合同新聞',
#    '1943年',
#    '9月',
#    '27-a-3_07',
#    '大分縣 大分縣商工控海事 大政梵大分縣支部 大分縣彈特壯年團 大分合同新聞社'),
#   0.8038382685904157),
#  (('大分新聞', '1934年', '6月', '26-a-3_08', '大分局の從業'), 0.80375530431239),
#  (('大分合同新聞', '1954年', '8月', '8-a-2_09', '竹田(大分)~28度\nOXIN'),
#   0.8037478512615756),
#  (('大分新聞', '1936年', '6月', '2-y-2_08', '書籍萬引 臼杵、大分'), 0.8036960023265606),
#  (('大分新聞', '1952年', '2月', '16-a-1_14', '- 大分が最高 -'), 0.8036305025705379),
#  (('豊州新報', '1935年', '1月', '8-a-4_11', '入營兵の宿」 大分市内の割當て 事務所は大分驛前に'),
#   0.803486875516531),
#  (('大分新聞', '1935年', '10月', '22-y-2_10', '『生長の家」の 講演會 大分で'),
#   0.8033993794962133),
#  (('大分新聞', '1928年', '12月', '4-a-2_12', '大分啦隊 軍旗歸還 七日大分縣書'), 0.803377465263287),
#  (('大分合同新聞', '1955年', '7月', '15-a-1_12', '大分第二郡氏太守諸校校事 新任而言:'),
#   0.8033715482358009),
#  (('豊州新報', '1933年', '5月', '28-a-4_18', '佐賀關のスリー\n餘罪ぞくく是\n大分、別府にも被害があ7'),
#   0.8033584202248947),
#  (('大分新聞', '1936年', '4月', '12-a-4_01', '大分歌 瘋'), 0.803114582653764),
#  (('豊州新報', '1932年', '12月', '22-a-2_15', '大分税務署 ドーナス'), 0.802828524117103),
#  (('大分合同新聞', '1951年', '12月', '7-a-1_04', 'lu-0\nF114\nWWWWWWWWWW\n朝刊\n大分會'),
#   0.8026241292744576),
#  (('大分新聞', '1933年', '10月', '21-g-2_02', 'ゴッタ返す\n別府支店を大分扱店'),
#   0.8025155565014466),
#  (('大分新聞', '1922年', '9月', '6-a-3_07', '長距離電話の開設 大分久留米間、大分鳥栖間'),
#   0.8024920905928591),
#  (('大分新聞', '1934年', '8月', '19-y-1_16', '郷田中將大分 | から京都へ'), 0.8024680087735765),
#  (('豊州新報', '1938年', '4月', '23-a-3_10', '產組大分支會 協議會'), 0.8023370238589688),
#  (('大分合同新聞', '1956年', '6月', '27-a-4_06', '「大分からはバドミン ントンの流行を'),
#   0.8015915010236114),
#  (('豊州新報', '1940年', '8月', '17-a-2_10', '大分の疏茶相場一\n大分署の一齊調查'),
#   0.8014987958568568),
#  (('大分新聞', '1934年', '5月', '26-y-2_11', '大分市在住 熊本縣人會 大州で'), 0.8011030470088992),
#  (('大分新聞', '1937年', '8月', '18-y-2_14', '經科 長生略院\n大分市大分'), 0.8010857175864057),
#  (('大分合同新聞', '1953年', '10月', '8-a-1_04', '重点は玖珠川對策\n大分、熊本両県の說明会'),
#   0.8009441695530068),
#  (('大分新聞', '1929年', '11月', '9-a-3_06', '豊肥線の 荷動き狀態,\n大分より熊本行が多い'),
#   0.8009161260804256),
#  (('大分合同新聞', '1961年', '3月', '31-y-1_07', '【大分 那\n校長'), 0.800668364195722),
# ...
#   0.7834834626804266),
#  (('豊州新報', '1942年', '2月', '16-a-4_16', '中等劍道大會(大分飞'), 0.7834734228509795),
#  (('大分新聞', '1931年', '1月', '13-a-7_04', 'TT\n大分縣人數名負傷'), 0.7834007998828507),
#  (('大分合同新聞', '1961年', '3月', '13-y-3_01', '地価 はね上がる。\n臨エブームの大分・鶴崎'),
#   0.783342992281753),
#  (('大分新聞', '1941年', '10月', '16-a-1_05', '大分縣標行'), 0.7831200846056193),
#  (('大分合同新聞', '1959年', '11月', '26-a-6_02', '大分、別府両球場て\n" 中日のキャンプ'),
#   0.782907481246298),
#  (('豊州新報', '1935年', '9月', '21-a-7_04', '徵兵合格當籤者\n別府、大分、中津三市'),
#   0.7828371773490803),
#  (('大分合同新聞', '1961年', '8月', '3-y-1_14', '(大分各同案內)'), 0.7827239294600788),
#  (('大分新聞', '1930年', '10月', '19-a-4_13', '大分縣 弓道大會\n11'), 0.7825164114356685),
#  (('豊州新報', '1937年', '10月', '29-a-2_10', '戰傷兵\n大分《轉送'), 0.7825098545697026),
#  (('大分新聞', '1935年', '8月', '27-a-2_08', 'RE\n關屋熊本縣知 事鶴崎視察'),
#   0.7824602665600201),
#  (('豊州新報', '1927年', '4月', '5-a-4_04', '汽車博覽會\n大分別府でも開催'), 0.7822684209817058),
#  (('大分合同新聞', '1950年', '6月', '15-a-1_02', '大分に營業所鶴。'), 0.7822112482121507),
#  (('大分新聞', '1929年', '11月', '3-a-4_07', '大分縣の得點」\n十川'), 0.7820526940327156),
#  (('大分合同新聞', '1960年', '8月', '4-a-5_15', '大分に書き置\nきドコドウ'), 0.7813674004524496),
#  (('大分新聞', '1938年', '7月', '20-a-2_04', '大分市內商店 正札販賣\n#日大分営が臨做'),
#   0.7813001795407881),
#  (('大分新聞', '1923年', '3月', '27-a-7_10', '大分から 延岡\n二人連れの'), 0.7810936144561907),
#  (('大分新聞', '1932年', '6月', '30-a-2_03', '- 大分、別府、中津\n「教育協議會\n別府高小校に'),
#   0.7807235152193396),
#  (('大分合同新聞', '1964年', '12月', '31-a-4_03', '小說 大分銀行'), 0.7805695521174364),
#  (('大分合同新聞', '1944年', '9月', '24-a-1_11', '佐賀縣の駐\n49. 30'), 0.7805319989652643),
#  (('大分新聞', '1925年', '8月', '24-y-2_09', '佐賀に於る 內の演說'), 0.7805319989652643),
#  (('大分新聞', '1937年', '6月', '24-a-3_10', '16\n: PEG\n-4,\n佐賀關雜貨商'),
#   0.7805319989652643),
#  (('大分新聞', '1938年', '3月', '26-y-2_05', '「である\n佐賀關地區に'), 0.7805319989652643),
#  (('豊州新報', '1933年', '6月', '7-a-8_03', '佐賀關行'), 0.7805319989652643),
#  (('豊州新報', '1936年', '12月', '22-a-2_08', '入退營奉告祭 と姆軍入會式 ?:佐賀關町て'),
#   0.7805319989652643),
#  (('豊州新報', '1937年', '11月', '26-a-1_11', '佐賀關'), 0.7805319989652643),
#  (('豊州新報', '1938年', '3月', '5-a-2_12', '佐賀關例'), 0.7805319989652643),
#  (('豊州新報', '1938年', '6月', '17-a-2_18', '佐賀關'), 0.7805319989652643),
#  (('豊州新報', '1941年', '3月', '2-a-7_12', '佐賀關町の'), 0.7805319989652643),
#  (('大分合同新聞', '1955年', '11月', '20-a-2_07', '大分県い觀光'), 0.7804908872510917),
#  (('大分合同新聞', '1945年', '12月', '30-a-1_05', '- 大分縣民に告ぐ'), 0.7803751279607483),
#  (('大分合同新聞', '1945年', '12月', '29-a-1_03', '「大分縣民に告ぐ-|'), 0.7803751279607483),
#  (('大分合同新聞', '1945年', '12月', '31-a-1_05', '大分縣民に告ぐ |'), 0.7803751279607483),
#  (('大分合同新聞', '1964年', '3月', '19-a-6_05', '大町 大分パズ発狂\n主催\n大分合同新聞辻 大分バス観光社'),
#   0.7803455302822311),
#  (('豊州新報', '1930年', '10月', '28-a-7_05', '大分縣名勝地\n叫干'), 0.7800046050589798),
#  (('日曜大分', '1934年', '8月', '6-a-2_01', '少年キャムブ團\n阿蘇〈大分驛出發'),
#   0.7798914897094302),
#  (('大分新聞', '1925年', '10月', '30-a-4_14', '貸ボートの只乘りて 別府5大分に來怪漢\n大分署に準げらる」'),
#   0.77988787170619),
#  (('大分新聞',
#    '1935年',
#    '7月',
#    '22-a-2_05',
#    'サムの試合番組 大分商業一層叫對性怕中期三\n正午阳 大分工業(1) 對 大分師範三'),
#   0.7798500377947654),
#  (('豊州新報', '1940年', '4月', '14-a-1_07', '講習會 、大分、岡て'), 0.779765171455215),
#  (('大分新聞', '1937年', '3月', '18-y-1_03', '大分市豫算の内容」\n朝吹大分市長の說明'),
#   0.7797306317348209),
#  (('豊州新報', '1934年', '1月', '23-a-4_10', '大分地方G 大寒中 大分測候所調查'),
#   0.7796565767218234),
#  (('大分合同新聞', '1962年', '3月', '20-a-4_01', '大分県赤ちゃんコンクープ'), 0.7796527379989715),
#  (('大分合同新聞', '1966年', '11月', '3-a-9_01', '・赤ちゃん 大分県'), 0.7796527379989715),
#  (('大分新聞', '1930年', '2月', '14-a-4_05', '長野候補 大野大分轉戰'), 0.7794227005373923),
#  (('大分新聞', '1934年', '11月', '26-a-1_08', '森永の爆笑大會\n大分、別府に大宣'),
#   0.779371903152115),
#  (('大分合同新聞', '1964年', '1月', '7-a-5_09', '響 大分国体に備'), 0.7793272582577839),
#  (('大分合同新聞', '1964年', '7月', '17-a-1_02', '大分をモデル地区に'), 0.7793072585529279),
#  (('大分合同新聞', '1965年', '2月', '8-a-4_06', '大分国体入光明霸道。'), 0.779288335408192),
#  (('大分合同新聞', '1962年', '1月', '20-a-1_07', '大分坂ノ市まで\nS鶏 新大分港の港域'),
#   0.7792343417113793),
#  (('大分新聞', '1941年', '10月', '6-a-1_12', 'また\n日産大分出張'), 0.7789894204332065),
#  (('豊州新報', '1934年', '1月', '11-a-4_11', '店の比は\n香川縣\n大分の'), 0.778887333495725),
#  (('大分合同新聞', '1960年', '9月', '14-y-3_02', '「大分県とな年7'), 0.7788073721672979),
#  (('大分新聞', '1925年', '5月', '9-a-4_07', '大分市 高齡者'), 0.7786266647329874),
#  (('豊州新報', '1939年', '7月', '27-a-7_06', '購代表として 南九州決勝大會へ\n大分商業と大分工業'),
#   0.778562424216355),
#  (('大分合同新聞', '1966年', '8月', '31-a-6_01', '別府をうるおす大分川の'), 0.7785099985908063),
#  (('豊州新報', '1927年', '11月', '22-a-5_11', '大分恐數叫椰油'), 0.77842561094732),
#  (('大分合同新聞', '1956年', '10月', '7-a-2_04', '一大分・熊本にリード許す'), 0.778345699664091),
#  (('大分新聞', '1921年', '7月', '19-a-7_07', '石炭部\n同大分縣三十那\n大分支站'),
#   0.7783327257841461),
#  (('大分合同新聞', '1967年', '10月', '2-a-6_01', 'せり合う日田市大分市'), 0.7783085513606041),
#  (('大分新聞', '1934年', '10月', '14-y-1_05', '道路から観 た大分縣\n中津営語'),
#   0.7782047541651373),
#  (('大分合同新聞', '1965年', '4月', '4-a-4_01', '大分企業太平記。\n小說大分交通'),
#   0.7781534153441729),
#  (('大分合同新聞', '1965年', '5月', '10-a-3_04', '大分企業太平記。\n小說大分交通'),
#   0.7781534153441729),
#  (('大分合同新聞', '1965年', '11月', '30-a-5_03', '大分から新生国体'), 0.7781464363614415),
#  (('大分合同新聞', '1966年', '3月', '29-a-1_08', '県下は大分バスだは'), 0.7780395618200179),
#  (('大分新聞', '1930年', '10月', '16-a-1_03', '大分縣明年度豫算'), 0.7779931554696151),
#  (('豊州新報', '1936年', '6月', '14-a-7_11', 'Marchirt.\n十四日大分港て 大分觀正會'),
#   0.777819256138356),
#  (('大分合同新聞',
#    '1956年',
#    '9月',
#    '13-a-3_09',
#    '乘这也觀光团四千名\n部 久留米大分、別府に\n| ihe\nvar 19:\ne"'),
#   0.7778075245742355),
#  (('大分合同新聞', '1966年', '6月', '1-y-1_01', '大分必入之\n国体AF宅'), 0.7776895077975765),
#  (('豊州新報', '1931年', '11月', '24-a-2_21', '大分販賣組合 定時總會 大分で開く'),
#   0.7774860348923118),
#  (('豊州新報', '1934年', '4月', '7-a-1_15', 'IP大分中央)\n上小道民(大分セント本'),
#   0.7774847915639944),
#  (('大分新聞', '1938年', '3月', '31-y-1_03', '大分・八幡濱 交會日程决3'), 0.777439080798492),
#  (('大分合同新聞', '1963年', '4月', '5-a-7_05', '生活進路なんでも\nまず大分、別府、中津に'),
#   0.7772670879579016),
#  (('大分合同新聞', '1960年', '6月', '30-y-2_04', '大分の民謡'), 0.7771997811479311),
#  (('大分合同新聞', '1960年', '7月', '21-y-2_03', '大分の民謡'), 0.7771997811479311),
#  (('大分合同新聞', '1960年', '7月', '7-y-2_02', '大分の民謡'), 0.7771997811479311),
#  (('大分合同新聞', '1960年', '8月', '11-y-2_05', '大分の民謡'), 0.7771997811479311),
#  (('大分合同新聞', '1960年', '8月', '4-y-2_03', '大分の民謡'), 0.7771997811479311),
#  (('大分合同新聞', '1961年', '9月', '27-a-3_07', '日トが大分に新工場'), 0.7770745644671017),
#  (('大分合同新聞', '1965年', '1月', '11-a-5_02', '(大分国体へ工'), 0.7769389706048835),
#  (('大分合同新聞', '1965年', '2月', '5-a-5_02', '(大分国体へ工'), 0.7769389706048835),
#  (('大分合同新聞', '1955年', '5月', '1-y-1_02', '大分上田 杵築八坂氏'), 0.7769310023681307),
#  (('大分合同新聞', '1963年', '3月', '9-y-3_01', '湯布院にボタン雪\n大分・別府でもみぞ!'),
#   0.7766708616248876),
#  (('豊州新報', '1930年', '4月', '30-a-3_06', '大分市中。'), 0.7765354599685921),
#  (('大分新聞', '1936年', '1月', '19-y-2_10', '中津から大分へ\nゴールインするまで'),
#   0.7764697284857321),
#  (('大分合同新聞', '1965年', '10月', '5-a-5_06', '大分市(手と別府女子)'), 0.7764600779385489),
#  (('大分合同新聞', '1945年', '1月', '23-a-1_08', '縣警察部異動\n大分、別府、中津'),
#   0.7764017916375198),
#  (('大分合同新聞', '1947年', '1月', '1-a-3_04', '大分県ナンバーワン'), 0.776364509216692),
#  (('大分新聞', '1936年', '5月', '15-y-1_10', '大分縣情 成立'), 0.7763154024561078),
#  (('大分合同新聞', '1950年', '12月', '11-a-2_07', '再試合とも別府勝っ\n大分・別府交萩野球'),
#   0.7760314713271407),
#  (('大分新聞', '1933年', '9月', '12-a-2_08', '兩戰傷兵大分 {轉院'), 0.7760213392095079),
#  (('大分新聞', '1922年', '7月', '28-a-4_09', '九州野球大會\n伦師絕對大分師範叫 大分師範の大勝'),
#   0.7759292550069004),
#  (('大分新聞', '1937年', '10月', '13-y-3_01', '職選盤大分熊本・自動車訪問 大分市內'),
#   0.7758974552233162),
#  (('大分新聞', '1932年', '9月', '8-a-3_04', '購体育大會は 、 全部大分市で開け\n「大分縣のオリムピックだ!」'),
#   0.7758891443103505),
#  (('豊州新報', '1931年', '5月', '15-a-4_06', '豐州健兒 熊本縣下 。'), 0.7758296226969705),
#  (('大分合同新聞', '1962年', '7月', '29-a-6_03', '沖縄選手、大分入り'), 0.7755223575969412),
#  (('大分新聞', '1936年', '7月', '24-a-1_06', '大分地方の 天氣はよくなる\n大分測候所の觀測\nバーコーラスフライス」'),
#   0.7753554966011975),
#  (('豊州新報', '1929年', '8月', '25-a-2_14', '大分セメントの 大販賞店招待\n別府'),
#   0.7752741847932583),
#  (('豊州新報', '1932年', '6月', '8-a-8_03', '轄豈後拉\n太好而可\n大分にて、'),
#   0.7752186394493497),
#  (('大分新聞', '1935年', '11月', '7-y-2_12', '大分川製倒ね。 老婆轢き殺さる\n大分佐賀關間バス'),
#   0.775204667896522),
#  (('大分合同新聞', '1953年', '7月', '17-a-2_07', 'mmmンビー\n|大分稅務署の\n0.4*'),
#   0.775147446474369),
#  (('大分新聞', '1923年', '12月', '11-y-2_12', '大分署に救取闘中'), 0.775147446474369),
#  (('豊州新報', '1929年', '11月', '29-a-2_08', '大分署で、\nのろける'), 0.775147446474369),
#  (('大分合同新聞', '1960年', '10月', '26-a-1_03', '『大分合同新廣'), 0.7750627262299603),
#  (('大分合同新聞', '1961年', '4月', '21-y-1_04', '「大分合同新廣'), 0.7750627262299603),
#  (('大分合同新聞', '1963年', '9月', '20-y-1_03', '"大分合同新廣'), 0.7750627262299603),
#  (('大分合同新聞', '1966年', '2月', '23-a-1_02', '「大分合同新廣'), 0.7750627262299603),
#  (('豊州新報', '1942年', '2月', '17-a-5_07', '大分地方の歓喜'), 0.7749692017848838),
#  (('大分合同新聞', '1961年', '4月', '17-a-5_04', '「立地条件をタテに一\n佐賀関 鶴崎と大分市'),
#   0.7743988217038793),
#  (('大分合同新聞', '1966年', '4月', '8-a-4_01', '大分県のふるさと宇佐神宮'), 0.7742524845725699),
#  (('豊州新報', '1938年', '3月', '18-a-2_12', '鮮米を大分と 直取引したい\n朝鮮の當業者大分ヘ'),
#   0.7742166656297025),
#  (('豊州新報', '1930年', '4月', '22-a-5_11', 'PIA\n大分郡の 後藤八幡'), 0.7741161331738755),
#  (('大分合同新聞', '1961年', '10月', '10-y-4_04', '高級野菜を大分、別府'), 0.7741012349255684),
#  (('大分合同新聞', '1942年', '5月', '26-a-3_08', '大分工業の一'), 0.7738978089096553),
#  (('大分合同新聞', '1958年', '11月', '6-y-2_03', '文芸大分'), 0.773887400161869),
#  (('豊州新報', '1936年', '9月', '26-a-1_10', '大分洋灰の 工場長」 津久見で送迎會'),
#   0.7738803320484461),
#  (('大分新聞', '1928年', '12月', '25-a-2_10', '大分県では、 継九州\n堂島の新搭'),
#   0.7738410720803437),
#  (('大分合同新聞', '1963年', '12月', '8-a-9_01', '生まれ変わる大分市'), 0.7738173159538919),
#  (('大分合同新聞', '1964年', '8月', '12-a-9_12', '来利タイヤル即時に\n製大分|別府'),
#   0.7737147425870489),
#  (('大分合同新聞', '1963年', '1月', '4-y-3_11', 'にし\n大分県から'), 0.773700660356777),
#  (('大分合同新聞', '1954年', '11月', '3-y-3_09', '「一津久見に進出\n大分楽の設置'),
#   0.7736598149738415),
#  (('大分合同新聞', '1958年', '1月', '13-y-2_04', '(ラジオ大分県のNHK)'), 0.7736091726216446),
#  (('大分合同新聞', '1953年', '1月', '26-a-3_13', '"城野、大分へ移送'), 0.7735334523359555),
#  (('大分合同新聞', '1966年', '8月', '26-a-1_12', '(Mょうの世界】\n県下大分'),
#   0.7734706615215039),
#  (('大分新聞', '1929年', '5月', '22-a-2_12', '大分藤下の\nTHISTEINWHIEEEEEEEEEEEEEEEEEE'),
#   0.7734377601574027),
#  (('大分合同新聞', '1962年', '6月', '19-y-4_02', '(中也回大分同PY援棋 |中津地区名人戰'),
#   0.7734275173643367),
#  (('豊州新報', '1938年', '3月', '27-y-3_11', '大分には二度目\n谷田新大分検事正'),
#   0.7733985141369436),
#  (('大分合同新聞', '1966年', '4月', '6-a-1_01', '大分国体 あと2008'), 0.7732772892700344),
#  (('大分合同新聞', '1966年', '5月', '20-a-4_01', '大分国体\n・あと1561'), 0.7732772892700344),
#  (('大分新聞', '1928年', '7月', '14-a-2_17', '大分縣長 更迭發表'), 0.7732548094641455),
#  (('大分新聞', '1925年', '7月', '31-y-3_07', '大分水泳會の'), 0.7731869594296769),
#  (('大分合同新聞', '1956年', '10月', '10-a-4_04', '..\n.....\n大分メニュース ランオ大た。\n【かんな】'),
#   0.7731780054821765),
#  (('大分合同新聞', '1962年', '5月', '19-a-1_07', '大分・鶴崎工 地帯を視察'), 0.7731636142184488),
#  (('豊州新報', '1934年', '11月', '25-a-4_09', '貴金屬泥逮捕\n大分、竹田、日出、杵築'),
#   0.773016455097033),
#  (('大分新聞', '1937年', '6月', '9-y-3_05', '大分縣ZO1物語日'), 0.7730149604187282),
#  (('大分合同新聞', '1942年', '9月', '13-y-1_09', '佐伯日杵、杵築は 大分區裁管轄に\n玉津は中津に'),
#   0.7730025886738372),
#  (('大分合同新聞', '1966年', '9月', '25-a-8_07', '大分市では二'), 0.772978335634272),
#  (('豊州新報', '1942年', '2月', '21-a-3_08', '大分の豫算市會\n二十日小野市長陳菊說明 一般會計九十萬圓'),
#   0.772978335634272),
#  (('大分新聞', '1928年', '2月', '10-a-3_11', '農政黨大分縣支'), 0.7729712073774923),
#  (('大分合同新聞', '1954年', '11月', '23-a-4_06', 'にき5臼杵石仏 大分別府などから団体客'),
#   0.7728368818130368),
#  (('大分新聞', '1930年', '5月', '19-a-3_08', '大分聯隊\n日出生臺'), 0.7726644026746028),
#  (('大分合同新聞', '1963年', '7月', '13-a-3_03', '新産都 大分・鶴崎の青写真'), 0.7725569097036086),
#  (('大分新聞', '1929年', '11月', '13-a-9_04', '大分佛壇\n日田亞浪'), 0.772300084354952),
#  (('大分新聞', '1929年', '4月', '12-a-1_02', '大分佛壇\n日田 亞選'), 0.772300084354952),
#  (('大分新聞', '1930年', '11月', '6-a-1_10', '大分佛壇 日田亞通譯'), 0.772300084354952),
#  (('大分新聞', '1930年', '1月', '28-a-12_02', '大分佛壇\n日田亞視購'), 0.772300084354952),
#  (('大分合同新聞', '1965年', '6月', '20-a-1_08', 'きょう大分、別府へ\n気県南、肥地区終わる'),
#   0.7721390342455525),
#  (('大分合同新聞', '1961年', '10月', '29-a-6_03', '|大分・熊本・長崎県 一九州横断駅伝コース紹介'),
#   0.7719587414380877),
#  (('大分新聞', '1924年', '2月', '28-a-3_10', '大分門司 電話線增設'), 0.771956610375665),
#  (('豊州新報', '1936年', '7月', '10-a-2_11', '大分觀正會 月例會'), 0.7718427626332197),
#  (('大分新聞', '1953年', '8月', '22-a-2_02', '大分市に日本脳炎'), 0.7716966971012745),
#  (('豊州新報',
#    '1937年',
#    '6月',
#    '18-a-4_10',
#    '大分高商 音樂演奏會 主唯 大分高商 音樂部\n大分高両津久見同窓會 豐州新報津久見支局\n發投'),
#   0.7715835752986915),
#  (('大分新聞', '1934年', '10月', '5-y-2_03', 'わが球界の兩雄大分へ'), 0.7715542177283023),
#  (('豊州新報', '1927年', '6月', '3-a-7_09', '上芬\n|大分市'), 0.7714618839005198),
#  (('大分合同新聞', '1965年', '8月', '29-a-8_03', '親切だった大分の主婦\n大分国本に役立てて、'),
#   0.771375445994355),
#  (('大分合同新聞', '1957年', '11月', '8-y-3_12', '大分県クリーニング環境補生同業\n大分支'),
#   0.771360692452804),
#  (('大分合同新聞', '1949年', '6月', '26-a-2_04', '所から大分 C1E分に'), 0.7713435208484035),
#  (('大分新聞', '1930年', '11月', '6-a-4_07', '本縣毓灸按師會\n于京大分會館'), 0.7712190450089907),
#  (('大分新聞', '1928年', '9月', '16-a-2_09', '豊肥線開通を前に 大分熊本握手 大分商工旬幹部一行 建築列車で熊本訪曲'),
#   0.7711903798893165),
#  (('大分新聞', '1936年', '9月', '29-y-3_01', '望主 ] age\n大分圍搭大會'), 0.771176750745138),
#  (('大分合同新聞', '1965年', '2月', '9-a-5_02', '(大分国体へ了'), 0.7711280875234683),
#  (('豊州新報', '1934年', '4月', '18-a-4_08', '九州逓信號の 九州感謝飛行\n四日宮崎から大分・'),
#   0.7711158850594093),
#  (('大分合同新聞', '1951年', '2月', '24-a-1_03', '今津留に大分新高校'), 0.7709968836946505),
#  (('大分合同新聞', '1966年', '8月', '29-y-3_03', '響 大分と日田市指定'), 0.7709739244471252),
#  (('豊州新報', '1933年', '6月', '23-a-1_15', '| 大分トの 地租主任會 大分税務署て'),
#   0.7709714786776022),
#  (('大分合同新聞', '1965年', '3月', '21-a-4_02', '大分縣企業太平 小說大分交通'),
#   0.7708621880631396),
#  (('大分新聞', '1936年', '6月', '24-a-1_09', '日田、大分土 て呼き手'), 0.7705904131712873),
#  (('豊州新報', '1937年', '12月', '6-a-2_05', '大分商議當選者號'), 0.7704855079562396),
#  (('大分合同新聞', '1963年', '2月', '5-y-1_04', '新大分前の問題」'), 0.770393606146143),
#  (('大分合同新聞', '1964年', '4月', '14-a-9_07', '糖 大分ー野津原、今市\n8日から即時に'),
#   0.7703270259425475),
#  (('大分合同新聞', '1960年', '12月', '8-y-3_03', '国労大分が すわり込み'), 0.7702457022075374),
#  (('大分新聞', '1930年', '1月', '20-a-2_11', '大分別府に 販路開拓\nトの'), 0.7702332416909192),
#  (('大分新聞', '1928年', '7月', '5-a-4_11', '大分启陪里时 部福岡、\n西部豫選们'),
#   0.7701578148436462),
#  (('豊州新報', '1937年', '1月', '21-a-2_06', '大分上野丘 | 公園計畫'), 0.7700212072215938),
#  (('豊州新報',
#    '1935年',
#    '4月',
#    '24-a-2_03',
#    '大分の博覽會は 十二年には出來ぬ 大分港と別大國道竣成後か\n別府と大分の意見'),
#   0.7700122839726469),
#  (('大分合同新聞', '1965年', '1月', '27-a-3_10', '長崎を参考に\n大分文化会津設の大め'),
#   0.7699929577531772),
#  (('大分合同新聞', '1966年', '9月', '10-y-6_05', '見にくいです大分'), 0.7699896995133784),
#  (('豊州新報', '1935年', '4月', '9-a-4_06', '熊本博觀光團 大分鼻を出'), 0.769984948593477),
#  (('大分合同新聞', '1951年', '11月', '6-a-1_11', '別府、大分の 災害地視察'), 0.7699643767071683),
#  (('大分合同新聞', '1965年', '2月', '27-y-3_05', '大分市がトップ\n中津、下毛がんばる'),
#   0.7699239122140411),
#  (('大分合同新聞', '1966年', '8月', '24-a-5_04', '日田と津久見子\n大分国体高校弓道代表'),
#   0.7698689719457907),
#  (('豊州新報', '1928年', '5月', '8-a-4_03', '大分の\n烯共進會\n各地からの'), 0.7698111211778873),
#  (('豊州新報', '1939年', '5月', '24-a-2_01', '大分縣下の 七電氣總會\n廿三日大分で開かる'),
#   0.769797916743296),
#  (('大分合同新聞', '1960年', '9月', '26-a-7_01', '熊本城圧した 水上大分'), 0.7697583206739277),
#  (('大分新聞', '1951年', '6月', '27-a-1_05', '舞鶴大橋流失大分市\n大分市'), 0.7696582311767242),
#  (('大分合同新聞',
#    '1950年',
#    '12月',
#    '1-a-1_04',
#    'mahhhhhh\nだって難度一 「タ利大分| FUども大分\n大分出\n発行所 大分市に 有限会社\n2門5'),
#   0.7695706727183971),
#  (('豊州新報', '1937年', '7月', '10-a-3_10', '大分中津間 國道の改修\n大分戸次間「緊要\nよなー」'),
#   0.7694778449889988),
#  (('大分新聞', '1925年', '2月', '18-a-3_12', '大分 宮崎和 炳稅務打合过\n大分税務署で開館'),
#   0.7694403706954674),
#  (('大分合同新聞', '1962年', '11月', '24-a-5_01', '大分が初優勝飾る\n西日本各県 福岡と鹿児島に圧勝'),
#   0.7692952040272165),
#  (('大分合同新聞', '1964年', '9月', '6-a-9_01', '来月 日田、大分へ\n肉匠バーナードリーチ氏'),
#   0.7692605789395812),
#  (('豊州新報', '1934年', '2月', '27-a-2_07', '大分市豫算\n一般會計の內容'), 0.7692513499223266),
#  (('大分新聞', '1929年', '2月', '6-a-3_06', '大分商人の'), 0.7691095969345222),
#  (('大分新聞', '1930年', '10月', '13-a-3_04', '大分縣の二再 年宮崎で取關'), 0.7689969006007211),
#  (('大分新聞', '1923年', '5月', '20-a-4_04', '別府大分間、別府翻川間'), 0.7688603561449437),
#  (('大分合同新聞', '1967年', '7月', '27-a-3_01', '大分一阪神フェリ'), 0.7687303351272892),
#  (('大分合同新聞', '1963年', '12月', '3-a-3_07', '水産高の大分'), 0.7686083153453025),
#  (('大分合同新聞', '1954年', '3月', '16-y-3_07', '來月1日から大分市'), 0.7685143835096098),
#  (('大分合同新聞', '1957年', '10月', '22-a-4_03', '29日に大分市'), 0.7685143835096098),
#  ...]

# %%
make_json(similarity_headlines)
